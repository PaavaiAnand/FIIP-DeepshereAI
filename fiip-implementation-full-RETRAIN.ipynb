# %%
#Loading libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
#loading Dataset
df = pd.read_csv("C:\\Users\91944\Desktop\\fiipdata.csv")

# %%
#displaying first 10 rows of data
df.head(10).T
# Out:
#                                                  0          1  \
# encounter_id                               2278392     149190
# patient_nbr                                8222157   55629189
# race                                     Caucasian  Caucasian
# gender                                      Female     Female
# age                                         [0-10)    [10-20)
# weight                                           ?          ?
# admission_type_id                                6          1
# discharge_disposition_id                        25          1
# admission_source_id                              1          7
# time_in_hospital                                 1          3
# payer_code                                       ?          ?
# medical_specialty         Pediatrics-Endocrinology          ?
# num_lab_procedures                              41         59
# num_procedures                                   0          0
# num_medications                                  1         18
# number_outpatient                                0          0
# number_emergency                                 0          0
# number_inpatient                                 0          0
# diag_1                                      250.83        276
# diag_2                                           ?     250.01
# diag_3                                           ?        255
# number_diagnoses                                 1          9
# max_glu_serum                                 None       None
# A1Cresult                                     None       None
# metformin                                       No         No
# repaglinide                                     No         No
# nateglinide                                     No         No
# chlorpropamide                                  No         No
# glimepiride                                     No         No
# acetohexamide                                   No         No
# glipizide                                       No         No
# glyburide                                       No         No
# tolbutamide                                     No         No
# pioglitazone                                    No         No
# rosiglitazone                                   No         No
# acarbose                                        No         No
# miglitol                                        No         No
# troglitazone                                    No         No
# tolazamide                                      No         No
# examide                                         No         No
# citoglipton                                     No         No
# insulin                                         No         Up
# glyburide-metformin                             No         No
# glipizide-metformin                             No         No
# glimepiride-pioglitazone                        No         No
# metformin-rosiglitazone                         No         No
# metformin-pioglitazone                          No         No
# change                                          No         Ch
# diabetesMed                                     No        Yes
# readmitted                                      NO        >30
#
#                                         2          3          4          5  \
# encounter_id                        64410     500364      16680      35754
# patient_nbr                      86047875   82442376   42519267   82637451
# race                      AfricanAmerican  Caucasian  Caucasian  Caucasian
# gender                             Female       Male       Male       Male
# age                               [20-30)    [30-40)    [40-50)    [50-60)
# weight                                  ?          ?          ?          ?
# admission_type_id                       1          1          1          2
# discharge_disposition_id                1          1          1          1
# admission_source_id                     7          7          7          2
# time_in_hospital                        2          2          1          3
# payer_code                              ?          ?          ?          ?
# medical_specialty                       ?          ?          ?          ?
# num_lab_procedures                     11         44         51         31
# num_procedures                          5          1          0          6
# num_medications                        13         16          8         16
# number_outpatient                       2          0          0          0
# number_emergency                        0          0          0          0
# number_inpatient                        1          0          0          0
# diag_1                                648          8        197        414
# diag_2                                250     250.43        157        411
# diag_3                                V27        403        250        250
# number_diagnoses                        6          7          5          9
# max_glu_serum                        None       None       None       None
# A1Cresult                            None       None       None       None
# metformin                              No         No         No         No
# repaglinide                            No         No         No         No
# nateglinide                            No         No         No         No
# chlorpropamide                         No         No         No         No
# glimepiride                            No         No         No         No
# acetohexamide                          No         No         No         No
# glipizide                          Steady         No     Steady         No
# glyburide                              No         No         No         No
# tolbutamide                            No         No         No         No
# pioglitazone                           No         No         No         No
# rosiglitazone                          No         No         No         No
# acarbose                               No         No         No         No
# miglitol                               No         No         No         No
# troglitazone                           No         No         No         No
# tolazamide                             No         No         No         No
# examide                                No         No         No         No
# citoglipton                            No         No         No         No
# insulin                                No         Up     Steady     Steady
# glyburide-metformin                    No         No         No         No
# glipizide-metformin                    No         No         No         No
# glimepiride-pioglitazone               No         No         No         No
# metformin-rosiglitazone                No         No         No         No
# metformin-pioglitazone                 No         No         No         No
# change                                 No         Ch         Ch         No
# diabetesMed                           Yes        Yes        Yes        Yes
# readmitted                             NO         NO         NO        >30
#
#                                   6          7          8                 9
# encounter_id                  55842      63768      12522             15738
# patient_nbr                84259809  114882984   48330783          63555939
# race                      Caucasian  Caucasian  Caucasian         Caucasian
# gender                         Male       Male     Female            Female
# age                         [60-70)    [70-80)    [80-90)          [90-100)
# weight                            ?          ?          ?                 ?
# admission_type_id                 3          1          2                 3
# discharge_disposition_id          1          1          1                 3
# admission_source_id               2          7          4                 4
# time_in_hospital                  4          5         13                12
# payer_code                        ?          ?          ?                 ?
# medical_specialty                 ?          ?          ?  InternalMedicine
# num_lab_procedures               70         73         68                33
# num_procedures                    1          0          2                 3
# num_medications                  21         12         28                18
# number_outpatient                 0          0          0                 0
# number_emergency                  0          0          0                 0
# number_inpatient                  0          0          0                 0
# diag_1                          414        428        398               434
# diag_2                          411        492        427               198
# diag_3                          V45        250         38               486
# number_diagnoses                  7          8          8                 8
# max_glu_serum                  None       None       None              None
# A1Cresult                      None       None       None              None
# metformin                    Steady         No         No                No
# repaglinide                      No         No         No                No
# nateglinide                      No         No         No                No
# chlorpropamide                   No         No         No                No
# glimepiride                  Steady         No         No                No
# acetohexamide                    No         No         No                No
# glipizide                        No         No     Steady                No
# glyburide                        No     Steady         No                No
# tolbutamide                      No         No         No                No
# pioglitazone                     No         No         No                No
# rosiglitazone                    No         No         No            Steady
# acarbose                         No         No         No                No
# miglitol                         No         No         No                No
# troglitazone                     No         No         No                No
# tolazamide                       No         No         No                No
# examide                          No         No         No                No
# citoglipton                      No         No         No                No
# insulin                      Steady         No     Steady            Steady
# glyburide-metformin              No         No         No                No
# glipizide-metformin              No         No         No                No
# glimepiride-pioglitazone         No         No         No                No
# metformin-rosiglitazone          No         No         No                No
# metformin-pioglitazone           No         No         No                No
# change                           Ch         No         Ch                Ch
# diabetesMed                     Yes        Yes        Yes               Yes
# readmitted                       NO        >30         NO                NO

# %%
#checking shape of the dataset
df.shape
# Out:
# (101666, 50)

# %%
#Checking data types of each variable
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# examide                     object
# citoglipton                 object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                  object
# dtype: object

# %%
#Checking for missing values in dataset
#In the dataset missing values are represented as '?' sign
for col in df.columns:
    if df[col].dtype == object:
         print(col,df[col][df[col] == '?'].count())
# Out:
# race 2269
# gender 0
# age 0
# weight 98471
# payer_code 40243
# medical_specialty 49877
# diag_1 21
# diag_2 357
# diag_3 1422
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# examide 0
# citoglipton 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0

# %%
# gender was coded differently so we use a custom count for this one            
print('gender', df['gender'][df['gender'] == 'Unknown/Invalid'].count())
# Out:
# gender 3

# %%
#dropping columns with large number of missing values
df = df.drop(['weight','payer_code','medical_specialty'], axis = 1)

# %%
drop_Idx = set(df[(df['diag_1'] == '?') & (df['diag_2'] == '?') & (df['diag_3'] == '?')].index)

drop_Idx = drop_Idx.union(set(df['diag_1'][df['diag_1'] == '?'].index))
drop_Idx = drop_Idx.union(set(df['diag_2'][df['diag_2'] == '?'].index))
drop_Idx = drop_Idx.union(set(df['diag_3'][df['diag_3'] == '?'].index))
drop_Idx = drop_Idx.union(set(df['race'][df['race'] == '?'].index))
drop_Idx = drop_Idx.union(set(df[df['discharge_disposition_id'] == 11].index))
drop_Idx = drop_Idx.union(set(df['gender'][df['gender'] == 'Unknown/Invalid'].index))
new_Idx = list(set(df.index) - set(drop_Idx))
df = df.iloc[new_Idx]

# %%
df = df.drop(['citoglipton', 'examide'], axis = 1)

# %%
#Checking for missing values in the data
for col in df.columns:
    if df[col].dtype == object:
         print(col,df[col][df[col] == '?'].count())
            
print('gender', df['gender'][df['gender'] == 'Unknown/Invalid'].count())
# Out:
# race 0
# gender 0
# age 0
# diag_1 0
# diag_2 0
# diag_3 0
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0
# gender 0

# %%
#Feature Engineering
df['service_utilization'] = df['number_outpatient'] + df['number_emergency'] + df['number_inpatient']

# %%
keys = ['metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 'glyburide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'insulin', 'glyburide-metformin', 'tolazamide', 'metformin-pioglitazone','metformin-rosiglitazone', 'glimepiride-pioglitazone', 'glipizide-metformin', 'troglitazone', 'tolbutamide', 'acetohexamide']
for col in keys:
    colname = str(col) + 'temp'
    df[colname] = df[col].apply(lambda x: 0 if (x == 'No' or x == 'Steady') else 1)
df['numchange'] = 0
for col in keys:
    colname = str(col) + 'temp'
    df['numchange'] = df['numchange'] + df[colname]
    del df[colname]
    
df['numchange'].value_counts()
# Out:
# 0    70085
# 1    24888
# 2     1268
# 3      106
# 4        5
# Name: numchange, dtype: int64

# %%
# re-encoding admission type, discharge type and admission source into fewer categories

df['admission_type_id'] = df['admission_type_id'].replace(2,1)
df['admission_type_id'] = df['admission_type_id'].replace(7,1)
df['admission_type_id'] = df['admission_type_id'].replace(6,5)
df['admission_type_id'] = df['admission_type_id'].replace(8,5)

df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(6,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(8,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(9,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(13,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(3,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(4,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(5,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(14,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(22,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(23,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(24,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(12,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(15,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(16,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(17,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(25,18)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(26,18)

df['admission_source_id'] = df['admission_source_id'].replace(2,1)
df['admission_source_id'] = df['admission_source_id'].replace(3,1)
df['admission_source_id'] = df['admission_source_id'].replace(5,4)
df['admission_source_id'] = df['admission_source_id'].replace(6,4)
df['admission_source_id'] = df['admission_source_id'].replace(10,4)
df['admission_source_id'] = df['admission_source_id'].replace(22,4)
df['admission_source_id'] = df['admission_source_id'].replace(25,4)
df['admission_source_id'] = df['admission_source_id'].replace(15,9)
df['admission_source_id'] = df['admission_source_id'].replace(17,9)
df['admission_source_id'] = df['admission_source_id'].replace(20,9)
df['admission_source_id'] = df['admission_source_id'].replace(21,9)
df['admission_source_id'] = df['admission_source_id'].replace(13,11)
df['admission_source_id'] = df['admission_source_id'].replace(14,11)

# %%
df['change'] = df['change'].replace('Ch', 1)
df['change'] = df['change'].replace('No', 0)
df['gender'] = df['gender'].replace('Male', 1)
df['gender'] = df['gender'].replace('Female', 0)
df['diabetesMed'] = df['diabetesMed'].replace('Yes', 1)
df['diabetesMed'] = df['diabetesMed'].replace('No', 0)
# keys is the same as before
for col in keys:
    df[col] = df[col].replace('No', 0)
    df[col] = df[col].replace('Steady', 1)
    df[col] = df[col].replace('Up', 1)
    df[col] = df[col].replace('Down', 1)

# %%
df['A1Cresult'] = df['A1Cresult'].replace('>7', 1)
df['A1Cresult'] = df['A1Cresult'].replace('>8', 1)
df['A1Cresult'] = df['A1Cresult'].replace('Norm', 0)
df['A1Cresult'] = df['A1Cresult'].replace('None', -99)
df['max_glu_serum'] = df['max_glu_serum'].replace('>200', 1)
df['max_glu_serum'] = df['max_glu_serum'].replace('>300', 1)
df['max_glu_serum'] = df['max_glu_serum'].replace('Norm', 0)
df['max_glu_serum'] = df['max_glu_serum'].replace('None', -99)

# %%
# code age intervals [0-10) - [90-100) from 1-10
for i in range(0,10):
    df['age'] = df['age'].replace('['+str(10*i)+'-'+str(10*(i+1))+')', i+1)
df['age'].value_counts()
# Out:
# 8     24784
# 7     21512
# 6     16530
# 9     16205
# 5      9199
# 4      3532
# 10     2591
# 3      1470
# 2       465
# 1        64
# Name: age, dtype: int64

# %%
df2 = df.drop_duplicates(subset= ['patient_nbr'], keep = 'first')
df2.shape
(70442, 55)
# Out:
# (70442, 55)

# %%
df.head().T
# Out:
#                                   1                2          3          4  \
# encounter_id                 149190            64410     500364      16680
# patient_nbr                55629189         86047875   82442376   42519267
# race                      Caucasian  AfricanAmerican  Caucasian  Caucasian
# gender                            0                0          1          1
# age                               2                3          4          5
# admission_type_id                 1                1          1          1
# discharge_disposition_id          1                1          1          1
# admission_source_id               7                7          7          7
# time_in_hospital                  3                2          2          1
# num_lab_procedures               59               11         44         51
# num_procedures                    0                5          1          0
# num_medications                  18               13         16          8
# number_outpatient                 0                2          0          0
# number_emergency                  0                0          0          0
# number_inpatient                  0                1          0          0
# diag_1                          276              648          8        197
# diag_2                       250.01              250     250.43        157
# diag_3                          255              V27        403        250
# number_diagnoses                  9                6          7          5
# max_glu_serum                   -99              -99        -99        -99
# A1Cresult                       -99              -99        -99        -99
# metformin                         0                0          0          0
# repaglinide                       0                0          0          0
# nateglinide                       0                0          0          0
# chlorpropamide                    0                0          0          0
# glimepiride                       0                0          0          0
# acetohexamide                     0                0          0          0
# glipizide                         0                1          0          1
# glyburide                         0                0          0          0
# tolbutamide                       0                0          0          0
# pioglitazone                      0                0          0          0
# rosiglitazone                     0                0          0          0
# acarbose                          0                0          0          0
# miglitol                          0                0          0          0
# troglitazone                      0                0          0          0
# tolazamide                        0                0          0          0
# insulin                           1                0          1          1
# glyburide-metformin               0                0          0          0
# glipizide-metformin               0                0          0          0
# glimepiride-pioglitazone          0                0          0          0
# metformin-rosiglitazone           0                0          0          0
# metformin-pioglitazone            0                0          0          0
# change                            1                0          1          1
# diabetesMed                       1                1          1          1
# readmitted                      >30               NO         NO         NO
# service_utilization               0                3          0          0
# numchange                         1                0          1          0
#
#                                   5
# encounter_id                  35754
# patient_nbr                82637451
# race                      Caucasian
# gender                            1
# age                               6
# admission_type_id                 1
# discharge_disposition_id          1
# admission_source_id               1
# time_in_hospital                  3
# num_lab_procedures               31
# num_procedures                    6
# num_medications                  16
# number_outpatient                 0
# number_emergency                  0
# number_inpatient                  0
# diag_1                          414
# diag_2                          411
# diag_3                          250
# number_diagnoses                  9
# max_glu_serum                   -99
# A1Cresult                       -99
# metformin                         0
# repaglinide                       0
# nateglinide                       0
# chlorpropamide                    0
# glimepiride                       0
# acetohexamide                     0
# glipizide                         0
# glyburide                         0
# tolbutamide                       0
# pioglitazone                      0
# rosiglitazone                     0
# acarbose                          0
# miglitol                          0
# troglitazone                      0
# tolazamide                        0
# insulin                           1
# glyburide-metformin               0
# glipizide-metformin               0
# glimepiride-pioglitazone          0
# metformin-rosiglitazone           0
# metformin-pioglitazone            0
# change                            0
# diabetesMed                       1
# readmitted                      >30
# service_utilization               0
# numchange                         0

# %%
df['readmitted'].value_counts()
# Out:
# NO     50669
# >30    34626
# <30    11057
# Name: readmitted, dtype: int64

# %%
df['readmitted'] = df['readmitted'].replace('>30', 0)
df['readmitted'] = df['readmitted'].replace('<30', 1)
df['readmitted'] = df['readmitted'].replace('NO', 0)

# %%
# Creating additional columns for diagnosis# Creati 
df['level1_diag1'] = df['diag_1']
df['level2_diag1'] = df['diag_1']
df['level1_diag2'] = df['diag_2']
df['level2_diag2'] = df['diag_2']
df['level1_diag3'] = df['diag_3']
df['level2_diag3'] = df['diag_3']

# %%
df.loc[df['diag_1'].str.contains('V'), ['level1_diag1', 'level2_diag1']] = 0
df.loc[df['diag_1'].str.contains('E'), ['level1_diag1', 'level2_diag1']] = 0
df.loc[df['diag_2'].str.contains('V'), ['level1_diag2', 'level2_diag2']] = 0
df.loc[df['diag_2'].str.contains('E'), ['level1_diag2', 'level2_diag2']] = 0
df.loc[df['diag_3'].str.contains('V'), ['level1_diag3', 'level2_diag3']] = 0
df.loc[df['diag_3'].str.contains('E'), ['level1_diag3', 'level2_diag3']] = 0
df['level1_diag1'] = df['level1_diag1'].replace('?', -1)
df['level2_diag1'] = df['level2_diag1'].replace('?', -1)
df['level1_diag2'] = df['level1_diag2'].replace('?', -1)
df['level2_diag2'] = df['level2_diag2'].replace('?', -1)
df['level1_diag3'] = df['level1_diag3'].replace('?', -1)
df['level2_diag3'] = df['level2_diag3'].replace('?', -1)

# %%
df['level1_diag1'] = df['level1_diag1'].astype(float)
df['level2_diag1'] = df['level2_diag1'].astype(float)
df['level1_diag2'] = df['level1_diag2'].astype(float)
df['level2_diag2'] = df['level2_diag2'].astype(float)
df['level1_diag3'] = df['level1_diag3'].astype(float)
df['level2_diag3'] = df['level2_diag3'].astype(float)

# %%
for index, row in df.iterrows():
    if (row['level1_diag1'] >= 390 and row['level1_diag1'] < 460) or (np.floor(row['level1_diag1']) == 785):
        df.loc[index, 'level1_diag1'] = 1
    elif (row['level1_diag1'] >= 460 and row['level1_diag1'] < 520) or (np.floor(row['level1_diag1']) == 786):
        df.loc[index, 'level1_diag1'] = 2
    elif (row['level1_diag1'] >= 520 and row['level1_diag1'] < 580) or (np.floor(row['level1_diag1']) == 787):
        df.loc[index, 'level1_diag1'] = 3
    elif (np.floor(row['level1_diag1']) == 250):
        df.loc[index, 'level1_diag1'] = 4
    elif (row['level1_diag1'] >= 800 and row['level1_diag1'] < 1000):
        df.loc[index, 'level1_diag1'] = 5
    elif (row['level1_diag1'] >= 710 and row['level1_diag1'] < 740):
        df.loc[index, 'level1_diag1'] = 6
    elif (row['level1_diag1'] >= 580 and row['level1_diag1'] < 630) or (np.floor(row['level1_diag1']) == 788):
        df.loc[index, 'level1_diag1'] = 7
    elif (row['level1_diag1'] >= 140 and row['level1_diag1'] < 240):
        df.loc[index, 'level1_diag1'] = 8
    else:
        df.loc[index, 'level1_diag1'] = 0
        
    if (row['level1_diag2'] >= 390 and row['level1_diag2'] < 460) or (np.floor(row['level1_diag2']) == 785):
        df.loc[index, 'level1_diag2'] = 1
    elif (row['level1_diag2'] >= 460 and row['level1_diag2'] < 520) or (np.floor(row['level1_diag2']) == 786):
        df.loc[index, 'level1_diag2'] = 2
    elif (row['level1_diag2'] >= 520 and row['level1_diag2'] < 580) or (np.floor(row['level1_diag2']) == 787):
        df.loc[index, 'level1_diag2'] = 3
    elif (np.floor(row['level1_diag2']) == 250):
        df.loc[index, 'level1_diag2'] = 4
    elif (row['level1_diag2'] >= 800 and row['level1_diag2'] < 1000):
        df.loc[index, 'level1_diag2'] = 5
    elif (row['level1_diag2'] >= 710 and row['level1_diag2'] < 740):
        df.loc[index, 'level1_diag2'] = 6
    elif (row['level1_diag2'] >= 580 and row['level1_diag2'] < 630) or (np.floor(row['level1_diag2']) == 788):
        df.loc[index, 'level1_diag2'] = 7
    elif (row['level1_diag2'] >= 140 and row['level1_diag2'] < 240):
        df.loc[index, 'level1_diag2'] = 8
    else:
        df.loc[index, 'level1_diag2'] = 0
    
    if (row['level1_diag3'] >= 390 and row['level1_diag3'] < 460) or (np.floor(row['level1_diag3']) == 785):
        df.loc[index, 'level1_diag3'] = 1
    elif (row['level1_diag3'] >= 460 and row['level1_diag3'] < 520) or (np.floor(row['level1_diag3']) == 786):
        df.loc[index, 'level1_diag3'] = 2
    elif (row['level1_diag3'] >= 520 and row['level1_diag3'] < 580) or (np.floor(row['level1_diag3']) == 787):
        df.loc[index, 'level1_diag3'] = 3
    elif (np.floor(row['level1_diag3']) == 250):
        df.loc[index, 'level1_diag3'] = 4
    elif (row['level1_diag3'] >= 800 and row['level1_diag3'] < 1000):
        df.loc[index, 'level1_diag3'] = 5
    elif (row['level1_diag3'] >= 710 and row['level1_diag3'] < 740):
        df.loc[index, 'level1_diag3'] = 6
    elif (row['level1_diag3'] >= 580 and row['level1_diag3'] < 630) or (np.floor(row['level1_diag3']) == 788):
        df.loc[index, 'level1_diag3'] = 7
    elif (row['level1_diag3'] >= 140 and row['level1_diag3'] < 240):
        df.loc[index, 'level1_diag3'] = 8
    else:
        df.loc[index, 'level1_diag3'] = 0

# %%
for index, row in df.iterrows():
    if (row['level2_diag1'] >= 390 and row['level2_diag1'] < 399):
        df.loc[index, 'level2_diag1'] = 1
    elif (row['level2_diag1'] >= 401 and row['level2_diag1'] < 415):
        df.loc[index, 'level2_diag1'] = 2
    elif (row['level2_diag1'] >= 415 and row['level2_diag1'] < 460):
        df.loc[index, 'level2_diag1'] = 3
    elif (np.floor(row['level2_diag1']) == 785):
        df.loc[index, 'level2_diag1'] = 4
    elif (row['level2_diag1'] >= 460 and row['level2_diag1'] < 489):
        df.loc[index, 'level2_diag1'] = 5
    elif (row['level2_diag1'] >= 490 and row['level2_diag1'] < 497):
        df.loc[index, 'level2_diag1'] = 6
    elif (row['level2_diag1'] >= 500 and row['level2_diag1'] < 520):
        df.loc[index, 'level2_diag1'] = 7
    elif (np.floor(row['level2_diag1']) == 786):
        df.loc[index, 'level2_diag1'] = 8
    elif (row['level2_diag1'] >= 520 and row['level2_diag1'] < 530):
        df.loc[index, 'level2_diag1'] = 9
    elif (row['level2_diag1'] >= 530 and row['level2_diag1'] < 544):
        df.loc[index, 'level2_diag1'] = 10
    elif (row['level2_diag1'] >= 550 and row['level2_diag1'] < 554):
        df.loc[index, 'level2_diag1'] = 11
    elif (row['level2_diag1'] >= 555 and row['level2_diag1'] < 580):
        df.loc[index, 'level2_diag1'] = 12
    elif (np.floor(row['level2_diag1']) == 787):
        df.loc[index, 'level2_diag1'] = 13
    elif (np.floor(row['level2_diag1']) == 250):
        df.loc[index, 'level2_diag1'] = 14
    elif (row['level2_diag1'] >= 800 and row['level2_diag1'] < 1000):
        df.loc[index, 'level2_diag1'] = 15
    elif (row['level2_diag1'] >= 710 and row['level2_diag1'] < 740):
        df.loc[index, 'level2_diag1'] = 16
    elif (row['level2_diag1'] >= 580 and row['level2_diag1'] < 630):
        df.loc[index, 'level2_diag1'] = 17
    elif (np.floor(row['level2_diag1']) == 788):
        df.loc[index, 'level2_diag1'] = 18
    elif (row['level2_diag1'] >= 140 and row['level2_diag1'] < 240):
        df.loc[index, 'level2_diag1'] = 19
    elif row['level2_diag1'] >= 240 and row['level2_diag1'] < 280 and (np.floor(row['level2_diag1']) != 250):
        df.loc[index, 'level2_diag1'] = 20
    elif (row['level2_diag1'] >= 680 and row['level2_diag1'] < 710) or (np.floor(row['level2_diag1']) == 782):
        df.loc[index, 'level2_diag1'] = 21
    elif (row['level2_diag1'] >= 290 and row['level2_diag1'] < 320):
        df.loc[index, 'level2_diag1'] = 22
    else:
        df.loc[index, 'level2_diag1'] = 0
        
    if (row['level2_diag2'] >= 390 and row['level2_diag2'] < 399):
        df.loc[index, 'level2_diag2'] = 1
    elif (row['level2_diag2'] >= 401 and row['level2_diag2'] < 415):
        df.loc[index, 'level2_diag2'] = 2
    elif (row['level2_diag2'] >= 415 and row['level2_diag2'] < 460):
        df.loc[index, 'level2_diag2'] = 3
    elif (np.floor(row['level2_diag2']) == 785):
        df.loc[index, 'level2_diag2'] = 4
    elif (row['level2_diag2'] >= 460 and row['level2_diag2'] < 489):
        df.loc[index, 'level2_diag2'] = 5
    elif (row['level2_diag2'] >= 490 and row['level2_diag2'] < 497):
        df.loc[index, 'level2_diag2'] = 6
    elif (row['level2_diag2'] >= 500 and row['level2_diag2'] < 520):
        df.loc[index, 'level2_diag2'] = 7
    elif (np.floor(row['level2_diag2']) == 786):
        df.loc[index, 'level2_diag2'] = 8
    elif (row['level2_diag2'] >= 520 and row['level2_diag2'] < 530):
        df.loc[index, 'level2_diag2'] = 9
    elif (row['level2_diag2'] >= 530 and row['level2_diag2'] < 544):
        df.loc[index, 'level2_diag2'] = 10
    elif (row['level2_diag2'] >= 550 and row['level2_diag2'] < 554):
        df.loc[index, 'level2_diag2'] = 11
    elif (row['level2_diag2'] >= 555 and row['level2_diag2'] < 580):
        df.loc[index, 'level2_diag2'] = 12
    elif (np.floor(row['level2_diag2']) == 787):
        df.loc[index, 'level2_diag2'] = 13
    elif (np.floor(row['level2_diag2']) == 250):
        df.loc[index, 'level2_diag2'] = 14
    elif (row['level2_diag2'] >= 800 and row['level2_diag2'] < 1000):
        df.loc[index, 'level2_diag2'] = 15
    elif (row['level2_diag2'] >= 710 and row['level2_diag2'] < 740):
        df.loc[index, 'level2_diag2'] = 16
    elif (row['level2_diag2'] >= 580 and row['level2_diag2'] < 630):
        df.loc[index, 'level2_diag2'] = 17
    elif (np.floor(row['level2_diag2']) == 788):
        df.loc[index, 'level2_diag2'] = 18
    elif (row['level2_diag2'] >= 140 and row['level2_diag2'] < 240):
        df.loc[index, 'level2_diag2'] = 19
    elif row['level2_diag2'] >= 240 and row['level2_diag2'] < 280 and (np.floor(row['level2_diag2']) != 250):
        df.loc[index, 'level2_diag2'] = 20
    elif (row['level2_diag2'] >= 680 and row['level2_diag2'] < 710) or (np.floor(row['level2_diag2']) == 782):
        df.loc[index, 'level2_diag2'] = 21
    elif (row['level2_diag2'] >= 290 and row['level2_diag2'] < 320):
        df.loc[index, 'level2_diag2'] = 22
    else:
        df.loc[index, 'level2_diag2'] = 0
        
        
    if (row['level2_diag3'] >= 390 and row['level2_diag3'] < 399):
        df.loc[index, 'level2_diag3'] = 1
    elif (row['level2_diag3'] >= 401 and row['level2_diag3'] < 415):
        df.loc[index, 'level2_diag3'] = 2
    elif (row['level2_diag3'] >= 415 and row['level2_diag3'] < 460):
        df.loc[index, 'level2_diag3'] = 3
    elif (np.floor(row['level2_diag3']) == 785):
        df.loc[index, 'level2_diag3'] = 4
    elif (row['level2_diag3'] >= 460 and row['level2_diag3'] < 489):
        df.loc[index, 'level2_diag3'] = 5
    elif (row['level2_diag3'] >= 490 and row['level2_diag3'] < 497):
        df.loc[index, 'level2_diag3'] = 6
    elif (row['level2_diag3'] >= 500 and row['level2_diag3'] < 520):
        df.loc[index, 'level2_diag3'] = 7
    elif (np.floor(row['level2_diag3']) == 786):
        df.loc[index, 'level2_diag3'] = 8
    elif (row['level2_diag3'] >= 520 and row['level2_diag3'] < 530):
        df.loc[index, 'level2_diag3'] = 9
    elif (row['level2_diag3'] >= 530 and row['level2_diag3'] < 544):
        df.loc[index, 'level2_diag3'] = 10
    elif (row['level2_diag3'] >= 550 and row['level2_diag3'] < 554):
        df.loc[index, 'level2_diag3'] = 11
    elif (row['level2_diag3'] >= 555 and row['level2_diag3'] < 580):
        df.loc[index, 'level2_diag3'] = 12
    elif (np.floor(row['level2_diag3']) == 787):
        df.loc[index, 'level2_diag3'] = 13
    elif (np.floor(row['level2_diag3']) == 250):
        df.loc[index, 'level2_diag3'] = 14
    elif (row['level2_diag3'] >= 800 and row['level2_diag3'] < 1000):
        df.loc[index, 'level2_diag3'] = 15
    elif (row['level2_diag3'] >= 710 and row['level2_diag3'] < 740):
        df.loc[index, 'level2_diag3'] = 16
    elif (row['level2_diag3'] >= 580 and row['level2_diag3'] < 630):
        df.loc[index, 'level2_diag3'] = 17
    elif (np.floor(row['level2_diag3']) == 788):
        df.loc[index, 'level2_diag3'] = 18
    elif (row['level2_diag3'] >= 140 and row['level2_diag3'] < 240):
        df.loc[index, 'level2_diag3'] = 19
    elif row['level2_diag3'] >= 240 and row['level2_diag3'] < 280 and (np.floor(row['level2_diag3']) != 250):
        df.loc[index, 'level2_diag3'] = 20
    elif (row['level2_diag3'] >= 680 and row['level2_diag3'] < 710) or (np.floor(row['level2_diag3']) == 782):
        df.loc[index, 'level2_diag3'] = 21
    elif (row['level2_diag3'] >= 290 and row['level2_diag3'] < 320):
        df.loc[index, 'level2_diag3'] = 22
    else:
        df.loc[index, 'level2_diag3'] = 0

# %%
#Data Visualization
# Distribution of Readmission 
sns.countplot(df['readmitted']).set_title('Distribution of Readmission')
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribution of Readmission')

# %%
#Time in Hospital VS. Readmission
fig = plt.figure(figsize=(13,7),)
ax=sns.kdeplot(df.loc[(df['readmitted'] == 0),'time_in_hospital'] , color='b',shade=True,label='Not Readmitted')
ax=sns.kdeplot(df.loc[(df['readmitted'] == 1),'time_in_hospital'] , color='r',shade=True, label='Readmitted')
ax.set(xlabel='Time in Hospital', ylabel='Frequency')
plt.title('Time in Hospital VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Time in Hospital VS. Readmission')

# %%
#Age of Patient VS. Readmission
fig = plt.figure(figsize=(15,10))
sns.countplot(y= df['age'], hue = df['readmitted']).set_title('Age of Patient VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Age of Patient VS. Readmission')

# %%
#race VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(y = df['race'], hue = df['readmitted'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='race'>

# %%
#Number of medication used VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.barplot(x = df['readmitted'], y = df['num_medications']).set_title("Number of medication used VS. Readmission")
# Out:
# Text(0.5, 1.0, 'Number of medication used VS. Readmission')

# %%
#Gender of Patient VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(df['gender'], hue = df['readmitted']).set_title("Gender of Patient VS. Readmission")
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gender of Patient VS. Readmission')

# %%
#Change of Medication VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(df['change'], hue = df['readmitted']).set_title('Change of Medication VS. Readmission')
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Change of Medication VS. Readmission')

# %%
#Diabetes Medication prescribed VS Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(df['diabetesMed'], hue = df['readmitted']).set_title('Diabetes Medication prescribed VS Readmission')
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Diabetes Medication prescribed VS Readmission')

# %%
#Service Utilization VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.barplot( y = df['service_utilization'], x = df['readmitted']).set_title('Service Utilization VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Service Utilization VS. Readmission')

# %%
#Glucose test serum test result VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(y = df['max_glu_serum'], hue = df['readmitted']).set_title('Glucose test serum test result VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Glucose test serum test result VS. Readmission')

# %%
#A1C test result VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(y= df['A1Cresult'], hue = df['readmitted']).set_title('A1C test result VS. Readmission')
# Out:
# Text(0.5, 1.0, 'A1C test result VS. Readmission')

# %%
#Number of lab procedure VS. Readmission
fig = plt.figure(figsize=(15,6),)
ax=sns.kdeplot(df.loc[(df['readmitted'] == 0),'num_lab_procedures'] , color='b',shade=True,label='Not readmitted')
ax=sns.kdeplot(df.loc[(df['readmitted'] == 1),'num_lab_procedures'] , color='r',shade=True, label='readmitted')
ax.set(xlabel='Number of lab procedure', ylabel='Frequency')
plt.title('Number of lab procedure VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Number of lab procedure VS. Readmission')

# %%
#Pre-Modeling Data Preprocessing
df['age'] = df['age'].astype('int64')
print(df.age.value_counts())
# convert age categories to mid-point values
age_dict = {1:5, 2:15, 3:25, 4:35, 5:45, 6:55, 7:65, 8:75, 9:85, 10:95}
df['age'] = df.age.map(age_dict)
print(df.age.value_counts())
# Out:
# 8     24784
# 7     21512
# 6     16530
# 9     16205
# 5      9199
# 4      3532
# 10     2591
# 3      1470
# 2       465
# 1        64
# Name: age, dtype: int64
# 75    24784
# 65    21512
# 55    16530
# 85    16205
# 45     9199
# 35     3532
# 95     2591
# 25     1470
# 15      465
# 5        64
# Name: age, dtype: int64

# %%
# convert data type of nominal features in dataframe to 'object' type
i = ['encounter_id', 'patient_nbr', 'gender', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id',\
          'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', \
          'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose','miglitol', \
          'troglitazone', 'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin', \
          'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed', \
          'age', 'A1Cresult', 'max_glu_serum', 'level1_diag1', 'level1_diag2', 'level1_diag3', 'level2_diag1', 'level2_diag2', 'level2_diag3']

df[i] = df[i].astype('object')

# %%
df.dtypes
# Out:
# encounter_id                object
# patient_nbr                 object
# race                        object
# gender                      object
# age                         object
# admission_type_id           object
# discharge_disposition_id    object
# admission_source_id         object
# time_in_hospital             int64
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                   int64
# service_utilization          int64
# numchange                    int64
# level1_diag1                object
# level2_diag1                object
# level1_diag2                object
# level2_diag2                object
# level1_diag3                object
# level2_diag3                object
# dtype: object

# %%
df['nummed'] = 0

for col in keys:
    df['nummed'] = df['nummed'] + df[col]
df['nummed'].value_counts()
# Out:
# 1    44539
# 0    22144
# 2    20878
# 3     7439
# 4     1290
# 5       57
# 6        5
# Name: nummed, dtype: int64

# %%
# get list of only numeric features
num_col = list(set(list(df._get_numeric_data().columns))- {'readmitted'})
num_col
# Out:
# ['number_inpatient',
#  'service_utilization',
#  'num_lab_procedures',
#  'number_emergency',
#  'time_in_hospital',
#  'number_diagnoses',
#  'numchange',
#  'num_procedures',
#  'number_outpatient',
#  'num_medications']

# %%
# Removing skewnewss and kurtosis using log transformation if it is above a threshold value -  2

statdataframe = pd.DataFrame()
statdataframe['numeric_column'] = num_col
skew_before = []
skew_after = []

kurt_before = []
kurt_after = []

standard_deviation_before = []
standard_deviation_after = []

log_transform_needed = []

log_type = []

for i in num_col:
    skewval = df[i].skew()
    skew_before.append(skewval)
    
    kurtval = df[i].kurtosis()
    kurt_before.append(kurtval)
    
    sdval = df[i].std()
    standard_deviation_before.append(sdval)
    
    if (abs(skewval) >2) & (abs(kurtval) >2):
        log_transform_needed.append('Yes')
        
        if len(df[df[i] == 0])/len(df) <=0.02:
            log_type.append('log')
            skewvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).skew()
            skew_after.append(skewvalnew)
            
            kurtvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).kurtosis()
            kurt_after.append(kurtvalnew)
            
            sdvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).std()
            standard_deviation_after.append(sdvalnew)
            
        else:
            log_type.append('log1p')
            skewvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).skew()
            skew_after.append(skewvalnew)
        
            kurtvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).kurtosis()
            kurt_after.append(kurtvalnew)
            
            sdvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).std()
            standard_deviation_after.append(sdvalnew)
            
    else:
        log_type.append('NA')
        log_transform_needed.append('No')
        
        skew_after.append(skewval)
        kurt_after.append(kurtval)
        standard_deviation_after.append(sdval)

statdataframe['skew_before'] = skew_before
statdataframe['kurtosis_before'] = kurt_before
statdataframe['standard_deviation_before'] = standard_deviation_before
statdataframe['log_transform_needed'] = log_transform_needed
statdataframe['log_type'] = log_type
statdataframe['skew_after'] = skew_after
statdataframe['kurtosis_after'] = kurt_after
statdataframe['standard_deviation_after'] = standard_deviation_after

# %%
statdataframe
# Out:
#         numeric_column  skew_before  kurtosis_before  \
# 0     number_inpatient     3.566745        20.046816
# 1  service_utilization     5.312668        67.186861
# 2   num_lab_procedures    -0.240602        -0.253321
# 3     number_emergency    22.690853      1164.432578
# 4     time_in_hospital     1.127237         0.837861
# 5     number_diagnoses    -0.809105        -0.380149
# 6            numchange     1.427227         1.454673
# 7       num_procedures     1.313315         0.856937
# 8    number_outpatient     8.770568       146.332546
# 9      num_medications     1.338507         3.542840
#
#    standard_deviation_before log_transform_needed log_type  skew_after  \
# 0                   1.270213                  Yes    log1p    1.425332
# 1                   2.316389                  Yes    log1p    1.097495
# 2                  19.655471                   No       NA   -0.240602
# 3                   0.948463                  Yes    log1p    3.614896
# 4                   2.982393                   No       NA    1.127237
# 5                   1.836415                   No       NA   -0.809105
# 6                   0.488526                   No       NA    1.427227
# 7                   1.702837                   No       NA    1.313315
# 8                   1.280134                  Yes    log1p    2.708537
# 9                   8.071928                   No       NA    1.338507
#
#    kurtosis_after  standard_deviation_after
# 0        1.320066                  0.513417
# 1        0.497783                  0.665716
# 2       -0.253321                 19.655471
# 3       15.856617                  0.318794
# 4        0.837861                  2.982393
# 5       -0.380149                  1.836415
# 6        1.454673                  0.488526
# 7        0.856937                  1.702837
# 8        7.648436                  0.432947
# 9        3.542840                  8.071928

# %%
# performing the log transformation for the columns determined to be needing it above.

for i in range(len(statdataframe)):
    if statdataframe['log_transform_needed'][i] == 'Yes':
        colname = str(statdataframe['numeric_column'][i])
        
        if statdataframe['log_type'][i] == 'log':
            df = df[df[colname] > 0]
            df[colname + "_log"] = np.log(df[colname])
            
        elif statdataframe['log_type'][i] == 'log1p':
            df = df[df[colname] >= 0]
            df[colname + "_log1p"] = np.log1p(df[colname])

# %%
df = df.drop(['number_outpatient', 'number_inpatient', 'number_emergency','service_utilization'], axis = 1)

# %%
df.shape
# Out:
# (96352, 54)

# %%
# get list of only numeric features
numerics = list(set(list(df._get_numeric_data().columns))- {'readmitted'})
numerics
# Out:
# ['service_utilization_log1p',
#  'num_lab_procedures',
#  'number_inpatient_log1p',
#  'time_in_hospital',
#  'number_diagnoses',
#  'numchange',
#  'num_procedures',
#  'number_outpatient_log1p',
#  'number_emergency_log1p',
#  'num_medications']

# %%
# show list of features that are categorical
df.encounter_id = df.encounter_id.astype('int64')
df.patient_nbr = df.patient_nbr.astype('int64')
df.diabetesMed = df.diabetesMed.astype('int64')
df.change = df.change.astype('int64')

# convert data type of nominal features in dataframe to 'object' type for aggregating
i = ['metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', \
          'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose','miglitol', \
          'troglitazone', 'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin', \
          'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone','A1Cresult']
df[i] = df[i].astype('int64')

df.dtypes
# Out:
# encounter_id                   int64
# patient_nbr                    int64
# race                          object
# gender                        object
# age                           object
# admission_type_id             object
# discharge_disposition_id      object
# admission_source_id           object
# time_in_hospital               int64
# num_lab_procedures             int64
# num_procedures                 int64
# num_medications                int64
# diag_1                        object
# diag_2                        object
# diag_3                        object
# number_diagnoses               int64
# max_glu_serum                 object
# A1Cresult                      int64
# metformin                      int64
# repaglinide                    int64
# nateglinide                    int64
# chlorpropamide                 int64
# glimepiride                    int64
# acetohexamide                  int64
# glipizide                      int64
# glyburide                      int64
# tolbutamide                    int64
# pioglitazone                   int64
# rosiglitazone                  int64
# acarbose                       int64
# miglitol                       int64
# troglitazone                   int64
# tolazamide                     int64
# insulin                        int64
# glyburide-metformin            int64
# glipizide-metformin            int64
# glimepiride-pioglitazone       int64
# metformin-rosiglitazone        int64
# metformin-pioglitazone         int64
# change                         int64
# diabetesMed                    int64
# readmitted                     int64
# numchange                      int64
# level1_diag1                  object
# level2_diag1                  object
# level1_diag2                  object
# level2_diag2                  object
# level1_diag3                  object
# level2_diag3                  object
# nummed                        object
# number_inpatient_log1p       float64
# service_utilization_log1p    float64
# number_emergency_log1p       float64
# number_outpatient_log1p      float64
# dtype: object

# %%
dfcopy = df.copy(deep = True)

# %%
df['readmitted'] = df['readmitted'].apply(lambda x: 0 if x == 2 else x)

# %%
# drop individual diagnosis columns that have too granular disease information
# also drop level 2 categorization (which was not comparable with any reference)
# also drop level 1 secondary and tertiary diagnoses
df.drop(['diag_1', 'diag_2', 'diag_3', 'level2_diag1', 'level1_diag2', 'level2_diag2', 'level1_diag3', 'level2_diag3'], axis=1, inplace=True)

# %%
interactionterms = [('num_medications','time_in_hospital'),
('num_medications','num_procedures'),
('time_in_hospital','num_lab_procedures'),
('num_medications','num_lab_procedures'),
('num_medications','number_diagnoses'),
('age','number_diagnoses'),
('change','num_medications'),
('number_diagnoses','time_in_hospital'),
('num_medications','numchange')]

# %%
for inter in interactionterms:
    name = inter[0] + '|' + inter[1]
    df[name] = df[inter[0]] * df[inter[1]]

# %%
df[['num_medications','time_in_hospital', 'num_medications|time_in_hospital']].head()
# Out:
#    num_medications  time_in_hospital  num_medications|time_in_hospital
# 1               18                 3                                54
# 2               13                 2                                26
# 3               16                 2                                32
# 4                8                 1                                 8
# 5               16                 3                                48

# %%
# Feature Scaling
datf = pd.DataFrame()
datf['features'] = numerics
datf['std_dev'] = datf['features'].apply(lambda x: df[x].std())
datf['mean'] = datf['features'].apply(lambda x: df[x].mean())

# %%
# dropping multiple encounters while keeping either first or last encounter of these patients
df2 = df.drop_duplicates(subset= ['patient_nbr'], keep = 'first')
df2.shape
# Out:
# (67528, 55)

# %%
# standardize function
def standardize(raw_data):
    return ((raw_data - np.mean(raw_data, axis = 0)) / np.std(raw_data, axis = 0))

# %%
df2[numerics] = standardize(df2[numerics])
import scipy as sp
df2 = df2[(np.abs(sp.stats.zscore(df2[numerics])) < 3).all(axis=1)]
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
from matplotlib.colors import ListedColormap
my_cmap = ListedColormap(sns.light_palette((250, 100, 50), input="husl", n_colors=50).as_hex())
table = df2.drop(['patient_nbr', 'encounter_id'], axis=1).corr(method='pearson')
table.style.background_gradient(cmap=my_cmap, axis = 0)
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\pandas\io\formats\style.py:1264: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\91944\anaconda3\lib\site-packages\pandas\io\formats\style.py:1265: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# #T_afa4d_row0_col0,#T_afa4d_row1_col1,#T_afa4d_row2_col2,#T_afa4d_row3_col3,#T_afa4d_row4_col4,#T_afa4d_row5_col5,#T_afa4d_row6_col6,#T_afa4d_row7_col7,#T_afa4d_row8_col8,#T_afa4d_row9_col9,#T_afa4d_row10_col10,#T_afa4d_row12_col12,#T_afa4d_row13_col13,#T_afa4d_row14_col14,#T_afa4d_row15_col15,#T_afa4d_row16_col16,#T_afa4d_row17_col17,#T_afa4d_row18_col18,#T_afa4d_row19_col19,#T_afa4d_row20_col20,#T_afa4d_row21_col21,#T_afa4d_row22_col22,#T_afa4d_row23_col23,#T_afa4d_row26_col26,#T_afa4d_row27_col27,#T_afa4d_row28_col28,#T_afa4d_row29_col29,#T_afa4d_row30_col30,#T_afa4d_row31_col31,#T_afa4d_row32_col32,#T_afa4d_row33_col33,#T_afa4d_row34_col34,#T_afa4d_row35_col35,#T_afa4d_row36_col36,#T_afa4d_row37_col37,#T_afa4d_row38_col38,#T_afa4d_row39_col39,#T_afa4d_row40_col40,#T_afa4d_row41_col41,#T_afa4d_row42_col42{
#             background-color:  #007ad1;
#             color:  #f1f1f1;
#         }#T_afa4d_row0_col1,#T_afa4d_row1_col41,#T_afa4d_row28_col6,#T_afa4d_row40_col6,#T_afa4d_row41_col1{
#             background-color:  #9dc8e7;
#             color:  #000000;
#         }#T_afa4d_row0_col2,#T_afa4d_row1_col4,#T_afa4d_row2_col41,#T_afa4d_row4_col1,#T_afa4d_row5_col38,#T_afa4d_row12_col40,#T_afa4d_row13_col6,#T_afa4d_row16_col40,#T_afa4d_row21_col3,#T_afa4d_row21_col38,#T_afa4d_row27_col38,#T_afa4d_row28_col3,#T_afa4d_row28_col10,#T_afa4d_row30_col3,#T_afa4d_row30_col35,#T_afa4d_row30_col37,#T_afa4d_row30_col39,#T_afa4d_row35_col30,#T_afa4d_row37_col2,#T_afa4d_row38_col27,#T_afa4d_row40_col4,#T_afa4d_row40_col10,#T_afa4d_row41_col2,#T_afa4d_row42_col1{
#             background-color:  #c4dbec;
#             color:  #000000;
#         }#T_afa4d_row0_col3,#T_afa4d_row3_col0,#T_afa4d_row3_col37,#T_afa4d_row21_col30,#T_afa4d_row28_col40,#T_afa4d_row37_col3,#T_afa4d_row40_col28,#T_afa4d_row42_col21{
#             background-color:  #85bbe4;
#             color:  #000000;
#         }#T_afa4d_row0_col4,#T_afa4d_row1_col39,#T_afa4d_row2_col35,#T_afa4d_row3_col1,#T_afa4d_row27_col15,#T_afa4d_row27_col16,#T_afa4d_row36_col40,#T_afa4d_row37_col4,#T_afa4d_row40_col12,#T_afa4d_row40_col37,#T_afa4d_row40_col41,#T_afa4d_row42_col37,#T_afa4d_row42_col41{
#             background-color:  #b1d1ea;
#             color:  #000000;
#         }#T_afa4d_row0_col5,#T_afa4d_row0_col12,#T_afa4d_row0_col27,#T_afa4d_row1_col12,#T_afa4d_row1_col13,#T_afa4d_row2_col12,#T_afa4d_row2_col13,#T_afa4d_row2_col40,#T_afa4d_row3_col10,#T_afa4d_row3_col16,#T_afa4d_row4_col2,#T_afa4d_row5_col6,#T_afa4d_row5_col12,#T_afa4d_row5_col13,#T_afa4d_row5_col27,#T_afa4d_row5_col42,#T_afa4d_row6_col10,#T_afa4d_row6_col15,#T_afa4d_row10_col6,#T_afa4d_row10_col15,#T_afa4d_row12_col15,#T_afa4d_row15_col6,#T_afa4d_row15_col10,#T_afa4d_row15_col13,#T_afa4d_row16_col10,#T_afa4d_row17_col13,#T_afa4d_row18_col12,#T_afa4d_row23_col13,#T_afa4d_row27_col0,#T_afa4d_row27_col1,#T_afa4d_row27_col4,#T_afa4d_row28_col5,#T_afa4d_row29_col4,#T_afa4d_row29_col12,#T_afa4d_row29_col13,#T_afa4d_row30_col12,#T_afa4d_row30_col13,#T_afa4d_row31_col4,#T_afa4d_row31_col12,#T_afa4d_row31_col33,#T_afa4d_row32_col12,#T_afa4d_row32_col13,#T_afa4d_row33_col4,#T_afa4d_row33_col12,#T_afa4d_row33_col21,#T_afa4d_row33_col31,#T_afa4d_row34_col12,#T_afa4d_row34_col13,#T_afa4d_row35_col5,#T_afa4d_row36_col12,#T_afa4d_row36_col13,#T_afa4d_row37_col12,#T_afa4d_row37_col13,#T_afa4d_row37_col27,#T_afa4d_row39_col10,#T_afa4d_row39_col15,#T_afa4d_row39_col16,#T_afa4d_row39_col32,#T_afa4d_row41_col5,#T_afa4d_row41_col12,#T_afa4d_row41_col13,#T_afa4d_row41_col27,#T_afa4d_row42_col12,#T_afa4d_row42_col13{
#             background-color:  #d7e5ef;
#             color:  #000000;
#         }#T_afa4d_row0_col6,#T_afa4d_row0_col7,#T_afa4d_row0_col15,#T_afa4d_row0_col32,#T_afa4d_row1_col15,#T_afa4d_row1_col16,#T_afa4d_row1_col28,#T_afa4d_row1_col32,#T_afa4d_row3_col7,#T_afa4d_row3_col8,#T_afa4d_row3_col29,#T_afa4d_row4_col5,#T_afa4d_row4_col7,#T_afa4d_row4_col16,#T_afa4d_row4_col27,#T_afa4d_row4_col29,#T_afa4d_row6_col21,#T_afa4d_row6_col32,#T_afa4d_row7_col0,#T_afa4d_row7_col1,#T_afa4d_row7_col2,#T_afa4d_row7_col30,#T_afa4d_row7_col31,#T_afa4d_row7_col32,#T_afa4d_row7_col37,#T_afa4d_row7_col39,#T_afa4d_row7_col42,#T_afa4d_row8_col1,#T_afa4d_row8_col2,#T_afa4d_row8_col5,#T_afa4d_row8_col31,#T_afa4d_row8_col32,#T_afa4d_row8_col34,#T_afa4d_row8_col41,#T_afa4d_row9_col1,#T_afa4d_row9_col2,#T_afa4d_row9_col4,#T_afa4d_row9_col5,#T_afa4d_row9_col6,#T_afa4d_row9_col15,#T_afa4d_row9_col21,#T_afa4d_row9_col31,#T_afa4d_row9_col32,#T_afa4d_row10_col2,#T_afa4d_row10_col3,#T_afa4d_row10_col31,#T_afa4d_row10_col32,#T_afa4d_row10_col39,#T_afa4d_row10_col41,#T_afa4d_row12_col0,#T_afa4d_row12_col2,#T_afa4d_row12_col3,#T_afa4d_row12_col4,#T_afa4d_row12_col5,#T_afa4d_row12_col21,#T_afa4d_row12_col31,#T_afa4d_row12_col32,#T_afa4d_row12_col34,#T_afa4d_row12_col37,#T_afa4d_row12_col38,#T_afa4d_row12_col39,#T_afa4d_row13_col0,#T_afa4d_row13_col1,#T_afa4d_row13_col2,#T_afa4d_row13_col3,#T_afa4d_row13_col4,#T_afa4d_row13_col5,#T_afa4d_row13_col31,#T_afa4d_row13_col32,#T_afa4d_row13_col34,#T_afa4d_row13_col37,#T_afa4d_row13_col41,#T_afa4d_row14_col1,#T_afa4d_row14_col2,#T_afa4d_row14_col5,#T_afa4d_row14_col6,#T_afa4d_row14_col15,#T_afa4d_row14_col16,#T_afa4d_row14_col21,#T_afa4d_row14_col31,#T_afa4d_row14_col32,#T_afa4d_row15_col5,#T_afa4d_row15_col8,#T_afa4d_row15_col22,#T_afa4d_row15_col33,#T_afa4d_row15_col34,#T_afa4d_row15_col36,#T_afa4d_row15_col42,#T_afa4d_row16_col3,#T_afa4d_row16_col5,#T_afa4d_row16_col7,#T_afa4d_row16_col8,#T_afa4d_row16_col31,#T_afa4d_row16_col32,#T_afa4d_row16_col34,#T_afa4d_row16_col39,#T_afa4d_row17_col1,#T_afa4d_row17_col2,#T_afa4d_row17_col5,#T_afa4d_row17_col7,#T_afa4d_row17_col21,#T_afa4d_row17_col28,#T_afa4d_row17_col32,#T_afa4d_row17_col34,#T_afa4d_row17_col40,#T_afa4d_row18_col1,#T_afa4d_row18_col2,#T_afa4d_row18_col5,#T_afa4d_row18_col7,#T_afa4d_row18_col31,#T_afa4d_row18_col32,#T_afa4d_row18_col33,#T_afa4d_row18_col34,#T_afa4d_row19_col1,#T_afa4d_row19_col2,#T_afa4d_row19_col5,#T_afa4d_row19_col31,#T_afa4d_row19_col32,#T_afa4d_row19_col37,#T_afa4d_row19_col41,#T_afa4d_row20_col1,#T_afa4d_row20_col2,#T_afa4d_row20_col4,#T_afa4d_row20_col5,#T_afa4d_row20_col21,#T_afa4d_row20_col32,#T_afa4d_row21_col2,#T_afa4d_row21_col6,#T_afa4d_row22_col2,#T_afa4d_row22_col5,#T_afa4d_row22_col6,#T_afa4d_row22_col32,#T_afa4d_row22_col40,#T_afa4d_row23_col1,#T_afa4d_row23_col2,#T_afa4d_row23_col5,#T_afa4d_row23_col32,#T_afa4d_row23_col34,#T_afa4d_row26_col1,#T_afa4d_row26_col2,#T_afa4d_row26_col5,#T_afa4d_row26_col31,#T_afa4d_row26_col32,#T_afa4d_row27_col17,#T_afa4d_row27_col31,#T_afa4d_row29_col2,#T_afa4d_row29_col3,#T_afa4d_row29_col5,#T_afa4d_row29_col6,#T_afa4d_row29_col15,#T_afa4d_row29_col28,#T_afa4d_row29_col34,#T_afa4d_row29_col35,#T_afa4d_row29_col38,#T_afa4d_row29_col39,#T_afa4d_row30_col2,#T_afa4d_row30_col7,#T_afa4d_row30_col31,#T_afa4d_row30_col34,#T_afa4d_row31_col2,#T_afa4d_row31_col6,#T_afa4d_row31_col29,#T_afa4d_row31_col35,#T_afa4d_row31_col38,#T_afa4d_row31_col39,#T_afa4d_row32_col1,#T_afa4d_row32_col3,#T_afa4d_row32_col27,#T_afa4d_row32_col28,#T_afa4d_row32_col29,#T_afa4d_row32_col30,#T_afa4d_row32_col40,#T_afa4d_row32_col42,#T_afa4d_row33_col1,#T_afa4d_row33_col27,#T_afa4d_row33_col28,#T_afa4d_row33_col30,#T_afa4d_row33_col41,#T_afa4d_row33_col42,#T_afa4d_row34_col27,#T_afa4d_row34_col28,#T_afa4d_row34_col39,#T_afa4d_row35_col7,#T_afa4d_row36_col5,#T_afa4d_row36_col6,#T_afa4d_row36_col31,#T_afa4d_row37_col7,#T_afa4d_row37_col15,#T_afa4d_row37_col16,#T_afa4d_row37_col29,#T_afa4d_row37_col32,#T_afa4d_row38_col7,#T_afa4d_row38_col29,#T_afa4d_row38_col33,#T_afa4d_row39_col7,#T_afa4d_row39_col8,#T ...
#             background-color:  #e6ecf1;
#             color:  #000000;
#         }#T_afa4d_row0_col8,#T_afa4d_row0_col22,#T_afa4d_row0_col33,#T_afa4d_row1_col6,#T_afa4d_row1_col7,

# %%
df2['level1_diag1'] = df2['level1_diag1'].astype('object')
df_pd = pd.get_dummies(df2, columns=['gender', 'admission_type_id', 'discharge_disposition_id',
                                      'admission_source_id', 'max_glu_serum', 'A1Cresult', 'level1_diag1'], drop_first = True)
just_dummies = pd.get_dummies(df_pd['race'])
df_pd = pd.concat([df_pd, just_dummies], axis=1)      
df_pd.drop(['race'], inplace=True, axis=1)
df
# Out:
#         encounter_id  patient_nbr             race gender age  \
# 1             149190     55629189        Caucasian      0  15
# 2              64410     86047875  AfricanAmerican      0  25
# 3             500364     82442376        Caucasian      1  35
# 4              16680     42519267        Caucasian      1  45
# 5              35754     82637451        Caucasian      1  55
# ...              ...          ...              ...    ...  ..
# 101661     442558928     87326991        Caucasian      0  85
# 101662     442561946     97892019  AfricanAmerican      1  55
# 101663     442569986    146138783         Hispanic      0  55
# 101664     442573442     41262156        Caucasian      1  55
# 101665     442573472    132950534        Caucasian      0  55
#
#        admission_type_id discharge_disposition_id admission_source_id  \
# 1                      1                        1                   7
# 2                      1                        1                   7
# 3                      1                        1                   7
# 4                      1                        1                   7
# 5                      1                        1                   1
# ...                  ...                      ...                 ...
# 101661                 1                        1                   7
# 101662                 1                        1                   7
# 101663                 1                        1                   7
# 101664                 1                        1                   7
# 101665                 3                        1                   1
#
#         time_in_hospital  num_lab_procedures  ...  number_outpatient_log1p  \
# 1                      3                  59  ...                 0.000000
# 2                      2                  11  ...                 1.098612
# 3                      2                  44  ...                 0.000000
# 4                      1                  51  ...                 0.000000
# 5                      3                  31  ...                 0.000000
# ...                  ...                 ...  ...                      ...
# 101661                 4                  66  ...                 0.000000
# 101662                 6                  49  ...                 0.000000
# 101663                 3                  11  ...                 0.000000
# 101664                 4                  51  ...                 0.000000
# 101665                 3                  25  ...                 0.000000
#
#         num_medications|time_in_hospital  num_medications|num_procedures  \
# 1                                     54                               0
# 2                                     26                              65
# 3                                     32                              16
# 4                                      8                               0
# 5                                     48                              96
# ...                                  ...                             ...
# 101661                                56                               0
# 101662                                54                               9
# 101663                                24                               8
# 101664                                36                               0
# 101665                                42                              14
#
#        time_in_hospital|num_lab_procedures  \
# 1                                      177
# 2                                       22
# 3                                       88
# 4                                       51
# 5                                       93
# ...                                    ...
# 101661                                 264
# 101662                                 294
# 101663                                  33
# 101664                                 204
# 101665                                  75
#
#         num_medications|num_lab_procedures  num_medications|number_diagnoses  \
# 1                                     1062                               162
# 2                                      143                                78
# 3                                      704                               112
# 4                                      408                                40
# 5                                      496                               144
# ...                                    ...                               ...
# 101661                                 924                               112
# 101662                                 441                                54
# 101663                                  88                                40
# 101664                                 459                                63
# 101665                                 350                               126
#
#         age|number_diagnoses  change|num_medications  \
# 1                        135                      18
# 2                        150                       0
# 3                        245                      16
# 4                        225                       8
# 5                        495                       0
# ...                      ...                     ...
# 101661                   680                       0
# 101662                   330                       0
# 101663                   275                       8
# 101664                   385                       0
# 101665                   495                       0
#
#         number_diagnoses|time_in_hospital  num_medications|numchange
# 1                                      27                         18
# 2                                      12                          0
# 3                                      14                         16
# 4                                       5                          0
# 5                                      27                          0
# ...                                   ...                        ...
# 101661                                 32                          0
# 101662                                 36                          0
# 101663                                 15                          0
# 101664                                 28                          0
# 101665                                 27                          0
#
# [96352 rows x 55 columns]

# %%
non_num_cols = ['race', 'gender', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'max_glu_serum', 'A1Cresult', 'level1_diag1' ]

# %%
num_cols = list(set(list(df._get_numeric_data().columns))- {'readmitted', 'change'})
num_cols
# Out:
# ['num_medications|numchange',
#  'insulin',
#  'metformin-rosiglitazone',
#  'num_medications|num_procedures',
#  'tolazamide',
#  'number_diagnoses',
#  'num_medications|time_in_hospital',
#  'num_procedures',
#  'repaglinide',
#  'num_medications',
#  'service_utilization_log1p',
#  'metformin-pioglitazone',
#  'num_medications|number_diagnoses',
#  'glimepiride',
#  'encounter_id',
#  'num_lab_procedures',
#  'number_inpatient_log1p',
#  'time_in_hospital',
#  'number_diagnoses|time_in_hospital',
#  'acetohexamide',
#  'rosiglitazone',
#  'numchange',
#  'number_emergency_log1p',
#  'diabetesMed',
#  'glipizide-metformin',
#  'patient_nbr',
#  'chlorpropamide',
#  'glyburide',
#  'time_in_hospital|num_lab_procedures',
#  'glipizide',
#  'miglitol',
#  'acarbose',
#  'glyburide-metformin',
#  'change|num_medications',
#  'troglitazone',
#  'pioglitazone',
#  'nateglinide',
#  'metformin',
#  'num_medications|num_lab_procedures',
#  'A1Cresult',
#  'tolbutamide',
#  'glimepiride-pioglitazone',
#  'number_outpatient_log1p']

# %%
new_non_num_cols = []
for i in non_num_cols:
    for j in df_pd.columns:
        if i in j:
            new_non_num_cols.append(j)

# %%
new_non_num_cols
# Out:
# ['gender_1',
#  'admission_type_id_3',
#  'admission_type_id_4',
#  'admission_type_id_5',
#  'discharge_disposition_id_2',
#  'discharge_disposition_id_7',
#  'discharge_disposition_id_10',
#  'discharge_disposition_id_18',
#  'discharge_disposition_id_19',
#  'discharge_disposition_id_20',
#  'discharge_disposition_id_27',
#  'discharge_disposition_id_28',
#  'admission_source_id_4',
#  'admission_source_id_7',
#  'admission_source_id_8',
#  'admission_source_id_9',
#  'admission_source_id_11',
#  'max_glu_serum_0',
#  'max_glu_serum_1',
#  'A1Cresult_0',
#  'A1Cresult_1',
#  'level1_diag1_1.0',
#  'level1_diag1_2.0',
#  'level1_diag1_3.0',
#  'level1_diag1_4.0',
#  'level1_diag1_5.0',
#  'level1_diag1_6.0',
#  'level1_diag1_7.0',
#  'level1_diag1_8.0']

# %%
l = []
for feature in list(df_pd.columns):
    if '|' in feature:
        l.append(feature)
l
# Out:
# ['num_medications|time_in_hospital',
#  'num_medications|num_procedures',
#  'time_in_hospital|num_lab_procedures',
#  'num_medications|num_lab_procedures',
#  'num_medications|number_diagnoses',
#  'age|number_diagnoses',
#  'change|num_medications',
#  'number_diagnoses|time_in_hospital',
#  'num_medications|numchange']

# %%
df_pd.head().T
# Out:
#                            1         2         3         4         5
# encounter_id          149190     64410    500364     16680     35754
# patient_nbr         55629189  86047875  82442376  42519267  82637451
# age                       15        25        35        45        55
# time_in_hospital   -0.444771 -0.784051 -0.784051 -1.123332 -0.444771
# num_lab_procedures  0.803836 -1.602187  0.051954  0.402832 -0.599677
# ...                      ...       ...       ...       ...       ...
# AfricanAmerican            0         1         0         0         0
# Asian                      0         0         0         0         0
# Caucasian                  1         0         1         1         1
# Hispanic                   0         0         0         0         0
# Other                      0         0         0         0         0
#
# [81 rows x 5 columns]

# %%
feature_set = ['age', 'time_in_hospital', 'num_procedures', 'num_medications', 'number_outpatient_log1p', 
                 'number_emergency_log1p', 'number_inpatient_log1p', 'number_diagnoses', 'metformin', 
                 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 'glyburide',
                 'pioglitazone', 'rosiglitazone', 'acarbose', 'tolazamide', 'insulin', 'glyburide-metformin',
                 'AfricanAmerican', 'Asian', 'Caucasian', 'Hispanic', 'Other', 'gender_1', 
                 'admission_type_id_3', 'admission_type_id_5', 'discharge_disposition_id_2', 'discharge_disposition_id_7', 
                 'discharge_disposition_id_10', 'discharge_disposition_id_18', 'admission_source_id_4',
                 'admission_source_id_7', 'admission_source_id_9', 'max_glu_serum_0', 'max_glu_serum_1', 'A1Cresult_0',
                 'A1Cresult_1', 'num_medications|time_in_hospital', 'num_medications|num_procedures',
                 'time_in_hospital|num_lab_procedures', 'num_medications|num_lab_procedures', 'num_medications|number_diagnoses',
                 'age|number_diagnoses', 'change|num_medications', 'number_diagnoses|time_in_hospital',
                 'num_medications|numchange', 'level1_diag1_1.0', 'level1_diag1_2.0', 'level1_diag1_3.0', 'level1_diag1_4.0',
                 'level1_diag1_5.0','level1_diag1_6.0', 'level1_diag1_7.0', 'level1_diag1_8.0']

# %%
X = df_pd[feature_set]
y = df_pd['readmitted']

# %%
df_pd['readmitted'].value_counts()
# Out:
# 0    54593
# 1     5070
# Name: readmitted, dtype: int64

# %%
#TRAINING - LOGIT
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
logit = LogisticRegression(fit_intercept=True)
logit.fit(X_train, y_train)
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#VALIDATION
#cross validation
from sklearn.model_selection import cross_val_score,KFold
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
kf=KFold(n_splits=5)
score=cross_val_score(logreg,X_train,y_train,cv=kf)
print("Cross Validation Scores are {}".format(score))
print("Average Cross Validation score :{}".format(score.mean()))
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross Validation Scores are [0.91514771 0.91535722 0.91399539 0.9168238  0.91430966]
# Average Cross Validation score :0.9151267546616385
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#TESTING
logit_pred = logit.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
# Out:
# Predict     0   All
# Actual
# 0        1466  1466
# 1         166   166
# All      1632  1632

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))
# Out:
# Accuracy is 0.91
# Precision is 0.00
# Recall is 0.00

# %%
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE
from collections import Counter
print('Original dataset shape {}'.format(Counter(y_train)))
sm = SMOTE(random_state=20)
train_input_new, train_output_new = sm.fit_resample(X_train, y_train)
print('New dataset shape {}'.format(Counter(train_output_new)))
# Out:
# Original dataset shape Counter({0: 43685, 1: 4045})
# New dataset shape Counter({1: 43685, 0: 43685})

# %%
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
logit = LogisticRegression(fit_intercept=True)
logit.fit(X_train, y_train)
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='warn',
          n_jobs=None, penalty='l1', random_state=None, solver='warn',
          tol=0.0001, verbose=0, warm_start=False)
# Out:
# LogisticRegression(multi_class='warn', penalty='l1', solver='warn')

# %%
logit_pred = logit.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
# Out:
# Predict     0     1   All
# Actual
# 0        1690  1469  3159
# 1         161   130   291
# All      1851  1599  3450

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))

accuracy_logit = accuracy_score(y_test, logit_pred)
precision_logit = precision_score(y_test, logit_pred)
recall_logit = recall_score(y_test, logit_pred)
# Out:
# Accuracy is 0.75
# Precision is 0.77
# Recall is 0.73

# %%
feature_set_no_int = ['age', 'time_in_hospital', 'num_procedures', 'num_medications', 'number_outpatient_log1p', 
                 'number_emergency_log1p', 'number_inpatient_log1p', 'number_diagnoses', 'metformin', 
                 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 
                 'glyburide', 'pioglitazone', 'rosiglitazone', 'acarbose', 
                 'tolazamide', 'insulin', 'glyburide-metformin',
                 'AfricanAmerican', 'Asian', 'Caucasian', 
                 'Hispanic', 'Other', 'gender_1', 
                 'admission_type_id_3', 'admission_type_id_5', 
                 'discharge_disposition_id_2', 'discharge_disposition_id_7', 
                 'discharge_disposition_id_10', 'discharge_disposition_id_18', 
                 'admission_source_id_4', 'admission_source_id_7', 
                 'admission_source_id_9', 'max_glu_serum_0', 
                 'max_glu_serum_1', 'A1Cresult_0', 'A1Cresult_1', 
                 'level1_diag1_1.0',
                 'level1_diag1_2.0',
                 'level1_diag1_3.0',
                 'level1_diag1_4.0',
                 'level1_diag1_5.0',
                 'level1_diag1_6.0',
                 'level1_diag1_7.0',
                 'level1_diag1_8.0']

# %%
X = df_pd[feature_set_no_int]
y = df_pd['readmitted']
df_pd['readmitted'].value_counts()
# Out:
# 0    54593
# 1     5070
# Name: readmitted, dtype: int64

# %%
print('Original dataset shape {}'.format(Counter(y)))
smt = SMOTE(random_state=20)
train_input_new, train_output_new = smt.fit_resample(X, y)
print('New dataset shape {}'.format(Counter(train_output_new)))
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
# Out:
# Original dataset shape Counter({0: 54593, 1: 5070})
# New dataset shape Counter({0: 54593, 1: 54593})

# %%
#TRAINING - DECISION TREE
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=28, criterion = "entropy", min_samples_split=10)
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=28, min_samples_split=10)

# %%
#VALIDATION
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold, cross_val_score
clf = DecisionTreeClassifier(random_state=42)
k_folds = KFold(n_splits = 5)
scores = cross_val_score(clf, X_train, y_train, cv = k_folds)
print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.88986835 0.89009731 0.88780767 0.89426985 0.89266701]
# Average CV Score:  0.8909420370562058
# Number of CV Scores used in Average:  5

# %%
#TESTING
dtree_pred = dtree.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(dtree_pred, name = 'Predict'), margins = True)
# Out:
# Predict     0     1   All
# Actual
# 0        2066  1907  3973
# 1         218   202   420
# All      2284  2109  4393

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, dtree_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, dtree_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, dtree_pred)))

accuracy_dtree = accuracy_score(y_test, dtree_pred)
precision_dtree = precision_score(y_test, dtree_pred)
recall_dtree = recall_score(y_test, dtree_pred)
# Out:
# Accuracy is 0.90
# Precision is 0.92
# Recall is 0.87

# %%
feature_set_no_int = ['age', 'time_in_hospital', 'num_procedures', 'num_medications', 'number_outpatient_log1p', 
                 'number_emergency_log1p', 'number_inpatient_log1p', 'number_diagnoses', 'metformin', 
                 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 
                 'glyburide', 'pioglitazone', 'rosiglitazone', 'acarbose', 
                 'tolazamide', 'insulin', 'glyburide-metformin',
                 'AfricanAmerican', 'Asian', 'Caucasian', 
                 'Hispanic', 'Other', 'gender_1', 
                 'admission_type_id_3', 'admission_type_id_5', 
                 'discharge_disposition_id_2', 'discharge_disposition_id_7', 
                 'discharge_disposition_id_10', 'discharge_disposition_id_18', 
                 'admission_source_id_4', 'admission_source_id_7', 
                 'admission_source_id_9', 'max_glu_serum_0', 
                 'max_glu_serum_1', 'A1Cresult_0', 'A1Cresult_1', 
                 'level1_diag1_1.0',
                 'level1_diag1_2.0',
                 'level1_diag1_3.0',
                 'level1_diag1_4.0',
                 'level1_diag1_5.0',
                 'level1_diag1_6.0',
                 'level1_diag1_7.0',
                 'level1_diag1_8.0']

# %%
X = df_pd[feature_set_no_int]
y = df_pd['readmitted']
df_pd['readmitted'].value_counts()
# Out:
# 0    54593
# 1     5070
# Name: readmitted, dtype: int64

# %%
print('Original dataset shape {}'.format(Counter(y)))
smt = SMOTE(random_state=20)
train_input_new, train_output_new = smt.fit_resample(X, y)
print('New dataset shape {}'.format(Counter(train_output_new)))
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
# Out:
# Original dataset shape Counter({0: 54593, 1: 5070})
# New dataset shape Counter({0: 54593, 1: 54593})

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=28, criterion = "entropy", min_samples_split=10)
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=28, min_samples_split=10)

# %%
dtree_pred = dtree.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(dtree_pred, name = 'Predict'), margins = True)
# Out:
# Predict     0     1   All
# Actual
# 0        2068  1905  3973
# 1         217   203   420
# All      2285  2108  4393

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, dtree_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, dtree_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, dtree_pred)))

accuracy_dtree = accuracy_score(y_test, dtree_pred)
precision_dtree = precision_score(y_test, dtree_pred)
recall_dtree = recall_score(y_test, dtree_pred)
# Out:
# Accuracy is 0.90
# Precision is 0.92
# Recall is 0.87

# %%
# Create list of top most features based on importance
feature_names = X_train.columns
feature_imports = dtree.feature_importances_
most_imp_features = pd.DataFrame([f for f in zip(feature_names,feature_imports)], columns=["Feature", "Importance"]).nlargest(10, "Importance")
most_imp_features.sort_values(by="Importance", inplace=True)
print(most_imp_features)
plt.figure(figsize=(10,6))
plt.barh(range(len(most_imp_features)), most_imp_features.Importance, align='center', alpha=0.8)
plt.yticks(range(len(most_imp_features)), most_imp_features.Feature, fontsize=14)
plt.xlabel('Importance')
plt.title('Most important features - Decision Tree')
plt.show()
# Out:
#                        Feature  Importance
# 19                     insulin    0.008722
# 34       admission_source_id_7    0.008854
# 4      number_outpatient_log1p    0.008981
# 29  discharge_disposition_id_2    0.009030
# 26                    gender_1    0.010013
# 0                          age    0.031332
# 7             number_diagnoses    0.068002
# 2               num_procedures    0.073052
# 3              num_medications    0.091641
# 1             time_in_hospital    0.560665

# %%
X = df_pd[feature_set_no_int]
y = df_pd['readmitted']

print('Original dataset shape {}'.format(Counter(y)))
smt = SMOTE(random_state=20)
train_input_new, train_output_new = smt.fit_resample(X, y)
print('New dataset shape {}'.format(Counter(train_output_new)))
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
# Out:
# Original dataset shape Counter({0: 54593, 1: 5070})
# New dataset shape Counter({0: 54593, 1: 54593})

# %%
#TRAINING - RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
rm = RandomForestClassifier(n_estimators = 10, max_depth=25, criterion = "gini", min_samples_split=10)
rm.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=25, min_samples_split=10, n_estimators=10)

# %%
#VALIDATION - RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, cross_val_score
clf = RandomForestClassifier()
k_folds = KFold(n_splits = 5)
scores = cross_val_score(clf, X_train, y_train, cv = k_folds)
print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.93749284 0.93308529 0.93720664 0.93622989 0.93737478]
# Average CV Score:  0.9362778890059659
# Number of CV Scores used in Average:  5

# %%
#TESTING - RANDOM FOREST
rm_prd = rm.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(rm_prd, name = 'Predict'), margins = True)
# Out:
# Predict     0     1   All
# Actual
# 0        1976  1997  3973
# 1         203   217   420
# All      2179  2214  4393

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, rm_prd)))
print("Precision is {0:.2f}".format(precision_score(y_test, rm_prd)))
print("Recall is {0:.2f}".format(recall_score(y_test, rm_prd)))

accuracy_rm = accuracy_score(y_test, rm_prd)
precision_rm = precision_score(y_test, rm_prd)
recall_rm = recall_score(y_test, rm_prd)
# Out:
# Accuracy is 0.89
# Precision is 0.88
# Recall is 0.89

# %%
# Create list of top most features based on importance
feature_names = X_train.columns
feature_imports = rm.feature_importances_
most_imp_features = pd.DataFrame([f for f in zip(feature_names,feature_imports)], columns=["Feature", "Importance"]).nlargest(10, "Importance")
most_imp_features.sort_values(by="Importance", inplace=True)
plt.figure(figsize=(10,6))
plt.barh(range(len(most_imp_features)), most_imp_features.Importance, align='center', alpha=0.8)
plt.yticks(range(len(most_imp_features)), most_imp_features.Feature, fontsize=14)
plt.xlabel('Importance')
plt.title('Most important features - Random Forest ')
plt.show()

# %%
plt.figure(figsize=(14, 7))
ax = plt.subplot(111)

models = ['Logistic Regression', 'Decision Tree', 'Random Forests']
values = [accuracy_logit, accuracy_dtree, accuracy_rm]
model = np.arange(len(models))

plt.bar(model, values, align='center', width = 0.15, alpha=0.7, color = 'red', label= 'accuracy')
plt.xticks(model, models)
           

           
ax = plt.subplot(111)

models = ['Logistic Regression', 'Decision Tree', 'Random Forests']
values = [precision_logit, precision_dtree, precision_rm]
model = np.arange(len(models))

plt.bar(model+0.15, values, align='center', width = 0.15, alpha=0.7, color = 'blue', label = 'precision')
plt.xticks(model, models)



ax = plt.subplot(111)

models = ['Logistic Regression', 'Decision Tree', 'Random Forests' ]
values = [recall_logit, recall_dtree, recall_rm, ]
model = np.arange(len(models))

plt.bar(model+0.3, values, align='center', width = 0.15, alpha=0.7, color = 'green', label = 'recall')
plt.xticks(model, models)



plt.ylabel('Performance Metrics for Different models')
plt.title('Model')
    
# removing the axis on the top and right of the plot window
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.legend()

plt.show()
# Out:
# <ipython-input-101-a1f6da031ada>:13: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(111)
# <ipython-input-101-a1f6da031ada>:24: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(111)

# %%
# Linear Classifier
from sklearn.metrics import accuracy_score,classification_report
from sklearn.svm import SVC

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
model_svm = SVC(kernel='rbf')

# %%
model_svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
#TRAINING - SVM
print ("\nSVM Classifier - Train Confusion Matrix\n\n",pd.crosstab(pd.Series(y_train, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True))
print ("\nSVM Classifier - Train accuracy:",round(accuracy_score(y_train, model_svm.predict(X_train)),3))
print ("\nSVM Classifier - Train Classification Report\n", classification_report(y_train,model_svm.predict(X_train)))
# Out:
# SVM Linear Classifier - Train Confusion Matrix
#
#  Predict     0     1   All
# Actual
# 0        4349  4012  8361
# 1         438   407   845
# All      4787  4419  9206
#
# SVM Linear Classifier - Train accuracy: 0.915
#
# SVM Linear Classifier - Train Classification Report
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     43685
#            1       0.00      0.00      0.00      4045
#
#     accuracy                           0.92     47730
#    macro avg       0.46      0.50      0.48     47730
# weighted avg       0.84      0.92      0.87     47730
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#VALIDATION - SVM
from sklearn.metrics import accuracy_score,classification_report
from sklearn.svm import SVC
from sklearn.model_selection import KFold, cross_val_score
clf = SVC(kernel='rbf')
k_folds = KFold(n_splits = 5)
scores = cross_val_score(clf, X_train, y_train, cv = k_folds)
print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.91514771 0.91535722 0.91399539 0.91703331 0.91472868]
# Average CV Score:  0.9152524617640896
# Number of CV Scores used in Average:  5

# %%
#TESTING - SVM
print ("\n\nSVM Linear Classifier - Test Confusion Matrix\n\n",pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True))
print ("\nSVM Linear Classifier - Test accuracy:",round(accuracy_score(y_test,model_svm.predict(X_test)),3))
print ("\nSVM Linear Classifier - Test Classification Report\n",classification_report(y_test,model_svm.predict(X_test)))
# Out:
# SVM Linear Classifier - Test Confusion Matrix
#
#  Predict     0     1   All
# Actual
# 0        1053   974  2027
# 1         124   109   233
# All      1177  1083  2260
#
# SVM Linear Classifier - Test accuracy: 0.914
#
# SVM Linear Classifier - Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.96     10908
#            1       0.00      0.00      0.00      1025
#
#     accuracy                           0.91     11933
#    macro avg       0.46      0.50      0.48     11933
# weighted avg       0.84      0.91      0.87     11933
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE
from collections import Counter
print('Original dataset shape {}'.format(Counter(y_train)))
sm = SMOTE(random_state=20)
train_input_new, train_output_new = sm.fit_resample(X_train, y_train)
print('New dataset shape {}'.format(Counter(train_output_new)))
# Out:
# Original dataset shape Counter({0: 35067, 1: 34829})
# New dataset shape Counter({0: 35067, 1: 35067})

# %%
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)

# %%
model_svm1 = SVC(kernel='rbf')

# %%
model_svm1.fit(X_train, y_train)
# Out:
# SVC()

# %%
print ("\nSVM Linear Classifier - Train Confusion Matrix\n\n",pd.crosstab(y_train, model_svm1.predict(X_train),rownames =["Actuall"],colnames = ["Predicted"]) )
print ("\nSVM Linear Classifier - Train accuracy:",round(accuracy_score(y_train, model_svm1.predict(X_train)),3))
print ("\nSVM Linear Classifier - Train Classification Report\n", classification_report(y_train,model_svm1.predict(X_train)))
# Out:
# SVM Linear Classifier - Train Confusion Matrix
#
#  Predicted      0      1
# Actuall
# 0          18356   9790
# 1           6571  21390
#
# SVM Linear Classifier - Train accuracy: 0.708
#
# SVM Linear Classifier - Train Classification Report
#                precision    recall  f1-score   support
#
#            0       0.74      0.65      0.69     28146
#            1       0.69      0.76      0.72     27961
#
#     accuracy                           0.71     56107
#    macro avg       0.71      0.71      0.71     56107
# weighted avg       0.71      0.71      0.71     56107

# %%
#print ("\n\nSVM Linear Classifier - Test Confusion Matrix\n\n",pd.crosstab(y_test, model_svm1.predict(X_test),rownames = ["Actuall"],colnames = ["Predicted"]))
print ("\nSVM Linear Classifier - Test accuracy:",round(accuracy_score(y_test,model_svm1.predict(X_test)),3))
#print ("\nSVM Linear Classifier - Test Classification Report\n",classification_report(y_test,model_svm1.predict(X_test)))
# Out:
# SVM Linear Classifier - Test accuracy: 0.714

# %%
#Deep neural network classifier applied on handwritten digits using Keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,classification_report

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import Adadelta,Adam,RMSprop
from keras.utils import np_utils

# %%
# Defining hyper parameters
np.random.seed(1337)
nb_classes = 2
batch_size = 128
nb_epochs = 100

# %%
#Deep Layer Model building in Keras
model = Sequential()

# %%
model.add(Dense(50, input_shape=(48,), activation='relu'))

# %%
model.add(Dense(100))
model.add(Activation('softmax'))
model.add(Dropout(0.5))

# %%
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
#Model training
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
#Y_train = np_utils.to_categorical(y_train, nb_classes)

# %%
x_vars_stdscle = StandardScaler().fit_transform(X)
#The following section of the code splits the data into train and test based on a 70-30 split:
X_train,X_test,y_train,y_test = train_test_split(x_vars_stdscle,y,train_size = 0.7,random_state=42)

# %%
X_train = np.asarray(X_train).astype(np.int64)
y_train = np.array(y_train).astype(np.int64)
X_train.size
# Out:
# 2004672

# %%
model.fit(X_train, y_train, batch_size=batch_size,epochs=nb_epochs,verbose=1)
# Out:
# Epoch 1/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.5165 - accuracy: 0.9024
# Epoch 2/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3818 - accuracy: 0.9147: 0s - loss: 0.3984 - accura
# Epoch 3/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3402 - accuracy: 0.9147
# Epoch 4/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3227 - accuracy: 0.9147
# Epoch 5/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3124 - accuracy: 0.9147
# Epoch 6/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3074 - accuracy: 0.9147
# Epoch 7/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3038 - accuracy: 0.9147
# Epoch 8/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2993 - accuracy: 0.9147
# Epoch 9/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2980 - accuracy: 0.9147
# Epoch 10/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2971 - accuracy: 0.9147
# Epoch 11/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2946 - accuracy: 0.9147
# Epoch 12/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2917 - accuracy: 0.9147
# Epoch 13/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2915 - accuracy: 0.9147
# Epoch 14/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2893 - accuracy: 0.9147
# Epoch 15/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2881 - accuracy: 0.9147
# Epoch 16/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2877 - accuracy: 0.9147
# Epoch 17/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2871 - accuracy: 0.9147: 0s - loss: 0.2836 - accuracy: 0.91 - ETA: 0s - loss: 0.2859 - accuracy:
# Epoch 18/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2861 - accuracy: 0.9147
# Epoch 19/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2861 - accuracy: 0.9147
# Epoch 20/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2860 - accuracy: 0.9147: 0s - loss: 0.2
# Epoch 21/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2854 - accuracy: 0.9147
# Epoch 22/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2857 - accuracy: 0.9147
# Epoch 23/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2846 - accuracy: 0.9147
# Epoch 24/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2851 - accuracy: 0.9147
# Epoch 25/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2847 - accuracy: 0.9147
# Epoch 26/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2847 - accuracy: 0.9147
# Epoch 27/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2844 - accuracy: 0.9147
# Epoch 28/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2845 - accuracy: 0.9147
# Epoch 29/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2841 - accuracy: 0.9147
# Epoch 30/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2840 - accuracy: 0.9147
# Epoch 31/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2837 - accuracy: 0.9147
# Epoch 32/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2837 - accuracy: 0.9147
# Epoch 33/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2832 - accuracy: 0.9147
# Epoch 34/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2831 - accuracy: 0.9147
# Epoch 35/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2827 - accuracy: 0.9147
# Epoch 36/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2823 - accuracy: 0.9147: 0s - loss: 0.2829 - accuracy: 0.91
# Epoch 37/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2821 - accuracy: 0.9147
# Epoch 38/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2820 - accuracy: 0.9147
# Epoch 39/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2816 - accuracy: 0.9147
# Epoch 40/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2817 - accuracy: 0.9147
# Epoch 41/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2813 - accuracy: 0.9147
# Epoch 42/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2809 - accuracy: 0.9147: 0s - loss: 0.2824 - accuracy:
# Epoch 43/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2808 - accuracy: 0.9147
# Epoch 44/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2813 - accuracy: 0.9147
# Epoch 45/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2800 - accuracy: 0.9147
# Epoch 46/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2798 - accuracy: 0.9147
# Epoch 47/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2794 - accuracy: 0.9147
# Epoch 48/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2791 - accuracy: 0.9147
# Epoch 49/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2790 - accuracy: 0.9147
# Epoch 50/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2789 - accuracy: 0.9147
# Epoch 51/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2786 - accuracy: 0.9147
# Epoch 52/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2784 - accuracy: 0.9147
# Epoch 53/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2777 - accuracy: 0.9147
# Epoch 54/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2775 - accuracy: 0.9147
# Epoch 55/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2775 - accuracy: 0.9147
# Epoch 56/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2773 - accuracy: 0.9147
# Epoch 57/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2766 - accuracy: 0.9147
# Epoch 58/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2763 - accuracy: 0.9147: 0s - loss: 0.2793 - accuracy
# Epoch 59/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2758 - accuracy: 0.9147
# Epoch 60/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2752 - accuracy: 0.9147: 0s - loss: 0.2655
# Epoch 61/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2755 - accuracy: 0.9147
# Epoch 62/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2759 - accuracy: 0.9147: 0s - loss: 0.2807 - accura
# Epoch 63/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2749 - accuracy: 0.9147: 0s - loss: 0.2744 - accuracy:
# Epoch 64/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2750 - accuracy: 0.9147
# Epoch 65/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2741 - accuracy: 0.9147
# Epoch 66/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2749 - accuracy: 0.9147: 0s - loss: 0.2740 - accuracy: 0.
# Epoch 67/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2741 - accuracy: 0.9147
# Epoch 68/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2734 - accuracy: 0.9147
# Epoch 69/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2731 - accuracy: 0.9147
# Epoch 70/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2731 - accuracy: 0.9147
# Epoch 71/100
# 327/327 [==============================] - 1s 3ms/step - loss: 0.2727 - accuracy: 0.9147
# Epoch 72/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2723 - accuracy: 0.9147
# Epoch 73/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2723 - accuracy: 0.9147
# Epoch 74/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2721 - accuracy: 0.9147
# Epoch 75/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2716 - accuracy: 0.9147
# Epoch 76/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2715 - accuracy: 0.9147
# Epoch 77/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2709 - accuracy: 0.9147
# Epoch 78/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2707 - accuracy: 0.9147
# Epoch 79/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2707 - accuracy: 0.9147
# Epoch 80/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2705 - accuracy: 0.9147
# Epoch 81/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2699 - accuracy: 0.9147
# Epoch 82/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2692 - accuracy: 0.9147
# Epoch 83/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2689 - accuracy: 0.9147
# Epoch 84/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2687 - accuracy: 0.9147
# Epoch 85/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2685 - accuracy: 0.9147
# Epoch 86/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2681 - accuracy: 0.9147
# Epoch 87/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2675 - accuracy: 0.9147
# Epoch 88/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2670 - accuracy: 0.9147: 0s - loss: 0.2673 - accuracy: 0.91
# Epoch 89/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2673 - accuracy: 0.9147
# Epoch 90/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2663 - accuracy: 0.9147
# Epoch 91/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2668 - accuracy: 0.9147: 0s - loss: 0.2647 - accuracy: 0.91 - ETA: 0s - loss: 0.2662 - accuracy: 0.91 - ETA: 0s - loss: 0.2684 - accuracy
# Epoch 92/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2661 - accuracy: 0.9147
# Epoch 93/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2663 - accuracy: 0.9147
# Epoch 94/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2662 - accuracy: 0.9147
# Epoch 95/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2655 - accuracy: 0.9147
# Epoch 96/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2657 - accuracy: 0.9147: 0s - loss: 0.2610 - accu
# Epoch 97/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2649 - accuracy: 0.9147
# Epoch 98/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2645 - accuracy: 0.9147
# Epoch 99/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2647 - accuracy: 0.9147: 0s - loss: 0.2628 - accuracy
# Epoch 100/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2641 - accuracy: 0.9147

# %%
#Returns the loss value & metrics values for the model in test mode.
score = model.evaluate(X_test, y_test,
                       batch_size=batch_size, verbose=1)
 
print('Test accuracy:', score[0], score[1])
# Out:
# 140/140 [==============================] - 0s 781us/step - loss: 0.3143 - accuracy: 0.9158
# Test accuracy: 0.3143123984336853 0.9158053398132324

# %%
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#Model Prediction
y_train_predclass = model.predict_classes(X_train,batch_size=batch_size)
y_test_predclass = model.predict_classes(X_test,batch_size=batch_size)
y_train_predclass = np.array(y_train).astype(np.int64)
y_test_predclass = np.array(y_test).astype(np.int64)
# Out:
# WARNING:tensorflow:From <ipython-input-137-1024f55cdba2>:2: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
print ("\n\nDeep Neural Network - Train accuracy:", round(accuracy_score(y_train,y_train_predclass),3))
print ("\nDeep Neural Network - Train Classification Report", print (classification_report(y_train,y_train_predclass)))
print ('\n Deep Neural Network - Train Confusion Matrix')
print (pd.crosstab(y_train,y_train_predclass[1],rownames = ["Actual"],colnames = ["Predicted"]) )
# Out:
# Deep Neural Network - Train accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     38201
#            1       1.00      1.00      1.00      3563
#
#     accuracy                           1.00     41764
#    macro avg       1.00      1.00      1.00     41764
# weighted avg       1.00      1.00      1.00     41764
#
#
# Deep Neural Network - Train Classification Report None
#
#  Deep Neural Network - Train Confusion Matrix
# Predicted      0
# Actual
# 0          38201
# 1           3563

# %%
print ("\nDeep Neural Network - Test accuracy:",round(accuracy_score(y_test, y_test_predclass),3))
print ("\nDeep Neural Network - Test Classification Report")
print (classification_report(y_test,y_test_predclass))
print ("\nDeep Neural Network - Test Confusion Matrix\n")
print (pd.crosstab(y_test,y_test_predclass,rownames = ["Actuall"],colnames = ["Predicted"]) )
# Out:
# Deep Neural Network - Test accuracy: 1.0
#
# Deep Neural Network - Test Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     16392
#            1       1.00      1.00      1.00      1507
#
#     accuracy                           1.00     17899
#    macro avg       1.00      1.00      1.00     17899
# weighted avg       1.00      1.00      1.00     17899
#
#
# Deep Neural Network - Test Confusion Matrix
#
# Predicted      0     1
# Actuall
# 0          16392     0
# 1              0  1507

# %%
# RETRAINING - HAPPENS FROM HERE

# %%
#loading Dataset
df = pd.read_csv("C:\\Users\91944\Desktop\\fiipdata-retrain.csv")

# %%
#displaying first 10 rows of data
df.head(10).T
# Out:
#                                                  0          1  \
# encounter_id                               2278392     149190
# patient_nbr                                8222157   55629189
# race                                     Caucasian  Caucasian
# gender                                      Female     Female
# age                                         [0-10)    [10-20)
# weight                                           ?          ?
# admission_type_id                                6          1
# discharge_disposition_id                        25          1
# admission_source_id                              1          7
# time_in_hospital                                 1          3
# payer_code                                       ?          ?
# medical_specialty         Pediatrics-Endocrinology          ?
# num_lab_procedures                              41         59
# num_procedures                                   0          0
# num_medications                                  1         18
# number_outpatient                                0          0
# number_emergency                                 0          0
# number_inpatient                                 0          0
# diag_1                                      250.83        276
# diag_2                                           ?     250.01
# diag_3                                           ?        255
# number_diagnoses                                 1          9
# max_glu_serum                                 None       None
# A1Cresult                                     None       None
# metformin                                       No         No
# repaglinide                                     No         No
# nateglinide                                     No         No
# chlorpropamide                                  No         No
# glimepiride                                     No         No
# acetohexamide                                   No         No
# glipizide                                       No         No
# glyburide                                       No         No
# tolbutamide                                     No         No
# pioglitazone                                    No         No
# rosiglitazone                                   No         No
# acarbose                                        No         No
# miglitol                                        No         No
# troglitazone                                    No         No
# tolazamide                                      No         No
# examide                                         No         No
# citoglipton                                     No         No
# insulin                                         No         Up
# glyburide-metformin                             No         No
# glipizide-metformin                             No         No
# glimepiride-pioglitazone                        No         No
# metformin-rosiglitazone                         No         No
# metformin-pioglitazone                          No         No
# change                                          No         Ch
# diabetesMed                                     No        Yes
# readmitted                                      NO        >30
#
#                                         2          3          4          5  \
# encounter_id                        64410     500364      16680      35754
# patient_nbr                      86047875   82442376   42519267   82637451
# race                      AfricanAmerican  Caucasian  Caucasian  Caucasian
# gender                             Female       Male       Male       Male
# age                               [20-30)    [30-40)    [40-50)    [50-60)
# weight                                  ?          ?          ?          ?
# admission_type_id                       1          1          1          2
# discharge_disposition_id                1          1          1          1
# admission_source_id                     7          7          7          2
# time_in_hospital                        2          2          1          3
# payer_code                              ?          ?          ?          ?
# medical_specialty                       ?          ?          ?          ?
# num_lab_procedures                     11         44         51         31
# num_procedures                          5          1          0          6
# num_medications                        13         16          8         16
# number_outpatient                       2          0          0          0
# number_emergency                        0          0          0          0
# number_inpatient                        1          0          0          0
# diag_1                                648          8        197        414
# diag_2                                250     250.43        157        411
# diag_3                                V27        403        250        250
# number_diagnoses                        6          7          5          9
# max_glu_serum                        None       None       None       None
# A1Cresult                            None       None       None       None
# metformin                              No         No         No         No
# repaglinide                            No         No         No         No
# nateglinide                            No         No         No         No
# chlorpropamide                         No         No         No         No
# glimepiride                            No         No         No         No
# acetohexamide                          No         No         No         No
# glipizide                          Steady         No     Steady         No
# glyburide                              No         No         No         No
# tolbutamide                            No         No         No         No
# pioglitazone                           No         No         No         No
# rosiglitazone                          No         No         No         No
# acarbose                               No         No         No         No
# miglitol                               No         No         No         No
# troglitazone                           No         No         No         No
# tolazamide                             No         No         No         No
# examide                                No         No         No         No
# citoglipton                            No         No         No         No
# insulin                                No         Up     Steady     Steady
# glyburide-metformin                    No         No         No         No
# glipizide-metformin                    No         No         No         No
# glimepiride-pioglitazone               No         No         No         No
# metformin-rosiglitazone                No         No         No         No
# metformin-pioglitazone                 No         No         No         No
# change                                 No         Ch         Ch         No
# diabetesMed                           Yes        Yes        Yes        Yes
# readmitted                             NO         NO         NO        >30
#
#                                   6          7          8                 9
# encounter_id                  55842      63768      12522             15738
# patient_nbr                84259809  114882984   48330783          63555939
# race                      Caucasian  Caucasian  Caucasian         Caucasian
# gender                         Male       Male     Female            Female
# age                         [60-70)    [70-80)    [80-90)          [90-100)
# weight                            ?          ?          ?                 ?
# admission_type_id                 3          1          2                 3
# discharge_disposition_id          1          1          1                 3
# admission_source_id               2          7          4                 4
# time_in_hospital                  4          5         13                12
# payer_code                        ?          ?          ?                 ?
# medical_specialty                 ?          ?          ?  InternalMedicine
# num_lab_procedures               70         73         68                33
# num_procedures                    1          0          2                 3
# num_medications                  21         12         28                18
# number_outpatient                 0          0          0                 0
# number_emergency                  0          0          0                 0
# number_inpatient                  0          0          0                 0
# diag_1                          414        428        398               434
# diag_2                          411        492        427               198
# diag_3                          V45        250         38               486
# number_diagnoses                  7          8          8                 8
# max_glu_serum                  None       None       None              None
# A1Cresult                      None       None       None              None
# metformin                    Steady         No         No                No
# repaglinide                      No         No         No                No
# nateglinide                      No         No         No                No
# chlorpropamide                   No         No         No                No
# glimepiride                  Steady         No         No                No
# acetohexamide                    No         No         No                No
# glipizide                        No         No     Steady                No
# glyburide                        No     Steady         No                No
# tolbutamide                      No         No         No                No
# pioglitazone                     No         No         No                No
# rosiglitazone                    No         No         No            Steady
# acarbose                         No         No         No                No
# miglitol                         No         No         No                No
# troglitazone                     No         No         No                No
# tolazamide                       No         No         No                No
# examide                          No         No         No                No
# citoglipton                      No         No         No                No
# insulin                      Steady         No     Steady            Steady
# glyburide-metformin              No         No         No                No
# glipizide-metformin              No         No         No                No
# glimepiride-pioglitazone         No         No         No                No
# metformin-rosiglitazone          No         No         No                No
# metformin-pioglitazone           No         No         No                No
# change                           Ch         No         Ch                Ch
# diabetesMed                     Yes        Yes        Yes               Yes
# readmitted                       NO        >30         NO                NO

# %%
#checking shape of the dataset
df.shape
# Out:
# (101766, 50)

# %%
#Checking data types of each variable
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# examide                     object
# citoglipton                 object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                  object
# dtype: object

# %%
#Checking for missing values in dataset
#In the dataset missing values are represented as '?' sign
for col in df.columns:
    if df[col].dtype == object:
         print(col,df[col][df[col] == '?'].count())
# Out:
# race 2273
# gender 0
# age 0
# weight 98569
# payer_code 40256
# medical_specialty 49949
# diag_1 21
# diag_2 358
# diag_3 1423
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# examide 0
# citoglipton 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0

# %%
# gender was coded differently so we use a custom count for this one            
print('gender', df['gender'][df['gender'] == 'Unknown/Invalid'].count())
# Out:
# gender 3

# %%
#dropping columns with large number of missing values
df = df.drop(['weight','payer_code','medical_specialty'], axis = 1)

# %%
drop_Idx = set(df[(df['diag_1'] == '?') & (df['diag_2'] == '?') & (df['diag_3'] == '?')].index)

drop_Idx = drop_Idx.union(set(df['diag_1'][df['diag_1'] == '?'].index))
drop_Idx = drop_Idx.union(set(df['diag_2'][df['diag_2'] == '?'].index))
drop_Idx = drop_Idx.union(set(df['diag_3'][df['diag_3'] == '?'].index))
drop_Idx = drop_Idx.union(set(df['race'][df['race'] == '?'].index))
drop_Idx = drop_Idx.union(set(df[df['discharge_disposition_id'] == 11].index))
drop_Idx = drop_Idx.union(set(df['gender'][df['gender'] == 'Unknown/Invalid'].index))
new_Idx = list(set(df.index) - set(drop_Idx))
df = df.iloc[new_Idx]

# %%
df = df.drop(['citoglipton', 'examide'], axis = 1)

# %%
#Checking for missing values in the data
for col in df.columns:
    if df[col].dtype == object:
         print(col,df[col][df[col] == '?'].count())
            
print('gender', df['gender'][df['gender'] == 'Unknown/Invalid'].count())
# Out:
# race 0
# gender 0
# age 0
# diag_1 0
# diag_2 0
# diag_3 0
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0
# gender 0

# %%
#Feature Engineering
df['service_utilization'] = df['number_outpatient'] + df['number_emergency'] + df['number_inpatient']

# %%
keys = ['metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 'glyburide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'insulin', 'glyburide-metformin', 'tolazamide', 'metformin-pioglitazone','metformin-rosiglitazone', 'glimepiride-pioglitazone', 'glipizide-metformin', 'troglitazone', 'tolbutamide', 'acetohexamide']
for col in keys:
    colname = str(col) + 'temp'
    df[colname] = df[col].apply(lambda x: 0 if (x == 'No' or x == 'Steady') else 1)
df['numchange'] = 0
for col in keys:
    colname = str(col) + 'temp'
    df['numchange'] = df['numchange'] + df[colname]
    del df[colname]
    
df['numchange'].value_counts()
# Out:
# 0    70142
# 1    24922
# 2     1271
# 3      106
# 4        5
# Name: numchange, dtype: int64

# %%
# re-encoding admission type, discharge type and admission source into fewer categories

df['admission_type_id'] = df['admission_type_id'].replace(2,1)
df['admission_type_id'] = df['admission_type_id'].replace(7,1)
df['admission_type_id'] = df['admission_type_id'].replace(6,5)
df['admission_type_id'] = df['admission_type_id'].replace(8,5)

df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(6,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(8,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(9,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(13,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(3,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(4,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(5,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(14,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(22,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(23,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(24,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(12,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(15,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(16,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(17,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(25,18)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(26,18)

df['admission_source_id'] = df['admission_source_id'].replace(2,1)
df['admission_source_id'] = df['admission_source_id'].replace(3,1)
df['admission_source_id'] = df['admission_source_id'].replace(5,4)
df['admission_source_id'] = df['admission_source_id'].replace(6,4)
df['admission_source_id'] = df['admission_source_id'].replace(10,4)
df['admission_source_id'] = df['admission_source_id'].replace(22,4)
df['admission_source_id'] = df['admission_source_id'].replace(25,4)
df['admission_source_id'] = df['admission_source_id'].replace(15,9)
df['admission_source_id'] = df['admission_source_id'].replace(17,9)
df['admission_source_id'] = df['admission_source_id'].replace(20,9)
df['admission_source_id'] = df['admission_source_id'].replace(21,9)
df['admission_source_id'] = df['admission_source_id'].replace(13,11)
df['admission_source_id'] = df['admission_source_id'].replace(14,11)

# %%
df['change'] = df['change'].replace('Ch', 1)
df['change'] = df['change'].replace('No', 0)
df['gender'] = df['gender'].replace('Male', 1)
df['gender'] = df['gender'].replace('Female', 0)
df['diabetesMed'] = df['diabetesMed'].replace('Yes', 1)
df['diabetesMed'] = df['diabetesMed'].replace('No', 0)
# keys is the same as before
for col in keys:
    df[col] = df[col].replace('No', 0)
    df[col] = df[col].replace('Steady', 1)
    df[col] = df[col].replace('Up', 1)
    df[col] = df[col].replace('Down', 1)

# %%
df['A1Cresult'] = df['A1Cresult'].replace('>7', 1)
df['A1Cresult'] = df['A1Cresult'].replace('>8', 1)
df['A1Cresult'] = df['A1Cresult'].replace('Norm', 0)
df['A1Cresult'] = df['A1Cresult'].replace('None', -99)
df['max_glu_serum'] = df['max_glu_serum'].replace('>200', 1)
df['max_glu_serum'] = df['max_glu_serum'].replace('>300', 1)
df['max_glu_serum'] = df['max_glu_serum'].replace('Norm', 0)
df['max_glu_serum'] = df['max_glu_serum'].replace('None', -99)

# %%
# code age intervals [0-10) - [90-100) from 1-10
for i in range(0,10):
    df['age'] = df['age'].replace('['+str(10*i)+'-'+str(10*(i+1))+')', i+1)
df['age'].value_counts()
# Out:
# 8     24815
# 7     21521
# 6     16546
# 9     16223
# 5      9208
# 4      3538
# 10     2594
# 3      1471
# 2       466
# 1        64
# Name: age, dtype: int64

# %%
df2 = df.drop_duplicates(subset= ['patient_nbr'], keep = 'first')
df2.shape
(70442, 55)
# Out:
# (70442, 55)

# %%
df.head().T
# Out:
#                                   1                2          3          4  \
# encounter_id                 149190            64410     500364      16680
# patient_nbr                55629189         86047875   82442376   42519267
# race                      Caucasian  AfricanAmerican  Caucasian  Caucasian
# gender                            0                0          1          1
# age                               2                3          4          5
# admission_type_id                 1                1          1          1
# discharge_disposition_id          1                1          1          1
# admission_source_id               7                7          7          7
# time_in_hospital                  3                2          2          1
# num_lab_procedures               59               11         44         51
# num_procedures                    0                5          1          0
# num_medications                  18               13         16          8
# number_outpatient                 0                2          0          0
# number_emergency                  0                0          0          0
# number_inpatient                  0                1          0          0
# diag_1                          276              648          8        197
# diag_2                       250.01              250     250.43        157
# diag_3                          255              V27        403        250
# number_diagnoses                  9                6          7          5
# max_glu_serum                   -99              -99        -99        -99
# A1Cresult                       -99              -99        -99        -99
# metformin                         0                0          0          0
# repaglinide                       0                0          0          0
# nateglinide                       0                0          0          0
# chlorpropamide                    0                0          0          0
# glimepiride                       0                0          0          0
# acetohexamide                     0                0          0          0
# glipizide                         0                1          0          1
# glyburide                         0                0          0          0
# tolbutamide                       0                0          0          0
# pioglitazone                      0                0          0          0
# rosiglitazone                     0                0          0          0
# acarbose                          0                0          0          0
# miglitol                          0                0          0          0
# troglitazone                      0                0          0          0
# tolazamide                        0                0          0          0
# insulin                           1                0          1          1
# glyburide-metformin               0                0          0          0
# glipizide-metformin               0                0          0          0
# glimepiride-pioglitazone          0                0          0          0
# metformin-rosiglitazone           0                0          0          0
# metformin-pioglitazone            0                0          0          0
# change                            1                0          1          1
# diabetesMed                       1                1          1          1
# readmitted                      >30               NO         NO         NO
# service_utilization               0                3          0          0
# numchange                         1                0          1          0
#
#                                   5
# encounter_id                  35754
# patient_nbr                82637451
# race                      Caucasian
# gender                            1
# age                               6
# admission_type_id                 1
# discharge_disposition_id          1
# admission_source_id               1
# time_in_hospital                  3
# num_lab_procedures               31
# num_procedures                    6
# num_medications                  16
# number_outpatient                 0
# number_emergency                  0
# number_inpatient                  0
# diag_1                          414
# diag_2                          411
# diag_3                          250
# number_diagnoses                  9
# max_glu_serum                   -99
# A1Cresult                       -99
# metformin                         0
# repaglinide                       0
# nateglinide                       0
# chlorpropamide                    0
# glimepiride                       0
# acetohexamide                     0
# glipizide                         0
# glyburide                         0
# tolbutamide                       0
# pioglitazone                      0
# rosiglitazone                     0
# acarbose                          0
# miglitol                          0
# troglitazone                      0
# tolazamide                        0
# insulin                           1
# glyburide-metformin               0
# glipizide-metformin               0
# glimepiride-pioglitazone          0
# metformin-rosiglitazone           0
# metformin-pioglitazone            0
# change                            0
# diabetesMed                       1
# readmitted                      >30
# service_utilization               0
# numchange                         0

# %%
df['readmitted'].value_counts()
# Out:
# NO     50731
# >30    34649
# <30    11066
# Name: readmitted, dtype: int64

# %%
df['readmitted'] = df['readmitted'].replace('>30', 0)
df['readmitted'] = df['readmitted'].replace('<30', 1)
df['readmitted'] = df['readmitted'].replace('NO', 0)

# %%
# Creating additional columns for diagnosis# Creati 
df['level1_diag1'] = df['diag_1']
df['level2_diag1'] = df['diag_1']
df['level1_diag2'] = df['diag_2']
df['level2_diag2'] = df['diag_2']
df['level1_diag3'] = df['diag_3']
df['level2_diag3'] = df['diag_3']

# %%
df.loc[df['diag_1'].str.contains('V'), ['level1_diag1', 'level2_diag1']] = 0
df.loc[df['diag_1'].str.contains('E'), ['level1_diag1', 'level2_diag1']] = 0
df.loc[df['diag_2'].str.contains('V'), ['level1_diag2', 'level2_diag2']] = 0
df.loc[df['diag_2'].str.contains('E'), ['level1_diag2', 'level2_diag2']] = 0
df.loc[df['diag_3'].str.contains('V'), ['level1_diag3', 'level2_diag3']] = 0
df.loc[df['diag_3'].str.contains('E'), ['level1_diag3', 'level2_diag3']] = 0
df['level1_diag1'] = df['level1_diag1'].replace('?', -1)
df['level2_diag1'] = df['level2_diag1'].replace('?', -1)
df['level1_diag2'] = df['level1_diag2'].replace('?', -1)
df['level2_diag2'] = df['level2_diag2'].replace('?', -1)
df['level1_diag3'] = df['level1_diag3'].replace('?', -1)
df['level2_diag3'] = df['level2_diag3'].replace('?', -1)

# %%
df['level1_diag1'] = df['level1_diag1'].astype(float)
df['level2_diag1'] = df['level2_diag1'].astype(float)
df['level1_diag2'] = df['level1_diag2'].astype(float)
df['level2_diag2'] = df['level2_diag2'].astype(float)
df['level1_diag3'] = df['level1_diag3'].astype(float)
df['level2_diag3'] = df['level2_diag3'].astype(float)

# %%
for index, row in df.iterrows():
    if (row['level1_diag1'] >= 390 and row['level1_diag1'] < 460) or (np.floor(row['level1_diag1']) == 785):
        df.loc[index, 'level1_diag1'] = 1
    elif (row['level1_diag1'] >= 460 and row['level1_diag1'] < 520) or (np.floor(row['level1_diag1']) == 786):
        df.loc[index, 'level1_diag1'] = 2
    elif (row['level1_diag1'] >= 520 and row['level1_diag1'] < 580) or (np.floor(row['level1_diag1']) == 787):
        df.loc[index, 'level1_diag1'] = 3
    elif (np.floor(row['level1_diag1']) == 250):
        df.loc[index, 'level1_diag1'] = 4
    elif (row['level1_diag1'] >= 800 and row['level1_diag1'] < 1000):
        df.loc[index, 'level1_diag1'] = 5
    elif (row['level1_diag1'] >= 710 and row['level1_diag1'] < 740):
        df.loc[index, 'level1_diag1'] = 6
    elif (row['level1_diag1'] >= 580 and row['level1_diag1'] < 630) or (np.floor(row['level1_diag1']) == 788):
        df.loc[index, 'level1_diag1'] = 7
    elif (row['level1_diag1'] >= 140 and row['level1_diag1'] < 240):
        df.loc[index, 'level1_diag1'] = 8
    else:
        df.loc[index, 'level1_diag1'] = 0
        
    if (row['level1_diag2'] >= 390 and row['level1_diag2'] < 460) or (np.floor(row['level1_diag2']) == 785):
        df.loc[index, 'level1_diag2'] = 1
    elif (row['level1_diag2'] >= 460 and row['level1_diag2'] < 520) or (np.floor(row['level1_diag2']) == 786):
        df.loc[index, 'level1_diag2'] = 2
    elif (row['level1_diag2'] >= 520 and row['level1_diag2'] < 580) or (np.floor(row['level1_diag2']) == 787):
        df.loc[index, 'level1_diag2'] = 3
    elif (np.floor(row['level1_diag2']) == 250):
        df.loc[index, 'level1_diag2'] = 4
    elif (row['level1_diag2'] >= 800 and row['level1_diag2'] < 1000):
        df.loc[index, 'level1_diag2'] = 5
    elif (row['level1_diag2'] >= 710 and row['level1_diag2'] < 740):
        df.loc[index, 'level1_diag2'] = 6
    elif (row['level1_diag2'] >= 580 and row['level1_diag2'] < 630) or (np.floor(row['level1_diag2']) == 788):
        df.loc[index, 'level1_diag2'] = 7
    elif (row['level1_diag2'] >= 140 and row['level1_diag2'] < 240):
        df.loc[index, 'level1_diag2'] = 8
    else:
        df.loc[index, 'level1_diag2'] = 0
    
    if (row['level1_diag3'] >= 390 and row['level1_diag3'] < 460) or (np.floor(row['level1_diag3']) == 785):
        df.loc[index, 'level1_diag3'] = 1
    elif (row['level1_diag3'] >= 460 and row['level1_diag3'] < 520) or (np.floor(row['level1_diag3']) == 786):
        df.loc[index, 'level1_diag3'] = 2
    elif (row['level1_diag3'] >= 520 and row['level1_diag3'] < 580) or (np.floor(row['level1_diag3']) == 787):
        df.loc[index, 'level1_diag3'] = 3
    elif (np.floor(row['level1_diag3']) == 250):
        df.loc[index, 'level1_diag3'] = 4
    elif (row['level1_diag3'] >= 800 and row['level1_diag3'] < 1000):
        df.loc[index, 'level1_diag3'] = 5
    elif (row['level1_diag3'] >= 710 and row['level1_diag3'] < 740):
        df.loc[index, 'level1_diag3'] = 6
    elif (row['level1_diag3'] >= 580 and row['level1_diag3'] < 630) or (np.floor(row['level1_diag3']) == 788):
        df.loc[index, 'level1_diag3'] = 7
    elif (row['level1_diag3'] >= 140 and row['level1_diag3'] < 240):
        df.loc[index, 'level1_diag3'] = 8
    else:
        df.loc[index, 'level1_diag3'] = 0

# %%
for index, row in df.iterrows():
    if (row['level2_diag1'] >= 390 and row['level2_diag1'] < 399):
        df.loc[index, 'level2_diag1'] = 1
    elif (row['level2_diag1'] >= 401 and row['level2_diag1'] < 415):
        df.loc[index, 'level2_diag1'] = 2
    elif (row['level2_diag1'] >= 415 and row['level2_diag1'] < 460):
        df.loc[index, 'level2_diag1'] = 3
    elif (np.floor(row['level2_diag1']) == 785):
        df.loc[index, 'level2_diag1'] = 4
    elif (row['level2_diag1'] >= 460 and row['level2_diag1'] < 489):
        df.loc[index, 'level2_diag1'] = 5
    elif (row['level2_diag1'] >= 490 and row['level2_diag1'] < 497):
        df.loc[index, 'level2_diag1'] = 6
    elif (row['level2_diag1'] >= 500 and row['level2_diag1'] < 520):
        df.loc[index, 'level2_diag1'] = 7
    elif (np.floor(row['level2_diag1']) == 786):
        df.loc[index, 'level2_diag1'] = 8
    elif (row['level2_diag1'] >= 520 and row['level2_diag1'] < 530):
        df.loc[index, 'level2_diag1'] = 9
    elif (row['level2_diag1'] >= 530 and row['level2_diag1'] < 544):
        df.loc[index, 'level2_diag1'] = 10
    elif (row['level2_diag1'] >= 550 and row['level2_diag1'] < 554):
        df.loc[index, 'level2_diag1'] = 11
    elif (row['level2_diag1'] >= 555 and row['level2_diag1'] < 580):
        df.loc[index, 'level2_diag1'] = 12
    elif (np.floor(row['level2_diag1']) == 787):
        df.loc[index, 'level2_diag1'] = 13
    elif (np.floor(row['level2_diag1']) == 250):
        df.loc[index, 'level2_diag1'] = 14
    elif (row['level2_diag1'] >= 800 and row['level2_diag1'] < 1000):
        df.loc[index, 'level2_diag1'] = 15
    elif (row['level2_diag1'] >= 710 and row['level2_diag1'] < 740):
        df.loc[index, 'level2_diag1'] = 16
    elif (row['level2_diag1'] >= 580 and row['level2_diag1'] < 630):
        df.loc[index, 'level2_diag1'] = 17
    elif (np.floor(row['level2_diag1']) == 788):
        df.loc[index, 'level2_diag1'] = 18
    elif (row['level2_diag1'] >= 140 and row['level2_diag1'] < 240):
        df.loc[index, 'level2_diag1'] = 19
    elif row['level2_diag1'] >= 240 and row['level2_diag1'] < 280 and (np.floor(row['level2_diag1']) != 250):
        df.loc[index, 'level2_diag1'] = 20
    elif (row['level2_diag1'] >= 680 and row['level2_diag1'] < 710) or (np.floor(row['level2_diag1']) == 782):
        df.loc[index, 'level2_diag1'] = 21
    elif (row['level2_diag1'] >= 290 and row['level2_diag1'] < 320):
        df.loc[index, 'level2_diag1'] = 22
    else:
        df.loc[index, 'level2_diag1'] = 0
        
    if (row['level2_diag2'] >= 390 and row['level2_diag2'] < 399):
        df.loc[index, 'level2_diag2'] = 1
    elif (row['level2_diag2'] >= 401 and row['level2_diag2'] < 415):
        df.loc[index, 'level2_diag2'] = 2
    elif (row['level2_diag2'] >= 415 and row['level2_diag2'] < 460):
        df.loc[index, 'level2_diag2'] = 3
    elif (np.floor(row['level2_diag2']) == 785):
        df.loc[index, 'level2_diag2'] = 4
    elif (row['level2_diag2'] >= 460 and row['level2_diag2'] < 489):
        df.loc[index, 'level2_diag2'] = 5
    elif (row['level2_diag2'] >= 490 and row['level2_diag2'] < 497):
        df.loc[index, 'level2_diag2'] = 6
    elif (row['level2_diag2'] >= 500 and row['level2_diag2'] < 520):
        df.loc[index, 'level2_diag2'] = 7
    elif (np.floor(row['level2_diag2']) == 786):
        df.loc[index, 'level2_diag2'] = 8
    elif (row['level2_diag2'] >= 520 and row['level2_diag2'] < 530):
        df.loc[index, 'level2_diag2'] = 9
    elif (row['level2_diag2'] >= 530 and row['level2_diag2'] < 544):
        df.loc[index, 'level2_diag2'] = 10
    elif (row['level2_diag2'] >= 550 and row['level2_diag2'] < 554):
        df.loc[index, 'level2_diag2'] = 11
    elif (row['level2_diag2'] >= 555 and row['level2_diag2'] < 580):
        df.loc[index, 'level2_diag2'] = 12
    elif (np.floor(row['level2_diag2']) == 787):
        df.loc[index, 'level2_diag2'] = 13
    elif (np.floor(row['level2_diag2']) == 250):
        df.loc[index, 'level2_diag2'] = 14
    elif (row['level2_diag2'] >= 800 and row['level2_diag2'] < 1000):
        df.loc[index, 'level2_diag2'] = 15
    elif (row['level2_diag2'] >= 710 and row['level2_diag2'] < 740):
        df.loc[index, 'level2_diag2'] = 16
    elif (row['level2_diag2'] >= 580 and row['level2_diag2'] < 630):
        df.loc[index, 'level2_diag2'] = 17
    elif (np.floor(row['level2_diag2']) == 788):
        df.loc[index, 'level2_diag2'] = 18
    elif (row['level2_diag2'] >= 140 and row['level2_diag2'] < 240):
        df.loc[index, 'level2_diag2'] = 19
    elif row['level2_diag2'] >= 240 and row['level2_diag2'] < 280 and (np.floor(row['level2_diag2']) != 250):
        df.loc[index, 'level2_diag2'] = 20
    elif (row['level2_diag2'] >= 680 and row['level2_diag2'] < 710) or (np.floor(row['level2_diag2']) == 782):
        df.loc[index, 'level2_diag2'] = 21
    elif (row['level2_diag2'] >= 290 and row['level2_diag2'] < 320):
        df.loc[index, 'level2_diag2'] = 22
    else:
        df.loc[index, 'level2_diag2'] = 0
        
        
    if (row['level2_diag3'] >= 390 and row['level2_diag3'] < 399):
        df.loc[index, 'level2_diag3'] = 1
    elif (row['level2_diag3'] >= 401 and row['level2_diag3'] < 415):
        df.loc[index, 'level2_diag3'] = 2
    elif (row['level2_diag3'] >= 415 and row['level2_diag3'] < 460):
        df.loc[index, 'level2_diag3'] = 3
    elif (np.floor(row['level2_diag3']) == 785):
        df.loc[index, 'level2_diag3'] = 4
    elif (row['level2_diag3'] >= 460 and row['level2_diag3'] < 489):
        df.loc[index, 'level2_diag3'] = 5
    elif (row['level2_diag3'] >= 490 and row['level2_diag3'] < 497):
        df.loc[index, 'level2_diag3'] = 6
    elif (row['level2_diag3'] >= 500 and row['level2_diag3'] < 520):
        df.loc[index, 'level2_diag3'] = 7
    elif (np.floor(row['level2_diag3']) == 786):
        df.loc[index, 'level2_diag3'] = 8
    elif (row['level2_diag3'] >= 520 and row['level2_diag3'] < 530):
        df.loc[index, 'level2_diag3'] = 9
    elif (row['level2_diag3'] >= 530 and row['level2_diag3'] < 544):
        df.loc[index, 'level2_diag3'] = 10
    elif (row['level2_diag3'] >= 550 and row['level2_diag3'] < 554):
        df.loc[index, 'level2_diag3'] = 11
    elif (row['level2_diag3'] >= 555 and row['level2_diag3'] < 580):
        df.loc[index, 'level2_diag3'] = 12
    elif (np.floor(row['level2_diag3']) == 787):
        df.loc[index, 'level2_diag3'] = 13
    elif (np.floor(row['level2_diag3']) == 250):
        df.loc[index, 'level2_diag3'] = 14
    elif (row['level2_diag3'] >= 800 and row['level2_diag3'] < 1000):
        df.loc[index, 'level2_diag3'] = 15
    elif (row['level2_diag3'] >= 710 and row['level2_diag3'] < 740):
        df.loc[index, 'level2_diag3'] = 16
    elif (row['level2_diag3'] >= 580 and row['level2_diag3'] < 630):
        df.loc[index, 'level2_diag3'] = 17
    elif (np.floor(row['level2_diag3']) == 788):
        df.loc[index, 'level2_diag3'] = 18
    elif (row['level2_diag3'] >= 140 and row['level2_diag3'] < 240):
        df.loc[index, 'level2_diag3'] = 19
    elif row['level2_diag3'] >= 240 and row['level2_diag3'] < 280 and (np.floor(row['level2_diag3']) != 250):
        df.loc[index, 'level2_diag3'] = 20
    elif (row['level2_diag3'] >= 680 and row['level2_diag3'] < 710) or (np.floor(row['level2_diag3']) == 782):
        df.loc[index, 'level2_diag3'] = 21
    elif (row['level2_diag3'] >= 290 and row['level2_diag3'] < 320):
        df.loc[index, 'level2_diag3'] = 22
    else:
        df.loc[index, 'level2_diag3'] = 0

# %%
#Data Visualization
# Distribution of Readmission 
sns.countplot(df['readmitted']).set_title('Distribution of Readmission')
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribution of Readmission')

# %%
#Time in Hospital VS. Readmission
fig = plt.figure(figsize=(13,7),)
ax=sns.kdeplot(df.loc[(df['readmitted'] == 0),'time_in_hospital'] , color='b',shade=True,label='Not Readmitted')
ax=sns.kdeplot(df.loc[(df['readmitted'] == 1),'time_in_hospital'] , color='r',shade=True, label='Readmitted')
ax.set(xlabel='Time in Hospital', ylabel='Frequency')
plt.title('Time in Hospital VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Time in Hospital VS. Readmission')

# %%
#Age of Patient VS. Readmission
fig = plt.figure(figsize=(15,10))
sns.countplot(y= df['age'], hue = df['readmitted']).set_title('Age of Patient VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Age of Patient VS. Readmission')

# %%
#race VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(y = df['race'], hue = df['readmitted'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='race'>

# %%
#Number of medication used VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.barplot(x = df['readmitted'], y = df['num_medications']).set_title("Number of medication used VS. Readmission")
# Out:
# Text(0.5, 1.0, 'Number of medication used VS. Readmission')

# %%
#Gender of Patient VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(df['gender'], hue = df['readmitted']).set_title("Gender of Patient VS. Readmission")
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gender of Patient VS. Readmission')

# %%
#Change of Medication VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(df['change'], hue = df['readmitted']).set_title('Change of Medication VS. Readmission')
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Change of Medication VS. Readmission')

# %%
#Diabetes Medication prescribed VS Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(df['diabetesMed'], hue = df['readmitted']).set_title('Diabetes Medication prescribed VS Readmission')
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Diabetes Medication prescribed VS Readmission')

# %%
#Service Utilization VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.barplot( y = df['service_utilization'], x = df['readmitted']).set_title('Service Utilization VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Service Utilization VS. Readmission')

# %%
#Glucose test serum test result VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(y = df['max_glu_serum'], hue = df['readmitted']).set_title('Glucose test serum test result VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Glucose test serum test result VS. Readmission')

# %%
#A1C test result VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(y= df['A1Cresult'], hue = df['readmitted']).set_title('A1C test result VS. Readmission')
# Out:
# Text(0.5, 1.0, 'A1C test result VS. Readmission')

# %%
#Number of lab procedure VS. Readmission
fig = plt.figure(figsize=(15,6),)
ax=sns.kdeplot(df.loc[(df['readmitted'] == 0),'num_lab_procedures'] , color='b',shade=True,label='Not readmitted')
ax=sns.kdeplot(df.loc[(df['readmitted'] == 1),'num_lab_procedures'] , color='r',shade=True, label='readmitted')
ax.set(xlabel='Number of lab procedure', ylabel='Frequency')
plt.title('Number of lab procedure VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Number of lab procedure VS. Readmission')

# %%
#Pre-Modeling Data Preprocessing
df['age'] = df['age'].astype('int64')
print(df.age.value_counts())
# convert age categories to mid-point values
age_dict = {1:5, 2:15, 3:25, 4:35, 5:45, 6:55, 7:65, 8:75, 9:85, 10:95}
df['age'] = df.age.map(age_dict)
print(df.age.value_counts())
# Out:
# 8     24815
# 7     21521
# 6     16546
# 9     16223
# 5      9208
# 4      3538
# 10     2594
# 3      1471
# 2       466
# 1        64
# Name: age, dtype: int64
# 75    24815
# 65    21521
# 55    16546
# 85    16223
# 45     9208
# 35     3538
# 95     2594
# 25     1471
# 15      466
# 5        64
# Name: age, dtype: int64

# %%
# convert data type of nominal features in dataframe to 'object' type
i = ['encounter_id', 'patient_nbr', 'gender', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id',\
          'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', \
          'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose','miglitol', \
          'troglitazone', 'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin', \
          'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed', \
          'age', 'A1Cresult', 'max_glu_serum', 'level1_diag1', 'level1_diag2', 'level1_diag3', 'level2_diag1', 'level2_diag2', 'level2_diag3']

df[i] = df[i].astype('object')

# %%
df.dtypes
# Out:
# encounter_id                object
# patient_nbr                 object
# race                        object
# gender                      object
# age                         object
# admission_type_id           object
# discharge_disposition_id    object
# admission_source_id         object
# time_in_hospital             int64
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                   int64
# service_utilization          int64
# numchange                    int64
# level1_diag1                object
# level2_diag1                object
# level1_diag2                object
# level2_diag2                object
# level1_diag3                object
# level2_diag3                object
# dtype: object

# %%
df['nummed'] = 0

for col in keys:
    df['nummed'] = df['nummed'] + df[col]
df['nummed'].value_counts()
# Out:
# 1    44589
# 0    22156
# 2    20901
# 3     7448
# 4     1290
# 5       57
# 6        5
# Name: nummed, dtype: int64

# %%
# get list of only numeric features
num_col = list(set(list(df._get_numeric_data().columns))- {'readmitted'})
num_col
# Out:
# ['number_inpatient',
#  'service_utilization',
#  'num_lab_procedures',
#  'number_emergency',
#  'time_in_hospital',
#  'number_diagnoses',
#  'numchange',
#  'num_procedures',
#  'number_outpatient',
#  'num_medications']

# %%
# Removing skewnewss and kurtosis using log transformation if it is above a threshold value -  2

statdataframe = pd.DataFrame()
statdataframe['numeric_column'] = num_col
skew_before = []
skew_after = []

kurt_before = []
kurt_after = []

standard_deviation_before = []
standard_deviation_after = []

log_transform_needed = []

log_type = []

for i in num_col:
    skewval = df[i].skew()
    skew_before.append(skewval)
    
    kurtval = df[i].kurtosis()
    kurt_before.append(kurtval)
    
    sdval = df[i].std()
    standard_deviation_before.append(sdval)
    
    if (abs(skewval) >2) & (abs(kurtval) >2):
        log_transform_needed.append('Yes')
        
        if len(df[df[i] == 0])/len(df) <=0.02:
            log_type.append('log')
            skewvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).skew()
            skew_after.append(skewvalnew)
            
            kurtvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).kurtosis()
            kurt_after.append(kurtvalnew)
            
            sdvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).std()
            standard_deviation_after.append(sdvalnew)
            
        else:
            log_type.append('log1p')
            skewvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).skew()
            skew_after.append(skewvalnew)
        
            kurtvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).kurtosis()
            kurt_after.append(kurtvalnew)
            
            sdvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).std()
            standard_deviation_after.append(sdvalnew)
            
    else:
        log_type.append('NA')
        log_transform_needed.append('No')
        
        skew_after.append(skewval)
        kurt_after.append(kurtval)
        standard_deviation_after.append(sdval)

statdataframe['skew_before'] = skew_before
statdataframe['kurtosis_before'] = kurt_before
statdataframe['standard_deviation_before'] = standard_deviation_before
statdataframe['log_transform_needed'] = log_transform_needed
statdataframe['log_type'] = log_type
statdataframe['skew_after'] = skew_after
statdataframe['kurtosis_after'] = kurt_after
statdataframe['standard_deviation_after'] = standard_deviation_after

# %%
statdataframe
# Out:
#         numeric_column  skew_before  kurtosis_before  \
# 0     number_inpatient     3.566269        20.044813
# 1  service_utilization     5.312374        67.194018
# 2   num_lab_procedures    -0.240626        -0.253275
# 3     number_emergency    22.695921      1165.140400
# 4     time_in_hospital     1.127510         0.839050
# 5     number_diagnoses    -0.807741        -0.372558
# 6            numchange     1.426548         1.451898
# 7       num_procedures     1.313236         0.856100
# 8    number_outpatient     8.767489       146.244961
# 9      num_medications     1.339187         3.549325
#
#    standard_deviation_before log_transform_needed log_type  skew_after  \
# 0                   1.269975                  Yes    log1p    1.425127
# 1                   2.315789                  Yes    log1p    1.097244
# 2                  19.656782                   No       NA   -0.240626
# 3                   0.948089                  Yes    log1p    3.614471
# 4                   2.982330                   No       NA    1.127510
# 5                   1.836659                   No       NA   -0.807741
# 6                   0.488614                   No       NA    1.426548
# 7                   1.703183                   No       NA    1.313236
# 8                   1.280061                  Yes    log1p    2.708627
# 9                   8.072516                   No       NA    1.339187
#
#    kurtosis_after  standard_deviation_after
# 0        1.319186                  0.513389
# 1        0.497241                  0.665656
# 2       -0.253275                 19.656782
# 3       15.854105                  0.318742
# 4        0.839050                  2.982330
# 5       -0.372558                  1.836659
# 6        1.451898                  0.488614
# 7        0.856100                  1.703183
# 8        7.648535                  0.432949
# 9        3.549325                  8.072516

# %%
# performing the log transformation for the columns determined to be needing it above.

for i in range(len(statdataframe)):
    if statdataframe['log_transform_needed'][i] == 'Yes':
        colname = str(statdataframe['numeric_column'][i])
        
        if statdataframe['log_type'][i] == 'log':
            df = df[df[colname] > 0]
            df[colname + "_log"] = np.log(df[colname])
            
        elif statdataframe['log_type'][i] == 'log1p':
            df = df[df[colname] >= 0]
            df[colname + "_log1p"] = np.log1p(df[colname])

# %%
df = df.drop(['number_outpatient', 'number_inpatient', 'number_emergency','service_utilization'], axis = 1)

# %%
df.shape
# Out:
# (96446, 54)

# %%
# get list of only numeric features
numerics = list(set(list(df._get_numeric_data().columns))- {'readmitted'})
numerics
# Out:
# ['service_utilization_log1p',
#  'num_lab_procedures',
#  'number_inpatient_log1p',
#  'time_in_hospital',
#  'number_diagnoses',
#  'numchange',
#  'num_procedures',
#  'number_outpatient_log1p',
#  'number_emergency_log1p',
#  'num_medications']

# %%
# show list of features that are categorical
df.encounter_id = df.encounter_id.astype('int64')
df.patient_nbr = df.patient_nbr.astype('int64')
df.diabetesMed = df.diabetesMed.astype('int64')
df.change = df.change.astype('int64')

# convert data type of nominal features in dataframe to 'object' type for aggregating
i = ['metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', \
          'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose','miglitol', \
          'troglitazone', 'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin', \
          'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone','A1Cresult']
df[i] = df[i].astype('int64')

df.dtypes
# Out:
# encounter_id                   int64
# patient_nbr                    int64
# race                          object
# gender                        object
# age                           object
# admission_type_id             object
# discharge_disposition_id      object
# admission_source_id           object
# time_in_hospital               int64
# num_lab_procedures             int64
# num_procedures                 int64
# num_medications                int64
# diag_1                        object
# diag_2                        object
# diag_3                        object
# number_diagnoses               int64
# max_glu_serum                 object
# A1Cresult                      int64
# metformin                      int64
# repaglinide                    int64
# nateglinide                    int64
# chlorpropamide                 int64
# glimepiride                    int64
# acetohexamide                  int64
# glipizide                      int64
# glyburide                      int64
# tolbutamide                    int64
# pioglitazone                   int64
# rosiglitazone                  int64
# acarbose                       int64
# miglitol                       int64
# troglitazone                   int64
# tolazamide                     int64
# insulin                        int64
# glyburide-metformin            int64
# glipizide-metformin            int64
# glimepiride-pioglitazone       int64
# metformin-rosiglitazone        int64
# metformin-pioglitazone         int64
# change                         int64
# diabetesMed                    int64
# readmitted                     int64
# numchange                      int64
# level1_diag1                  object
# level2_diag1                  object
# level1_diag2                  object
# level2_diag2                  object
# level1_diag3                  object
# level2_diag3                  object
# nummed                        object
# number_inpatient_log1p       float64
# service_utilization_log1p    float64
# number_emergency_log1p       float64
# number_outpatient_log1p      float64
# dtype: object

# %%
dfcopy = df.copy(deep = True)

# %%
df['readmitted'] = df['readmitted'].apply(lambda x: 0 if x == 2 else x)

# %%
# drop individual diagnosis columns that have too granular disease information
# also drop level 2 categorization (which was not comparable with any reference)
# also drop level 1 secondary and tertiary diagnoses
df.drop(['diag_1', 'diag_2', 'diag_3', 'level2_diag1', 'level1_diag2', 'level2_diag2', 'level1_diag3', 'level2_diag3'], axis=1, inplace=True)

# %%
interactionterms = [('num_medications','time_in_hospital'),
('num_medications','num_procedures'),
('time_in_hospital','num_lab_procedures'),
('num_medications','num_lab_procedures'),
('num_medications','number_diagnoses'),
('age','number_diagnoses'),
('change','num_medications'),
('number_diagnoses','time_in_hospital'),
('num_medications','numchange')]

# %%
for inter in interactionterms:
    name = inter[0] + '|' + inter[1]
    df[name] = df[inter[0]] * df[inter[1]]

# %%
df[['num_medications','time_in_hospital', 'num_medications|time_in_hospital']].head()
# Out:
#    num_medications  time_in_hospital  num_medications|time_in_hospital
# 1               18                 3                                54
# 2               13                 2                                26
# 3               16                 2                                32
# 4                8                 1                                 8
# 5               16                 3                                48

# %%
# Feature Scaling
datf = pd.DataFrame()
datf['features'] = numerics
datf['std_dev'] = datf['features'].apply(lambda x: df[x].std())
datf['mean'] = datf['features'].apply(lambda x: df[x].mean())

# %%
# dropping multiple encounters while keeping either first or last encounter of these patients
df2 = df.drop_duplicates(subset= ['patient_nbr'], keep = 'first')
df2.shape
# Out:
# (67580, 55)

# %%
# standardize function
def standardize(raw_data):
    return ((raw_data - np.mean(raw_data, axis = 0)) / np.std(raw_data, axis = 0))

# %%
df2[numerics] = standardize(df2[numerics])
import scipy as sp
df2 = df2[(np.abs(sp.stats.zscore(df2[numerics])) < 3).all(axis=1)]
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
from matplotlib.colors import ListedColormap
my_cmap = ListedColormap(sns.light_palette((250, 100, 50), input="husl", n_colors=50).as_hex())
table = df2.drop(['patient_nbr', 'encounter_id'], axis=1).corr(method='pearson')
table.style.background_gradient(cmap=my_cmap, axis = 0)
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\pandas\io\formats\style.py:1264: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\91944\anaconda3\lib\site-packages\pandas\io\formats\style.py:1265: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# #T_aa417_row0_col0,#T_aa417_row1_col1,#T_aa417_row2_col2,#T_aa417_row3_col3,#T_aa417_row4_col4,#T_aa417_row5_col5,#T_aa417_row6_col6,#T_aa417_row7_col7,#T_aa417_row8_col8,#T_aa417_row9_col9,#T_aa417_row10_col10,#T_aa417_row12_col12,#T_aa417_row13_col13,#T_aa417_row14_col14,#T_aa417_row15_col15,#T_aa417_row16_col16,#T_aa417_row17_col17,#T_aa417_row18_col18,#T_aa417_row19_col19,#T_aa417_row20_col20,#T_aa417_row21_col21,#T_aa417_row22_col22,#T_aa417_row23_col23,#T_aa417_row26_col26,#T_aa417_row27_col27,#T_aa417_row28_col28,#T_aa417_row29_col29,#T_aa417_row30_col30,#T_aa417_row31_col31,#T_aa417_row32_col32,#T_aa417_row33_col33,#T_aa417_row34_col34,#T_aa417_row35_col35,#T_aa417_row36_col36,#T_aa417_row37_col37,#T_aa417_row38_col38,#T_aa417_row39_col39,#T_aa417_row40_col40,#T_aa417_row41_col41,#T_aa417_row42_col42{
#             background-color:  #007ad1;
#             color:  #f1f1f1;
#         }#T_aa417_row0_col1,#T_aa417_row1_col41,#T_aa417_row28_col6,#T_aa417_row40_col6,#T_aa417_row41_col1{
#             background-color:  #9dc8e7;
#             color:  #000000;
#         }#T_aa417_row0_col2,#T_aa417_row1_col4,#T_aa417_row2_col41,#T_aa417_row4_col1,#T_aa417_row5_col38,#T_aa417_row12_col40,#T_aa417_row13_col6,#T_aa417_row16_col40,#T_aa417_row21_col3,#T_aa417_row21_col38,#T_aa417_row27_col38,#T_aa417_row28_col3,#T_aa417_row28_col10,#T_aa417_row30_col3,#T_aa417_row30_col35,#T_aa417_row30_col37,#T_aa417_row30_col39,#T_aa417_row35_col30,#T_aa417_row37_col2,#T_aa417_row38_col27,#T_aa417_row40_col4,#T_aa417_row40_col10,#T_aa417_row41_col2,#T_aa417_row42_col1{
#             background-color:  #c4dbec;
#             color:  #000000;
#         }#T_aa417_row0_col3,#T_aa417_row3_col0,#T_aa417_row3_col37,#T_aa417_row21_col30,#T_aa417_row28_col40,#T_aa417_row37_col3,#T_aa417_row40_col28,#T_aa417_row42_col21{
#             background-color:  #85bbe4;
#             color:  #000000;
#         }#T_aa417_row0_col4,#T_aa417_row1_col39,#T_aa417_row2_col35,#T_aa417_row3_col1,#T_aa417_row27_col15,#T_aa417_row27_col16,#T_aa417_row36_col40,#T_aa417_row37_col4,#T_aa417_row40_col12,#T_aa417_row40_col37,#T_aa417_row40_col41,#T_aa417_row42_col37,#T_aa417_row42_col41{
#             background-color:  #b1d1ea;
#             color:  #000000;
#         }#T_aa417_row0_col5,#T_aa417_row0_col12,#T_aa417_row0_col27,#T_aa417_row1_col12,#T_aa417_row1_col13,#T_aa417_row2_col12,#T_aa417_row2_col13,#T_aa417_row2_col40,#T_aa417_row3_col10,#T_aa417_row3_col16,#T_aa417_row4_col2,#T_aa417_row5_col6,#T_aa417_row5_col12,#T_aa417_row5_col13,#T_aa417_row5_col27,#T_aa417_row5_col42,#T_aa417_row6_col10,#T_aa417_row6_col15,#T_aa417_row10_col6,#T_aa417_row10_col15,#T_aa417_row15_col6,#T_aa417_row15_col10,#T_aa417_row16_col10,#T_aa417_row17_col13,#T_aa417_row18_col12,#T_aa417_row23_col13,#T_aa417_row27_col0,#T_aa417_row27_col1,#T_aa417_row27_col4,#T_aa417_row28_col5,#T_aa417_row29_col4,#T_aa417_row29_col12,#T_aa417_row29_col13,#T_aa417_row30_col12,#T_aa417_row30_col13,#T_aa417_row31_col4,#T_aa417_row31_col12,#T_aa417_row31_col33,#T_aa417_row32_col12,#T_aa417_row32_col13,#T_aa417_row33_col4,#T_aa417_row33_col12,#T_aa417_row33_col21,#T_aa417_row33_col31,#T_aa417_row34_col12,#T_aa417_row34_col13,#T_aa417_row35_col5,#T_aa417_row36_col12,#T_aa417_row36_col13,#T_aa417_row37_col12,#T_aa417_row37_col13,#T_aa417_row37_col27,#T_aa417_row39_col10,#T_aa417_row39_col15,#T_aa417_row39_col16,#T_aa417_row39_col32,#T_aa417_row41_col5,#T_aa417_row41_col12,#T_aa417_row41_col13,#T_aa417_row41_col27,#T_aa417_row42_col12,#T_aa417_row42_col13{
#             background-color:  #d7e5ef;
#             color:  #000000;
#         }#T_aa417_row0_col6,#T_aa417_row0_col7,#T_aa417_row0_col15,#T_aa417_row0_col32,#T_aa417_row1_col15,#T_aa417_row1_col16,#T_aa417_row1_col28,#T_aa417_row1_col32,#T_aa417_row3_col7,#T_aa417_row3_col8,#T_aa417_row3_col29,#T_aa417_row4_col5,#T_aa417_row4_col7,#T_aa417_row4_col16,#T_aa417_row4_col27,#T_aa417_row4_col29,#T_aa417_row6_col21,#T_aa417_row6_col32,#T_aa417_row7_col0,#T_aa417_row7_col1,#T_aa417_row7_col2,#T_aa417_row7_col30,#T_aa417_row7_col31,#T_aa417_row7_col32,#T_aa417_row7_col34,#T_aa417_row7_col37,#T_aa417_row7_col39,#T_aa417_row7_col42,#T_aa417_row8_col1,#T_aa417_row8_col2,#T_aa417_row8_col5,#T_aa417_row8_col31,#T_aa417_row8_col32,#T_aa417_row8_col34,#T_aa417_row8_col41,#T_aa417_row9_col1,#T_aa417_row9_col2,#T_aa417_row9_col4,#T_aa417_row9_col5,#T_aa417_row9_col6,#T_aa417_row9_col15,#T_aa417_row9_col21,#T_aa417_row9_col31,#T_aa417_row9_col32,#T_aa417_row10_col2,#T_aa417_row10_col3,#T_aa417_row10_col31,#T_aa417_row10_col32,#T_aa417_row10_col39,#T_aa417_row10_col41,#T_aa417_row12_col0,#T_aa417_row12_col2,#T_aa417_row12_col3,#T_aa417_row12_col4,#T_aa417_row12_col5,#T_aa417_row12_col21,#T_aa417_row12_col31,#T_aa417_row12_col32,#T_aa417_row12_col34,#T_aa417_row12_col37,#T_aa417_row12_col38,#T_aa417_row12_col39,#T_aa417_row13_col0,#T_aa417_row13_col1,#T_aa417_row13_col2,#T_aa417_row13_col3,#T_aa417_row13_col4,#T_aa417_row13_col5,#T_aa417_row13_col31,#T_aa417_row13_col32,#T_aa417_row13_col34,#T_aa417_row13_col37,#T_aa417_row13_col41,#T_aa417_row14_col1,#T_aa417_row14_col2,#T_aa417_row14_col5,#T_aa417_row14_col6,#T_aa417_row14_col15,#T_aa417_row14_col16,#T_aa417_row14_col21,#T_aa417_row14_col31,#T_aa417_row14_col32,#T_aa417_row15_col5,#T_aa417_row15_col8,#T_aa417_row15_col22,#T_aa417_row15_col33,#T_aa417_row15_col34,#T_aa417_row15_col36,#T_aa417_row15_col42,#T_aa417_row16_col3,#T_aa417_row16_col5,#T_aa417_row16_col7,#T_aa417_row16_col8,#T_aa417_row16_col31,#T_aa417_row16_col32,#T_aa417_row16_col34,#T_aa417_row16_col39,#T_aa417_row17_col1,#T_aa417_row17_col2,#T_aa417_row17_col5,#T_aa417_row17_col7,#T_aa417_row17_col21,#T_aa417_row17_col28,#T_aa417_row17_col32,#T_aa417_row17_col34,#T_aa417_row17_col40,#T_aa417_row18_col1,#T_aa417_row18_col2,#T_aa417_row18_col5,#T_aa417_row18_col7,#T_aa417_row18_col31,#T_aa417_row18_col32,#T_aa417_row18_col33,#T_aa417_row18_col34,#T_aa417_row19_col1,#T_aa417_row19_col2,#T_aa417_row19_col5,#T_aa417_row19_col31,#T_aa417_row19_col32,#T_aa417_row19_col37,#T_aa417_row19_col41,#T_aa417_row20_col1,#T_aa417_row20_col2,#T_aa417_row20_col4,#T_aa417_row20_col5,#T_aa417_row20_col21,#T_aa417_row20_col32,#T_aa417_row21_col2,#T_aa417_row21_col6,#T_aa417_row22_col2,#T_aa417_row22_col5,#T_aa417_row22_col6,#T_aa417_row22_col32,#T_aa417_row22_col40,#T_aa417_row23_col1,#T_aa417_row23_col2,#T_aa417_row23_col5,#T_aa417_row23_col32,#T_aa417_row23_col34,#T_aa417_row26_col1,#T_aa417_row26_col2,#T_aa417_row26_col5,#T_aa417_row26_col31,#T_aa417_row26_col32,#T_aa417_row27_col17,#T_aa417_row27_col31,#T_aa417_row29_col2,#T_aa417_row29_col3,#T_aa417_row29_col5,#T_aa417_row29_col6,#T_aa417_row29_col15,#T_aa417_row29_col28,#T_aa417_row29_col34,#T_aa417_row29_col35,#T_aa417_row29_col38,#T_aa417_row29_col39,#T_aa417_row30_col2,#T_aa417_row30_col7,#T_aa417_row30_col31,#T_aa417_row30_col34,#T_aa417_row31_col2,#T_aa417_row31_col6,#T_aa417_row31_col29,#T_aa417_row31_col35,#T_aa417_row31_col38,#T_aa417_row31_col39,#T_aa417_row32_col1,#T_aa417_row32_col3,#T_aa417_row32_col27,#T_aa417_row32_col28,#T_aa417_row32_col29,#T_aa417_row32_col30,#T_aa417_row32_col40,#T_aa417_row32_col42,#T_aa417_row33_col1,#T_aa417_row33_col27,#T_aa417_row33_col28,#T_aa417_row33_col30,#T_aa417_row33_col41,#T_aa417_row33_col42,#T_aa417_row34_col27,#T_aa417_row34_col28,#T_aa417_row34_col39,#T_aa417_row35_col7,#T_aa417_row36_col5,#T_aa417_row36_col6,#T_aa417_row36_col31,#T_aa417_row37_col7,#T_aa417_row37_col15,#T_aa417_row37_col16,#T_aa417_row37_col29,#T_aa417_row37_col32,#T_aa417_row38_col7,#T_aa417_row38_col29,#T_aa417_row38_col33,#T_aa417_row39_col7,#T ...
#             background-color:  #e6ecf1;
#             color:  #000000;
#         }#T_aa417_row0_col8,#T_aa417_row0_col22,#T_aa417_row0_col33,#T_aa417_row1_col7,#T_aa417_row1_col29,#T_aa417_row1_col33,#

# %%
df2['level1_diag1'] = df2['level1_diag1'].astype('object')
df_pd = pd.get_dummies(df2, columns=['gender', 'admission_type_id', 'discharge_disposition_id',
                                      'admission_source_id', 'max_glu_serum', 'A1Cresult', 'level1_diag1'], drop_first = True)
just_dummies = pd.get_dummies(df_pd['race'])
df_pd = pd.concat([df_pd, just_dummies], axis=1)      
df_pd.drop(['race'], inplace=True, axis=1)
df
# Out:
#         encounter_id  patient_nbr             race gender age  \
# 1             149190     55629189        Caucasian      0  15
# 2              64410     86047875  AfricanAmerican      0  25
# 3             500364     82442376        Caucasian      1  35
# 4              16680     42519267        Caucasian      1  45
# 5              35754     82637451        Caucasian      1  55
# ...              ...          ...              ...    ...  ..
# 101761     443847548    100162476  AfricanAmerican      1  75
# 101762     443847782     74694222  AfricanAmerican      0  85
# 101763     443854148     41088789        Caucasian      1  75
# 101764     443857166     31693671        Caucasian      0  85
# 101765     443867222    175429310        Caucasian      1  75
#
#        admission_type_id discharge_disposition_id admission_source_id  \
# 1                      1                        1                   7
# 2                      1                        1                   7
# 3                      1                        1                   7
# 4                      1                        1                   7
# 5                      1                        1                   1
# ...                  ...                      ...                 ...
# 101761                 1                        2                   7
# 101762                 1                        2                   4
# 101763                 1                        1                   7
# 101764                 1                        2                   7
# 101765                 1                        1                   7
#
#         time_in_hospital  num_lab_procedures  ...  number_outpatient_log1p  \
# 1                      3                  59  ...                 0.000000
# 2                      2                  11  ...                 1.098612
# 3                      2                  44  ...                 0.000000
# 4                      1                  51  ...                 0.000000
# 5                      3                  31  ...                 0.000000
# ...                  ...                 ...  ...                      ...
# 101761                 3                  51  ...                 0.000000
# 101762                 5                  33  ...                 0.000000
# 101763                 1                  53  ...                 0.693147
# 101764                10                  45  ...                 0.000000
# 101765                 6                  13  ...                 0.000000
#
#         num_medications|time_in_hospital  num_medications|num_procedures  \
# 1                                     54                               0
# 2                                     26                              65
# 3                                     32                              16
# 4                                      8                               0
# 5                                     48                              96
# ...                                  ...                             ...
# 101761                                48                               0
# 101762                                90                              54
# 101763                                 9                               0
# 101764                               210                              42
# 101765                                18                               9
#
#        time_in_hospital|num_lab_procedures  \
# 1                                      177
# 2                                       22
# 3                                       88
# 4                                       51
# 5                                       93
# ...                                    ...
# 101761                                 153
# 101762                                 165
# 101763                                  53
# 101764                                 450
# 101765                                  78
#
#         num_medications|num_lab_procedures  num_medications|number_diagnoses  \
# 1                                     1062                               162
# 2                                      143                                78
# 3                                      704                               112
# 4                                      408                                40
# 5                                      496                               144
# ...                                    ...                               ...
# 101761                                 816                               144
# 101762                                 594                               162
# 101763                                 477                               117
# 101764                                 945                               189
# 101765                                  39                                27
#
#         age|number_diagnoses  change|num_medications  \
# 1                        135                      18
# 2                        150                       0
# 3                        245                      16
# 4                        225                       8
# 5                        495                       0
# ...                      ...                     ...
# 101761                   675                      16
# 101762                   765                       0
# 101763                   975                       9
# 101764                   765                      21
# 101765                   675                       0
#
#         number_diagnoses|time_in_hospital  num_medications|numchange
# 1                                      27                         18
# 2                                      12                          0
# 3                                      14                         16
# 4                                       5                          0
# 5                                      27                          0
# ...                                   ...                        ...
# 101761                                 27                         16
# 101762                                 45                          0
# 101763                                 13                          9
# 101764                                 90                         21
# 101765                                 54                          0
#
# [96446 rows x 55 columns]

# %%
non_num_cols = ['race', 'gender', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'max_glu_serum', 'A1Cresult', 'level1_diag1' ]

# %%
num_cols = list(set(list(df._get_numeric_data().columns))- {'readmitted', 'change'})
num_cols
# Out:
# ['num_medications|numchange',
#  'insulin',
#  'metformin-rosiglitazone',
#  'num_medications|num_procedures',
#  'tolazamide',
#  'number_diagnoses',
#  'num_medications|time_in_hospital',
#  'num_procedures',
#  'repaglinide',
#  'num_medications',
#  'service_utilization_log1p',
#  'metformin-pioglitazone',
#  'num_medications|number_diagnoses',
#  'glimepiride',
#  'encounter_id',
#  'num_lab_procedures',
#  'number_inpatient_log1p',
#  'time_in_hospital',
#  'number_diagnoses|time_in_hospital',
#  'acetohexamide',
#  'rosiglitazone',
#  'numchange',
#  'number_emergency_log1p',
#  'diabetesMed',
#  'glipizide-metformin',
#  'patient_nbr',
#  'chlorpropamide',
#  'glyburide',
#  'time_in_hospital|num_lab_procedures',
#  'glipizide',
#  'miglitol',
#  'acarbose',
#  'glyburide-metformin',
#  'change|num_medications',
#  'troglitazone',
#  'pioglitazone',
#  'nateglinide',
#  'metformin',
#  'num_medications|num_lab_procedures',
#  'A1Cresult',
#  'tolbutamide',
#  'glimepiride-pioglitazone',
#  'number_outpatient_log1p']

# %%
new_non_num_cols = []
for i in non_num_cols:
    for j in df_pd.columns:
        if i in j:
            new_non_num_cols.append(j)

# %%
new_non_num_cols
# Out:
# ['gender_1',
#  'admission_type_id_3',
#  'admission_type_id_4',
#  'admission_type_id_5',
#  'discharge_disposition_id_2',
#  'discharge_disposition_id_7',
#  'discharge_disposition_id_10',
#  'discharge_disposition_id_18',
#  'discharge_disposition_id_19',
#  'discharge_disposition_id_20',
#  'discharge_disposition_id_27',
#  'discharge_disposition_id_28',
#  'admission_source_id_4',
#  'admission_source_id_7',
#  'admission_source_id_8',
#  'admission_source_id_9',
#  'admission_source_id_11',
#  'max_glu_serum_0',
#  'max_glu_serum_1',
#  'A1Cresult_0',
#  'A1Cresult_1',
#  'level1_diag1_1.0',
#  'level1_diag1_2.0',
#  'level1_diag1_3.0',
#  'level1_diag1_4.0',
#  'level1_diag1_5.0',
#  'level1_diag1_6.0',
#  'level1_diag1_7.0',
#  'level1_diag1_8.0']

# %%
l = []
for feature in list(df_pd.columns):
    if '|' in feature:
        l.append(feature)
l
# Out:
# ['num_medications|time_in_hospital',
#  'num_medications|num_procedures',
#  'time_in_hospital|num_lab_procedures',
#  'num_medications|num_lab_procedures',
#  'num_medications|number_diagnoses',
#  'age|number_diagnoses',
#  'change|num_medications',
#  'number_diagnoses|time_in_hospital',
#  'num_medications|numchange']

# %%
df_pd.head().T
# Out:
#                            1         2         3         4         5
# encounter_id          149190     64410    500364     16680     35754
# patient_nbr         55629189  86047875  82442376  42519267  82637451
# age                       15        25        35        45        55
# time_in_hospital   -0.444872 -0.784109 -0.784109 -1.123345 -0.444872
# num_lab_procedures  0.803605  -1.60206  0.051835  0.402661   -0.5997
# ...                      ...       ...       ...       ...       ...
# AfricanAmerican            0         1         0         0         0
# Asian                      0         0         0         0         0
# Caucasian                  1         0         1         1         1
# Hispanic                   0         0         0         0         0
# Other                      0         0         0         0         0
#
# [81 rows x 5 columns]

# %%
feature_set = ['age', 'time_in_hospital', 'num_procedures', 'num_medications', 'number_outpatient_log1p', 
                 'number_emergency_log1p', 'number_inpatient_log1p', 'number_diagnoses', 'metformin', 
                 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 'glyburide',
                 'pioglitazone', 'rosiglitazone', 'acarbose', 'tolazamide', 'insulin', 'glyburide-metformin',
                 'AfricanAmerican', 'Asian', 'Caucasian', 'Hispanic', 'Other', 'gender_1', 
                 'admission_type_id_3', 'admission_type_id_5', 'discharge_disposition_id_2', 'discharge_disposition_id_7', 
                 'discharge_disposition_id_10', 'discharge_disposition_id_18', 'admission_source_id_4',
                 'admission_source_id_7', 'admission_source_id_9', 'max_glu_serum_0', 'max_glu_serum_1', 'A1Cresult_0',
                 'A1Cresult_1', 'num_medications|time_in_hospital', 'num_medications|num_procedures',
                 'time_in_hospital|num_lab_procedures', 'num_medications|num_lab_procedures', 'num_medications|number_diagnoses',
                 'age|number_diagnoses', 'change|num_medications', 'number_diagnoses|time_in_hospital',
                 'num_medications|numchange', 'level1_diag1_1.0', 'level1_diag1_2.0', 'level1_diag1_3.0', 'level1_diag1_4.0',
                 'level1_diag1_5.0','level1_diag1_6.0', 'level1_diag1_7.0', 'level1_diag1_8.0']

# %%
X = df_pd[feature_set]
y = df_pd['readmitted']

# %%
df_pd['readmitted'].value_counts()
# Out:
# 0    54635
# 1     5071
# Name: readmitted, dtype: int64

# %%
#TRAINING - LOGIT
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
logit = LogisticRegression(fit_intercept=True)
logit.fit(X_train, y_train)
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#VALIDATION
#cross validation
from sklearn.model_selection import cross_val_score,KFold
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
kf=KFold(n_splits=5)
score=cross_val_score(logreg,X_train,y_train,cv=kf)
print("Cross Validation Scores are {}".format(score))
print("Average Cross Validation score :{}".format(score.mean()))
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross Validation Scores are [0.91332566 0.91500052 0.91280226 0.91918769 0.91488693]
# Average Cross Validation score :0.9150406131463346
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#TESTING
logit_pred = logit.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
# Out:
# Predict     0  1   All
# Actual
# 0        1465  1  1466
# 1         167  0   167
# All      1632  1  1633

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))
# Out:
# Accuracy is 0.91
# Precision is 0.00
# Recall is 0.00

# %%
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE
from collections import Counter
print('Original dataset shape {}'.format(Counter(y_train)))
sm = SMOTE(random_state=20)
train_input_new, train_output_new = sm.fit_resample(X_train, y_train)
print('New dataset shape {}'.format(Counter(train_output_new)))
# Out:
# Original dataset shape Counter({0: 43711, 1: 4053})
# New dataset shape Counter({0: 43711, 1: 43711})

# %%
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
logit = LogisticRegression(fit_intercept=True)
logit.fit(X_train, y_train)
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='warn',
          n_jobs=None, penalty='l1', random_state=None, solver='warn',
          tol=0.0001, verbose=0, warm_start=False)
# Out:
# LogisticRegression(multi_class='warn', penalty='l1', solver='warn')

# %%
logit_pred = logit.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
# Out:
# Predict     0     1   All
# Actual
# 0        1669  1487  3156
# 1         157   140   297
# All      1826  1627  3453

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))

accuracy_logit = accuracy_score(y_test, logit_pred)
precision_logit = precision_score(y_test, logit_pred)
recall_logit = recall_score(y_test, logit_pred)
# Out:
# Accuracy is 0.74
# Precision is 0.76
# Recall is 0.71

# %%
feature_set_no_int = ['age', 'time_in_hospital', 'num_procedures', 'num_medications', 'number_outpatient_log1p', 
                 'number_emergency_log1p', 'number_inpatient_log1p', 'number_diagnoses', 'metformin', 
                 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 
                 'glyburide', 'pioglitazone', 'rosiglitazone', 'acarbose', 
                 'tolazamide', 'insulin', 'glyburide-metformin',
                 'AfricanAmerican', 'Asian', 'Caucasian', 
                 'Hispanic', 'Other', 'gender_1', 
                 'admission_type_id_3', 'admission_type_id_5', 
                 'discharge_disposition_id_2', 'discharge_disposition_id_7', 
                 'discharge_disposition_id_10', 'discharge_disposition_id_18', 
                 'admission_source_id_4', 'admission_source_id_7', 
                 'admission_source_id_9', 'max_glu_serum_0', 
                 'max_glu_serum_1', 'A1Cresult_0', 'A1Cresult_1', 
                 'level1_diag1_1.0',
                 'level1_diag1_2.0',
                 'level1_diag1_3.0',
                 'level1_diag1_4.0',
                 'level1_diag1_5.0',
                 'level1_diag1_6.0',
                 'level1_diag1_7.0',
                 'level1_diag1_8.0']

# %%
X = df_pd[feature_set_no_int]
y = df_pd['readmitted']
df_pd['readmitted'].value_counts()
# Out:
# 0    54635
# 1     5071
# Name: readmitted, dtype: int64

# %%
print('Original dataset shape {}'.format(Counter(y)))
smt = SMOTE(random_state=20)
train_input_new, train_output_new = smt.fit_resample(X, y)
print('New dataset shape {}'.format(Counter(train_output_new)))
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
# Out:
# Original dataset shape Counter({0: 54635, 1: 5071})
# New dataset shape Counter({0: 54635, 1: 54635})

# %%
#TRAINING - DECISION TREE
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=28, criterion = "entropy", min_samples_split=10)
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=28, min_samples_split=10)

# %%
#VALIDATION
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold, cross_val_score
clf = DecisionTreeClassifier(random_state=42)
k_folds = KFold(n_splits = 5)
scores = cross_val_score(clf, X_train, y_train, cv = k_folds)
print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.88972775 0.88668993 0.89012183 0.88989304 0.89338214]
# Average CV Score:  0.889962938537424
# Number of CV Scores used in Average:  5

# %%
#TESTING
dtree_pred = dtree.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(dtree_pred, name = 'Predict'), margins = True)
# Out:
# Predict     0     1   All
# Actual
# 0        2103  1870  3973
# 1         219   201   420
# All      2322  2071  4393

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, dtree_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, dtree_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, dtree_pred)))

accuracy_dtree = accuracy_score(y_test, dtree_pred)
precision_dtree = precision_score(y_test, dtree_pred)
recall_dtree = recall_score(y_test, dtree_pred)
# Out:
# Accuracy is 0.89
# Precision is 0.91
# Recall is 0.87

# %%
feature_set_no_int = ['age', 'time_in_hospital', 'num_procedures', 'num_medications', 'number_outpatient_log1p', 
                 'number_emergency_log1p', 'number_inpatient_log1p', 'number_diagnoses', 'metformin', 
                 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 
                 'glyburide', 'pioglitazone', 'rosiglitazone', 'acarbose', 
                 'tolazamide', 'insulin', 'glyburide-metformin',
                 'AfricanAmerican', 'Asian', 'Caucasian', 
                 'Hispanic', 'Other', 'gender_1', 
                 'admission_type_id_3', 'admission_type_id_5', 
                 'discharge_disposition_id_2', 'discharge_disposition_id_7', 
                 'discharge_disposition_id_10', 'discharge_disposition_id_18', 
                 'admission_source_id_4', 'admission_source_id_7', 
                 'admission_source_id_9', 'max_glu_serum_0', 
                 'max_glu_serum_1', 'A1Cresult_0', 'A1Cresult_1', 
                 'level1_diag1_1.0',
                 'level1_diag1_2.0',
                 'level1_diag1_3.0',
                 'level1_diag1_4.0',
                 'level1_diag1_5.0',
                 'level1_diag1_6.0',
                 'level1_diag1_7.0',
                 'level1_diag1_8.0']

# %%
X = df_pd[feature_set_no_int]
y = df_pd['readmitted']
df_pd['readmitted'].value_counts()
# Out:
# 0    54635
# 1     5071
# Name: readmitted, dtype: int64

# %%
print('Original dataset shape {}'.format(Counter(y)))
smt = SMOTE(random_state=20)
train_input_new, train_output_new = smt.fit_resample(X, y)
print('New dataset shape {}'.format(Counter(train_output_new)))
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
# Out:
# Original dataset shape Counter({0: 54635, 1: 5071})
# New dataset shape Counter({0: 54635, 1: 54635})

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=28, criterion = "entropy", min_samples_split=10)
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=28, min_samples_split=10)

# %%
dtree_pred = dtree.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(dtree_pred, name = 'Predict'), margins = True)
# Out:
# Predict     0     1   All
# Actual
# 0        2112  1861  3973
# 1         215   205   420
# All      2327  2066  4393

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, dtree_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, dtree_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, dtree_pred)))

accuracy_dtree = accuracy_score(y_test, dtree_pred)
precision_dtree = precision_score(y_test, dtree_pred)
recall_dtree = recall_score(y_test, dtree_pred)
# Out:
# Accuracy is 0.89
# Precision is 0.91
# Recall is 0.87

# %%
# Create list of top most features based on importance
feature_names = X_train.columns
feature_imports = dtree.feature_importances_
most_imp_features = pd.DataFrame([f for f in zip(feature_names,feature_imports)], columns=["Feature", "Importance"]).nlargest(10, "Importance")
most_imp_features.sort_values(by="Importance", inplace=True)
print(most_imp_features)
plt.figure(figsize=(10,6))
plt.barh(range(len(most_imp_features)), most_imp_features.Importance, align='center', alpha=0.8)
plt.yticks(range(len(most_imp_features)), most_imp_features.Feature, fontsize=14)
plt.xlabel('Importance')
plt.title('Most important features - Decision Tree')
plt.show()
# Out:
#                        Feature  Importance
# 4      number_outpatient_log1p    0.008459
# 8                    metformin    0.009023
# 19                     insulin    0.009099
# 29  discharge_disposition_id_2    0.009408
# 26                    gender_1    0.010607
# 0                          age    0.032486
# 7             number_diagnoses    0.059365
# 2               num_procedures    0.080276
# 3              num_medications    0.083083
# 1             time_in_hospital    0.562107

# %%
X = df_pd[feature_set_no_int]
y = df_pd['readmitted']

print('Original dataset shape {}'.format(Counter(y)))
smt = SMOTE(random_state=20)
train_input_new, train_output_new = smt.fit_resample(X, y)
print('New dataset shape {}'.format(Counter(train_output_new)))
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
# Out:
# Original dataset shape Counter({0: 54635, 1: 5071})
# New dataset shape Counter({0: 54635, 1: 54635})

# %%
#TRAINING - RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
rm = RandomForestClassifier(n_estimators = 10, max_depth=25, criterion = "gini", min_samples_split=10)
rm.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=25, min_samples_split=10, n_estimators=10)

# %%
#VALIDATION - RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, cross_val_score
clf = RandomForestClassifier()
k_folds = KFold(n_splits = 5)
scores = cross_val_score(clf, X_train, y_train, cv = k_folds)
print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.93571265 0.93445061 0.93696734 0.93439341 0.93936967]
# Average CV Score:  0.9361787369141272
# Number of CV Scores used in Average:  5

# %%
#TESTING - RANDOM FOREST
rm_prd = rm.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(rm_prd, name = 'Predict'), margins = True)
# Out:
# Predict     0     1   All
# Actual
# 0        1898  2075  3973
# 1         208   212   420
# All      2106  2287  4393

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, rm_prd)))
print("Precision is {0:.2f}".format(precision_score(y_test, rm_prd)))
print("Recall is {0:.2f}".format(recall_score(y_test, rm_prd)))

accuracy_rm = accuracy_score(y_test, rm_prd)
precision_rm = precision_score(y_test, rm_prd)
recall_rm = recall_score(y_test, rm_prd)
# Out:
# Accuracy is 0.88
# Precision is 0.87
# Recall is 0.90

# %%
# Create list of top most features based on importance
feature_names = X_train.columns
feature_imports = rm.feature_importances_
most_imp_features = pd.DataFrame([f for f in zip(feature_names,feature_imports)], columns=["Feature", "Importance"]).nlargest(10, "Importance")
most_imp_features.sort_values(by="Importance", inplace=True)
plt.figure(figsize=(10,6))
plt.barh(range(len(most_imp_features)), most_imp_features.Importance, align='center', alpha=0.8)
plt.yticks(range(len(most_imp_features)), most_imp_features.Feature, fontsize=14)
plt.xlabel('Importance')
plt.title('Most important features - Random Forest ')
plt.show()

# %%
plt.figure(figsize=(14, 7))
ax = plt.subplot(111)

models = ['Logistic Regression', 'Decision Tree', 'Random Forests']
values = [accuracy_logit, accuracy_dtree, accuracy_rm]
model = np.arange(len(models))

plt.bar(model, values, align='center', width = 0.15, alpha=0.7, color = 'red', label= 'accuracy')
plt.xticks(model, models)
           

           
ax = plt.subplot(111)

models = ['Logistic Regression', 'Decision Tree', 'Random Forests']
values = [precision_logit, precision_dtree, precision_rm]
model = np.arange(len(models))

plt.bar(model+0.15, values, align='center', width = 0.15, alpha=0.7, color = 'blue', label = 'precision')
plt.xticks(model, models)



ax = plt.subplot(111)

models = ['Logistic Regression', 'Decision Tree', 'Random Forests' ]
values = [recall_logit, recall_dtree, recall_rm, ]
model = np.arange(len(models))

plt.bar(model+0.3, values, align='center', width = 0.15, alpha=0.7, color = 'green', label = 'recall')
plt.xticks(model, models)



plt.ylabel('Performance Metrics for Different models')
plt.title('Model')
    
# removing the axis on the top and right of the plot window
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.legend()

plt.show()
# Out:
# <ipython-input-240-a1f6da031ada>:13: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(111)
# <ipython-input-240-a1f6da031ada>:24: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(111)

# %%
# Linear Classifier
from sklearn.metrics import accuracy_score,classification_report
from sklearn.svm import SVC

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
model_svm = SVC(kernel='rbf')

# %%
model_svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
#TRAINING - SVM
print ("\nSVM Linear Classifier - Train Confusion Matrix\n\n",pd.crosstab(y_train, model_svm.predict(X_train),rownames =["Actuall"],colnames = ["Predicted"]) )
print ("\nSVM Linear Classifier - Train accuracy:",round(accuracy_score(y_train, model_svm.predict(X_train)),3))
print ("\nSVM Linear Classifier - Train Classification Report\n", classification_report(y_train,model_svm.predict(X_train)))
# Out:
# SVM Linear Classifier - Train Confusion Matrix
#
#  Predicted      0
# Actuall
# 0          43711
# 1           4053
#
# SVM Linear Classifier - Train accuracy: 0.915
#
# SVM Linear Classifier - Train Classification Report
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     43711
#            1       0.00      0.00      0.00      4053
#
#     accuracy                           0.92     47764
#    macro avg       0.46      0.50      0.48     47764
# weighted avg       0.84      0.92      0.87     47764
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#VALIDATION - SVM
from sklearn.metrics import accuracy_score,classification_report
from sklearn.svm import SVC
from sklearn.model_selection import KFold, cross_val_score
clf = SVC(kernel='rbf')
k_folds = KFold(n_splits = 5)
scores = cross_val_score(clf, X_train, y_train, cv = k_folds)
print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.91332566 0.91520988 0.91280226 0.91939705 0.91499162]
# Average CV Score:  0.915145294496489
# Number of CV Scores used in Average:  5

# %%
#TESTING - SVM
print ("\n\nSVM Linear Classifier - Test Confusion Matrix\n\n",pd.crosstab(y_test, model_svm.predict(X_test),rownames = ["Actuall"],colnames = ["Predicted"]))
print ("\nSVM Linear Classifier - Test accuracy:",round(accuracy_score(y_test,model_svm.predict(X_test)),3))
print ("\nSVM Linear Classifier - Test Classification Report\n",classification_report(y_test,model_svm.predict(X_test)))
# Out:
# SVM Linear Classifier - Test Confusion Matrix
#
#  Predicted      0
# Actuall
# 0          10924
# 1           1018
#
# SVM Linear Classifier - Test accuracy: 0.915
#
# SVM Linear Classifier - Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.96     10924
#            1       0.00      0.00      0.00      1018
#
#     accuracy                           0.91     11942
#    macro avg       0.46      0.50      0.48     11942
# weighted avg       0.84      0.91      0.87     11942
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE
from collections import Counter
print('Original dataset shape {}'.format(Counter(y_train)))
sm = SMOTE(random_state=20)
train_input_new, train_output_new = sm.fit_resample(X_train, y_train)
print('New dataset shape {}'.format(Counter(train_output_new)))
# Out:
# Original dataset shape Counter({0: 43711, 1: 4053})
# New dataset shape Counter({0: 43711, 1: 43711})

# %%
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)

# %%
model_svm1 = SVC(kernel='rbf')

# %%
model_svm1.fit(X_train, y_train)
# Out:
# SVC()

# %%
print ("\nSVM Linear Classifier - Train Confusion Matrix\n\n",pd.crosstab(y_train, model_svm1.predict(X_train),rownames =["Actuall"],colnames = ["Predicted"]) )
print ("\nSVM Linear Classifier - Train accuracy:",round(accuracy_score(y_train, model_svm1.predict(X_train)),3))
print ("\nSVM Linear Classifier - Train Classification Report\n", classification_report(y_train,model_svm1.predict(X_train)))
# Out:
# SVM Linear Classifier - Train Confusion Matrix
#
#  Predicted      0      1
# Actuall
# 0          23212  11793
# 1           7970  26962
#
# SVM Linear Classifier - Train accuracy: 0.717
#
# SVM Linear Classifier - Train Classification Report
#                precision    recall  f1-score   support
#
#            0       0.74      0.66      0.70     35005
#            1       0.70      0.77      0.73     34932
#
#     accuracy                           0.72     69937
#    macro avg       0.72      0.72      0.72     69937
# weighted avg       0.72      0.72      0.72     69937

# %%
#print ("\n\nSVM Linear Classifier - Test Confusion Matrix\n\n",pd.crosstab(y_test, model_svm1.predict(X_test),rownames = ["Actuall"],colnames = ["Predicted"]))
print ("\nSVM Linear Classifier - Test accuracy:",round(accuracy_score(y_test,model_svm1.predict(X_test)),3))
#print ("\nSVM Linear Classifier - Test Classification Report\n",classification_report(y_test,model_svm1.predict(X_test)))
# Out:
# SVM Linear Classifier - Test accuracy: 0.719

# %%
#Deep neural network classifier applied on handwritten digits using Keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,classification_report

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import Adadelta,Adam,RMSprop
from keras.utils import np_utils

# %%
# Defining hyper parameters
np.random.seed(1337)
nb_classes = 2
batch_size = 128
nb_epochs = 100

# %%
#Deep Layer Model building in Keras
model = Sequential()

# %%
model.add(Dense(50, input_shape=(48,), activation='relu'))

# %%
model.add(Dense(100))
model.add(Activation('softmax'))
model.add(Dropout(0.5))

# %%
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
#Model training
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
#Y_train = np_utils.to_categorical(y_train, nb_classes)

# %%
x_vars_stdscle = StandardScaler().fit_transform(X)
#The following section of the code splits the data into train and test based on a 70-30 split:
X_train,X_test,y_train,y_test = train_test_split(x_vars_stdscle,y,train_size = 0.7,random_state=42)

# %%
X_train = np.asarray(X_train).astype(np.int64)
y_train = np.array(y_train).astype(np.int64)
X_train.size
# Out:
# 2006112

# %%
model.fit(X_train, y_train, batch_size=batch_size,epochs=nb_epochs,verbose=1)
# Out:
# Epoch 1/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.5181 - accuracy: 0.9069
# Epoch 2/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3838 - accuracy: 0.9149
# Epoch 3/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3399 - accuracy: 0.9149
# Epoch 4/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3208 - accuracy: 0.9149
# Epoch 5/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3132 - accuracy: 0.9149
# Epoch 6/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3068 - accuracy: 0.9149
# Epoch 7/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3044 - accuracy: 0.9149
# Epoch 8/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3010 - accuracy: 0.9149
# Epoch 9/100
# 327/327 [==============================] - 1s 3ms/step - loss: 0.2992 - accuracy: 0.9149
# Epoch 10/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2962 - accuracy: 0.9149
# Epoch 11/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2929 - accuracy: 0.9149
# Epoch 12/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2917 - accuracy: 0.9149
# Epoch 13/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2898 - accuracy: 0.9149
# Epoch 14/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2896 - accuracy: 0.9149
# Epoch 15/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2884 - accuracy: 0.9149
# Epoch 16/100
# 327/327 [==============================] - 1s 3ms/step - loss: 0.2871 - accuracy: 0.9149
# Epoch 17/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2866 - accuracy: 0.9149
# Epoch 18/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2862 - accuracy: 0.9149
# Epoch 19/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2860 - accuracy: 0.9149
# Epoch 20/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2851 - accuracy: 0.9149
# Epoch 21/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2851 - accuracy: 0.9149
# Epoch 22/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2852 - accuracy: 0.9149
# Epoch 23/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2850 - accuracy: 0.9149
# Epoch 24/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2844 - accuracy: 0.9149
# Epoch 25/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2842 - accuracy: 0.9149
# Epoch 26/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2839 - accuracy: 0.9149
# Epoch 27/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2836 - accuracy: 0.9149
# Epoch 28/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2832 - accuracy: 0.9149
# Epoch 29/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2831 - accuracy: 0.9149
# Epoch 30/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2829 - accuracy: 0.9149
# Epoch 31/100
# 327/327 [==============================] - ETA: 0s - loss: 0.2827 - accuracy: 0.91 - 1s 2ms/step - loss: 0.2827 - accuracy: 0.9149
# Epoch 32/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2825 - accuracy: 0.9149
# Epoch 33/100
# 327/327 [==============================] - ETA: 0s - loss: 0.2823 - accuracy: 0.91 - 1s 2ms/step - loss: 0.2825 - accuracy: 0.9149
# Epoch 34/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2822 - accuracy: 0.9149
# Epoch 35/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2816 - accuracy: 0.9149
# Epoch 36/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2812 - accuracy: 0.9149
# Epoch 37/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2811 - accuracy: 0.9149
# Epoch 38/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2809 - accuracy: 0.9149
# Epoch 39/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2804 - accuracy: 0.9149
# Epoch 40/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2803 - accuracy: 0.9149
# Epoch 41/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2804 - accuracy: 0.9149
# Epoch 42/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2796 - accuracy: 0.9149
# Epoch 43/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2795 - accuracy: 0.9149
# Epoch 44/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2788 - accuracy: 0.9149
# Epoch 45/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2790 - accuracy: 0.9149
# Epoch 46/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2782 - accuracy: 0.9149
# Epoch 47/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2787 - accuracy: 0.9149
# Epoch 48/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2780 - accuracy: 0.9149: 0s - loss: 0.2780 - accu
# Epoch 49/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2784 - accuracy: 0.9149
# Epoch 50/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2773 - accuracy: 0.9149
# Epoch 51/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2764 - accuracy: 0.9149
# Epoch 52/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2770 - accuracy: 0.9149
# Epoch 53/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2768 - accuracy: 0.9149
# Epoch 54/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2765 - accuracy: 0.9149
# Epoch 55/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2761 - accuracy: 0.9149
# Epoch 56/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2765 - accuracy: 0.9149
# Epoch 57/100
# 327/327 [==============================] - 1s 3ms/step - loss: 0.2751 - accuracy: 0.9149
# Epoch 58/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2758 - accuracy: 0.9149
# Epoch 59/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2752 - accuracy: 0.9149
# Epoch 60/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2753 - accuracy: 0.9149
# Epoch 61/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2743 - accuracy: 0.9149
# Epoch 62/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2752 - accuracy: 0.9149
# Epoch 63/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2738 - accuracy: 0.9149
# Epoch 64/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2738 - accuracy: 0.9149
# Epoch 65/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2736 - accuracy: 0.9149
# Epoch 66/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2733 - accuracy: 0.9149
# Epoch 67/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2725 - accuracy: 0.9149
# Epoch 68/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2728 - accuracy: 0.9149
# Epoch 69/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2725 - accuracy: 0.9149
# Epoch 70/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2723 - accuracy: 0.9149
# Epoch 71/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2721 - accuracy: 0.9149
# Epoch 72/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2717 - accuracy: 0.9149
# Epoch 73/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2711 - accuracy: 0.9149: 0s - loss: 0.2678 - accura
# Epoch 74/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2707 - accuracy: 0.9149
# Epoch 75/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2710 - accuracy: 0.9149
# Epoch 76/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2704 - accuracy: 0.9149
# Epoch 77/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2703 - accuracy: 0.9149
# Epoch 78/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2690 - accuracy: 0.9149
# Epoch 79/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2694 - accuracy: 0.9149
# Epoch 80/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2699 - accuracy: 0.9149
# Epoch 81/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2685 - accuracy: 0.9149
# Epoch 82/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2688 - accuracy: 0.9149
# Epoch 83/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2686 - accuracy: 0.9149
# Epoch 84/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2681 - accuracy: 0.9149: 0s - loss: 0.2714 -
# Epoch 85/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2683 - accuracy: 0.9149
# Epoch 86/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2670 - accuracy: 0.9149
# Epoch 87/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2676 - accuracy: 0.9149
# Epoch 88/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2669 - accuracy: 0.9149
# Epoch 89/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2672 - accuracy: 0.9149
# Epoch 90/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2665 - accuracy: 0.9149
# Epoch 91/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2662 - accuracy: 0.9149
# Epoch 92/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2663 - accuracy: 0.9149
# Epoch 93/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2659 - accuracy: 0.9149
# Epoch 94/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2655 - accuracy: 0.9149
# Epoch 95/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2651 - accuracy: 0.9149
# Epoch 96/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2649 - accuracy: 0.9149
# Epoch 97/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2648 - accuracy: 0.9149
# Epoch 98/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2648 - accuracy: 0.9149
# Epoch 99/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2644 - accuracy: 0.9149
# Epoch 100/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2643 - accuracy: 0.9149

# %%
#Returns the loss value & metrics values for the model in test mode.
score = model.evaluate(X_test, y_test,
                       batch_size=batch_size, verbose=1)
 
print('Test accuracy:', score[0], score[1])
# Out:
# 140/140 [==============================] - 0s 1ms/step - loss: 0.3345 - accuracy: 0.9154
# Test accuracy: 0.33454519510269165 0.9153640270233154

# %%
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#Model Prediction
y_train_predclass = model.predict_classes(X_train,batch_size=batch_size)
y_test_predclass = model.predict_classes(X_test,batch_size=batch_size)
y_train_predclass = np.array(y_train).astype(np.int64)
y_test_predclass = np.array(y_test).astype(np.int64)

# %%
print ("\n\nDeep Neural Network - Train accuracy:", round(accuracy_score(y_train,y_train_predclass),3))
print ("\nDeep Neural Network - Train Classification Report", print (classification_report(y_train,y_train_predclass)))
print ('\n Deep Neural Network - Train Confusion Matrix')
print (pd.crosstab(y_train,y_train_predclass[1],rownames = ["Actual"],colnames = ["Predicted"]) )
# Out:
# Deep Neural Network - Train accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     38239
#            1       1.00      1.00      1.00      3555
#
#     accuracy                           1.00     41794
#    macro avg       1.00      1.00      1.00     41794
# weighted avg       1.00      1.00      1.00     41794
#
#
# Deep Neural Network - Train Classification Report None
#
#  Deep Neural Network - Train Confusion Matrix
# Predicted      0
# Actual
# 0          38239
# 1           3555

# %%
print ("\nDeep Neural Network - Test accuracy:",round(accuracy_score(y_test, y_test_predclass),3))
print ("\nDeep Neural Network - Test Classification Report")
print (classification_report(y_test,y_test_predclass))
print ("\nDeep Neural Network - Test Confusion Matrix\n")
print (pd.crosstab(y_test,y_test_predclass,rownames = ["Actuall"],colnames = ["Predicted"]) )
# Out:
# Deep Neural Network - Test accuracy: 1.0
#
# Deep Neural Network - Test Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     16396
#            1       1.00      1.00      1.00      1516
#
#     accuracy                           1.00     17912
#    macro avg       1.00      1.00      1.00     17912
# weighted avg       1.00      1.00      1.00     17912
#
#
# Deep Neural Network - Test Confusion Matrix
#
# Predicted      0     1
# Actuall
# 0          16396     0
# 1              0  1516

# %%
#loading Dataset
df = pd.read_csv("C:\\Users\91944\Desktop\\fiipdata.csv")

# %%
#displaying first 10 rows of data
df.head(10).T
# Out:
#                                                  0          1  \
# encounter_id                               2278392     149190
# patient_nbr                                8222157   55629189
# race                                     Caucasian  Caucasian
# gender                                      Female     Female
# age                                         [0-10)    [10-20)
# weight                                           ?          ?
# admission_type_id                                6          1
# discharge_disposition_id                        25          1
# admission_source_id                              1          7
# time_in_hospital                                 1          3
# payer_code                                       ?          ?
# medical_specialty         Pediatrics-Endocrinology          ?
# num_lab_procedures                              41         59
# num_procedures                                   0          0
# num_medications                                  1         18
# number_outpatient                                0          0
# number_emergency                                 0          0
# number_inpatient                                 0          0
# diag_1                                      250.83        276
# diag_2                                           ?     250.01
# diag_3                                           ?        255
# number_diagnoses                                 1          9
# max_glu_serum                                 None       None
# A1Cresult                                     None       None
# metformin                                       No         No
# repaglinide                                     No         No
# nateglinide                                     No         No
# chlorpropamide                                  No         No
# glimepiride                                     No         No
# acetohexamide                                   No         No
# glipizide                                       No         No
# glyburide                                       No         No
# tolbutamide                                     No         No
# pioglitazone                                    No         No
# rosiglitazone                                   No         No
# acarbose                                        No         No
# miglitol                                        No         No
# troglitazone                                    No         No
# tolazamide                                      No         No
# examide                                         No         No
# citoglipton                                     No         No
# insulin                                         No         Up
# glyburide-metformin                             No         No
# glipizide-metformin                             No         No
# glimepiride-pioglitazone                        No         No
# metformin-rosiglitazone                         No         No
# metformin-pioglitazone                          No         No
# change                                          No         Ch
# diabetesMed                                     No        Yes
# readmitted                                      NO        >30
#
#                                         2          3          4          5  \
# encounter_id                        64410     500364      16680      35754
# patient_nbr                      86047875   82442376   42519267   82637451
# race                      AfricanAmerican  Caucasian  Caucasian  Caucasian
# gender                             Female       Male       Male       Male
# age                               [20-30)    [30-40)    [40-50)    [50-60)
# weight                                  ?          ?          ?          ?
# admission_type_id                       1          1          1          2
# discharge_disposition_id                1          1          1          1
# admission_source_id                     7          7          7          2
# time_in_hospital                        2          2          1          3
# payer_code                              ?          ?          ?          ?
# medical_specialty                       ?          ?          ?          ?
# num_lab_procedures                     11         44         51         31
# num_procedures                          5          1          0          6
# num_medications                        13         16          8         16
# number_outpatient                       2          0          0          0
# number_emergency                        0          0          0          0
# number_inpatient                        1          0          0          0
# diag_1                                648          8        197        414
# diag_2                                250     250.43        157        411
# diag_3                                V27        403        250        250
# number_diagnoses                        6          7          5          9
# max_glu_serum                        None       None       None       None
# A1Cresult                            None       None       None       None
# metformin                              No         No         No         No
# repaglinide                            No         No         No         No
# nateglinide                            No         No         No         No
# chlorpropamide                         No         No         No         No
# glimepiride                            No         No         No         No
# acetohexamide                          No         No         No         No
# glipizide                          Steady         No     Steady         No
# glyburide                              No         No         No         No
# tolbutamide                            No         No         No         No
# pioglitazone                           No         No         No         No
# rosiglitazone                          No         No         No         No
# acarbose                               No         No         No         No
# miglitol                               No         No         No         No
# troglitazone                           No         No         No         No
# tolazamide                             No         No         No         No
# examide                                No         No         No         No
# citoglipton                            No         No         No         No
# insulin                                No         Up     Steady     Steady
# glyburide-metformin                    No         No         No         No
# glipizide-metformin                    No         No         No         No
# glimepiride-pioglitazone               No         No         No         No
# metformin-rosiglitazone                No         No         No         No
# metformin-pioglitazone                 No         No         No         No
# change                                 No         Ch         Ch         No
# diabetesMed                           Yes        Yes        Yes        Yes
# readmitted                             NO         NO         NO        >30
#
#                                   6          7          8                 9
# encounter_id                  55842      63768      12522             15738
# patient_nbr                84259809  114882984   48330783          63555939
# race                      Caucasian  Caucasian  Caucasian         Caucasian
# gender                         Male       Male     Female            Female
# age                         [60-70)    [70-80)    [80-90)          [90-100)
# weight                            ?          ?          ?                 ?
# admission_type_id                 3          1          2                 3
# discharge_disposition_id          1          1          1                 3
# admission_source_id               2          7          4                 4
# time_in_hospital                  4          5         13                12
# payer_code                        ?          ?          ?                 ?
# medical_specialty                 ?          ?          ?  InternalMedicine
# num_lab_procedures               70         73         68                33
# num_procedures                    1          0          2                 3
# num_medications                  21         12         28                18
# number_outpatient                 0          0          0                 0
# number_emergency                  0          0          0                 0
# number_inpatient                  0          0          0                 0
# diag_1                          414        428        398               434
# diag_2                          411        492        427               198
# diag_3                          V45        250         38               486
# number_diagnoses                  7          8          8                 8
# max_glu_serum                  None       None       None              None
# A1Cresult                      None       None       None              None
# metformin                    Steady         No         No                No
# repaglinide                      No         No         No                No
# nateglinide                      No         No         No                No
# chlorpropamide                   No         No         No                No
# glimepiride                  Steady         No         No                No
# acetohexamide                    No         No         No                No
# glipizide                        No         No     Steady                No
# glyburide                        No     Steady         No                No
# tolbutamide                      No         No         No                No
# pioglitazone                     No         No         No                No
# rosiglitazone                    No         No         No            Steady
# acarbose                         No         No         No                No
# miglitol                         No         No         No                No
# troglitazone                     No         No         No                No
# tolazamide                       No         No         No                No
# examide                          No         No         No                No
# citoglipton                      No         No         No                No
# insulin                      Steady         No     Steady            Steady
# glyburide-metformin              No         No         No                No
# glipizide-metformin              No         No         No                No
# glimepiride-pioglitazone         No         No         No                No
# metformin-rosiglitazone          No         No         No                No
# metformin-pioglitazone           No         No         No                No
# change                           Ch         No         Ch                Ch
# diabetesMed                     Yes        Yes        Yes               Yes
# readmitted                       NO        >30         NO                NO

# %%
#checking shape of the dataset
df.shape
# Out:
# (101666, 50)

# %%
#Checking data types of each variable
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# examide                     object
# citoglipton                 object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                  object
# dtype: object

# %%
#Checking for missing values in dataset
#In the dataset missing values are represented as '?' sign
for col in df.columns:
    if df[col].dtype == object:
         print(col,df[col][df[col] == '?'].count())
# Out:
# race 2269
# gender 0
# age 0
# weight 98471
# payer_code 40243
# medical_specialty 49877
# diag_1 21
# diag_2 357
# diag_3 1422
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# examide 0
# citoglipton 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0

# %%
# gender was coded differently so we use a custom count for this one            
print('gender', df['gender'][df['gender'] == 'Unknown/Invalid'].count())
# Out:
# gender 3

# %%
#dropping columns with large number of missing values
df = df.drop(['weight','payer_code','medical_specialty'], axis = 1)

# %%
drop_Idx = set(df[(df['diag_1'] == '?') & (df['diag_2'] == '?') & (df['diag_3'] == '?')].index)

drop_Idx = drop_Idx.union(set(df['diag_1'][df['diag_1'] == '?'].index))
drop_Idx = drop_Idx.union(set(df['diag_2'][df['diag_2'] == '?'].index))
drop_Idx = drop_Idx.union(set(df['diag_3'][df['diag_3'] == '?'].index))
drop_Idx = drop_Idx.union(set(df['race'][df['race'] == '?'].index))
drop_Idx = drop_Idx.union(set(df[df['discharge_disposition_id'] == 11].index))
drop_Idx = drop_Idx.union(set(df['gender'][df['gender'] == 'Unknown/Invalid'].index))
new_Idx = list(set(df.index) - set(drop_Idx))
df = df.iloc[new_Idx]

# %%
df = df.drop(['citoglipton', 'examide'], axis = 1)

# %%
#Checking for missing values in the data
for col in df.columns:
    if df[col].dtype == object:
         print(col,df[col][df[col] == '?'].count())
            
print('gender', df['gender'][df['gender'] == 'Unknown/Invalid'].count())
# Out:
# race 0
# gender 0
# age 0
# diag_1 0
# diag_2 0
# diag_3 0
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0
# gender 0

# %%
#Feature Engineering
df['service_utilization'] = df['number_outpatient'] + df['number_emergency'] + df['number_inpatient']

# %%
keys = ['metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 'glyburide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'insulin', 'glyburide-metformin', 'tolazamide', 'metformin-pioglitazone','metformin-rosiglitazone', 'glimepiride-pioglitazone', 'glipizide-metformin', 'troglitazone', 'tolbutamide', 'acetohexamide']
for col in keys:
    colname = str(col) + 'temp'
    df[colname] = df[col].apply(lambda x: 0 if (x == 'No' or x == 'Steady') else 1)
df['numchange'] = 0
for col in keys:
    colname = str(col) + 'temp'
    df['numchange'] = df['numchange'] + df[colname]
    del df[colname]
    
df['numchange'].value_counts()
# Out:
# 0    70085
# 1    24888
# 2     1268
# 3      106
# 4        5
# Name: numchange, dtype: int64

# %%
# re-encoding admission type, discharge type and admission source into fewer categories

df['admission_type_id'] = df['admission_type_id'].replace(2,1)
df['admission_type_id'] = df['admission_type_id'].replace(7,1)
df['admission_type_id'] = df['admission_type_id'].replace(6,5)
df['admission_type_id'] = df['admission_type_id'].replace(8,5)

df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(6,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(8,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(9,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(13,1)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(3,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(4,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(5,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(14,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(22,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(23,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(24,2)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(12,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(15,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(16,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(17,10)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(25,18)
df['discharge_disposition_id'] = df['discharge_disposition_id'].replace(26,18)

df['admission_source_id'] = df['admission_source_id'].replace(2,1)
df['admission_source_id'] = df['admission_source_id'].replace(3,1)
df['admission_source_id'] = df['admission_source_id'].replace(5,4)
df['admission_source_id'] = df['admission_source_id'].replace(6,4)
df['admission_source_id'] = df['admission_source_id'].replace(10,4)
df['admission_source_id'] = df['admission_source_id'].replace(22,4)
df['admission_source_id'] = df['admission_source_id'].replace(25,4)
df['admission_source_id'] = df['admission_source_id'].replace(15,9)
df['admission_source_id'] = df['admission_source_id'].replace(17,9)
df['admission_source_id'] = df['admission_source_id'].replace(20,9)
df['admission_source_id'] = df['admission_source_id'].replace(21,9)
df['admission_source_id'] = df['admission_source_id'].replace(13,11)
df['admission_source_id'] = df['admission_source_id'].replace(14,11)

# %%
df['change'] = df['change'].replace('Ch', 1)
df['change'] = df['change'].replace('No', 0)
df['gender'] = df['gender'].replace('Male', 1)
df['gender'] = df['gender'].replace('Female', 0)
df['diabetesMed'] = df['diabetesMed'].replace('Yes', 1)
df['diabetesMed'] = df['diabetesMed'].replace('No', 0)
# keys is the same as before
for col in keys:
    df[col] = df[col].replace('No', 0)
    df[col] = df[col].replace('Steady', 1)
    df[col] = df[col].replace('Up', 1)
    df[col] = df[col].replace('Down', 1)

# %%
df['A1Cresult'] = df['A1Cresult'].replace('>7', 1)
df['A1Cresult'] = df['A1Cresult'].replace('>8', 1)
df['A1Cresult'] = df['A1Cresult'].replace('Norm', 0)
df['A1Cresult'] = df['A1Cresult'].replace('None', -99)
df['max_glu_serum'] = df['max_glu_serum'].replace('>200', 1)
df['max_glu_serum'] = df['max_glu_serum'].replace('>300', 1)
df['max_glu_serum'] = df['max_glu_serum'].replace('Norm', 0)
df['max_glu_serum'] = df['max_glu_serum'].replace('None', -99)

# %%
# code age intervals [0-10) - [90-100) from 1-10
for i in range(0,10):
    df['age'] = df['age'].replace('['+str(10*i)+'-'+str(10*(i+1))+')', i+1)
df['age'].value_counts()
# Out:
# 8     24784
# 7     21512
# 6     16530
# 9     16205
# 5      9199
# 4      3532
# 10     2591
# 3      1470
# 2       465
# 1        64
# Name: age, dtype: int64

# %%
df2 = df.drop_duplicates(subset= ['patient_nbr'], keep = 'first')
df2.shape
(70442, 55)
# Out:
# (70442, 55)

# %%
df.head().T
# Out:
#                                   1                2          3          4  \
# encounter_id                 149190            64410     500364      16680
# patient_nbr                55629189         86047875   82442376   42519267
# race                      Caucasian  AfricanAmerican  Caucasian  Caucasian
# gender                            0                0          1          1
# age                               2                3          4          5
# admission_type_id                 1                1          1          1
# discharge_disposition_id          1                1          1          1
# admission_source_id               7                7          7          7
# time_in_hospital                  3                2          2          1
# num_lab_procedures               59               11         44         51
# num_procedures                    0                5          1          0
# num_medications                  18               13         16          8
# number_outpatient                 0                2          0          0
# number_emergency                  0                0          0          0
# number_inpatient                  0                1          0          0
# diag_1                          276              648          8        197
# diag_2                       250.01              250     250.43        157
# diag_3                          255              V27        403        250
# number_diagnoses                  9                6          7          5
# max_glu_serum                   -99              -99        -99        -99
# A1Cresult                       -99              -99        -99        -99
# metformin                         0                0          0          0
# repaglinide                       0                0          0          0
# nateglinide                       0                0          0          0
# chlorpropamide                    0                0          0          0
# glimepiride                       0                0          0          0
# acetohexamide                     0                0          0          0
# glipizide                         0                1          0          1
# glyburide                         0                0          0          0
# tolbutamide                       0                0          0          0
# pioglitazone                      0                0          0          0
# rosiglitazone                     0                0          0          0
# acarbose                          0                0          0          0
# miglitol                          0                0          0          0
# troglitazone                      0                0          0          0
# tolazamide                        0                0          0          0
# insulin                           1                0          1          1
# glyburide-metformin               0                0          0          0
# glipizide-metformin               0                0          0          0
# glimepiride-pioglitazone          0                0          0          0
# metformin-rosiglitazone           0                0          0          0
# metformin-pioglitazone            0                0          0          0
# change                            1                0          1          1
# diabetesMed                       1                1          1          1
# readmitted                      >30               NO         NO         NO
# service_utilization               0                3          0          0
# numchange                         1                0          1          0
#
#                                   5
# encounter_id                  35754
# patient_nbr                82637451
# race                      Caucasian
# gender                            1
# age                               6
# admission_type_id                 1
# discharge_disposition_id          1
# admission_source_id               1
# time_in_hospital                  3
# num_lab_procedures               31
# num_procedures                    6
# num_medications                  16
# number_outpatient                 0
# number_emergency                  0
# number_inpatient                  0
# diag_1                          414
# diag_2                          411
# diag_3                          250
# number_diagnoses                  9
# max_glu_serum                   -99
# A1Cresult                       -99
# metformin                         0
# repaglinide                       0
# nateglinide                       0
# chlorpropamide                    0
# glimepiride                       0
# acetohexamide                     0
# glipizide                         0
# glyburide                         0
# tolbutamide                       0
# pioglitazone                      0
# rosiglitazone                     0
# acarbose                          0
# miglitol                          0
# troglitazone                      0
# tolazamide                        0
# insulin                           1
# glyburide-metformin               0
# glipizide-metformin               0
# glimepiride-pioglitazone          0
# metformin-rosiglitazone           0
# metformin-pioglitazone            0
# change                            0
# diabetesMed                       1
# readmitted                      >30
# service_utilization               0
# numchange                         0

# %%
df['readmitted'].value_counts()
# Out:
# NO     50669
# >30    34626
# <30    11057
# Name: readmitted, dtype: int64

# %%
df['readmitted'] = df['readmitted'].replace('>30', 0)
df['readmitted'] = df['readmitted'].replace('<30', 1)
df['readmitted'] = df['readmitted'].replace('NO', 0)

# %%
# Creating additional columns for diagnosis# Creati 
df['level1_diag1'] = df['diag_1']
df['level2_diag1'] = df['diag_1']
df['level1_diag2'] = df['diag_2']
df['level2_diag2'] = df['diag_2']
df['level1_diag3'] = df['diag_3']
df['level2_diag3'] = df['diag_3']

# %%
df.loc[df['diag_1'].str.contains('V'), ['level1_diag1', 'level2_diag1']] = 0
df.loc[df['diag_1'].str.contains('E'), ['level1_diag1', 'level2_diag1']] = 0
df.loc[df['diag_2'].str.contains('V'), ['level1_diag2', 'level2_diag2']] = 0
df.loc[df['diag_2'].str.contains('E'), ['level1_diag2', 'level2_diag2']] = 0
df.loc[df['diag_3'].str.contains('V'), ['level1_diag3', 'level2_diag3']] = 0
df.loc[df['diag_3'].str.contains('E'), ['level1_diag3', 'level2_diag3']] = 0
df['level1_diag1'] = df['level1_diag1'].replace('?', -1)
df['level2_diag1'] = df['level2_diag1'].replace('?', -1)
df['level1_diag2'] = df['level1_diag2'].replace('?', -1)
df['level2_diag2'] = df['level2_diag2'].replace('?', -1)
df['level1_diag3'] = df['level1_diag3'].replace('?', -1)
df['level2_diag3'] = df['level2_diag3'].replace('?', -1)

# %%
df['level1_diag1'] = df['level1_diag1'].astype(float)
df['level2_diag1'] = df['level2_diag1'].astype(float)
df['level1_diag2'] = df['level1_diag2'].astype(float)
df['level2_diag2'] = df['level2_diag2'].astype(float)
df['level1_diag3'] = df['level1_diag3'].astype(float)
df['level2_diag3'] = df['level2_diag3'].astype(float)

# %%
for index, row in df.iterrows():
    if (row['level1_diag1'] >= 390 and row['level1_diag1'] < 460) or (np.floor(row['level1_diag1']) == 785):
        df.loc[index, 'level1_diag1'] = 1
    elif (row['level1_diag1'] >= 460 and row['level1_diag1'] < 520) or (np.floor(row['level1_diag1']) == 786):
        df.loc[index, 'level1_diag1'] = 2
    elif (row['level1_diag1'] >= 520 and row['level1_diag1'] < 580) or (np.floor(row['level1_diag1']) == 787):
        df.loc[index, 'level1_diag1'] = 3
    elif (np.floor(row['level1_diag1']) == 250):
        df.loc[index, 'level1_diag1'] = 4
    elif (row['level1_diag1'] >= 800 and row['level1_diag1'] < 1000):
        df.loc[index, 'level1_diag1'] = 5
    elif (row['level1_diag1'] >= 710 and row['level1_diag1'] < 740):
        df.loc[index, 'level1_diag1'] = 6
    elif (row['level1_diag1'] >= 580 and row['level1_diag1'] < 630) or (np.floor(row['level1_diag1']) == 788):
        df.loc[index, 'level1_diag1'] = 7
    elif (row['level1_diag1'] >= 140 and row['level1_diag1'] < 240):
        df.loc[index, 'level1_diag1'] = 8
    else:
        df.loc[index, 'level1_diag1'] = 0
        
    if (row['level1_diag2'] >= 390 and row['level1_diag2'] < 460) or (np.floor(row['level1_diag2']) == 785):
        df.loc[index, 'level1_diag2'] = 1
    elif (row['level1_diag2'] >= 460 and row['level1_diag2'] < 520) or (np.floor(row['level1_diag2']) == 786):
        df.loc[index, 'level1_diag2'] = 2
    elif (row['level1_diag2'] >= 520 and row['level1_diag2'] < 580) or (np.floor(row['level1_diag2']) == 787):
        df.loc[index, 'level1_diag2'] = 3
    elif (np.floor(row['level1_diag2']) == 250):
        df.loc[index, 'level1_diag2'] = 4
    elif (row['level1_diag2'] >= 800 and row['level1_diag2'] < 1000):
        df.loc[index, 'level1_diag2'] = 5
    elif (row['level1_diag2'] >= 710 and row['level1_diag2'] < 740):
        df.loc[index, 'level1_diag2'] = 6
    elif (row['level1_diag2'] >= 580 and row['level1_diag2'] < 630) or (np.floor(row['level1_diag2']) == 788):
        df.loc[index, 'level1_diag2'] = 7
    elif (row['level1_diag2'] >= 140 and row['level1_diag2'] < 240):
        df.loc[index, 'level1_diag2'] = 8
    else:
        df.loc[index, 'level1_diag2'] = 0
    
    if (row['level1_diag3'] >= 390 and row['level1_diag3'] < 460) or (np.floor(row['level1_diag3']) == 785):
        df.loc[index, 'level1_diag3'] = 1
    elif (row['level1_diag3'] >= 460 and row['level1_diag3'] < 520) or (np.floor(row['level1_diag3']) == 786):
        df.loc[index, 'level1_diag3'] = 2
    elif (row['level1_diag3'] >= 520 and row['level1_diag3'] < 580) or (np.floor(row['level1_diag3']) == 787):
        df.loc[index, 'level1_diag3'] = 3
    elif (np.floor(row['level1_diag3']) == 250):
        df.loc[index, 'level1_diag3'] = 4
    elif (row['level1_diag3'] >= 800 and row['level1_diag3'] < 1000):
        df.loc[index, 'level1_diag3'] = 5
    elif (row['level1_diag3'] >= 710 and row['level1_diag3'] < 740):
        df.loc[index, 'level1_diag3'] = 6
    elif (row['level1_diag3'] >= 580 and row['level1_diag3'] < 630) or (np.floor(row['level1_diag3']) == 788):
        df.loc[index, 'level1_diag3'] = 7
    elif (row['level1_diag3'] >= 140 and row['level1_diag3'] < 240):
        df.loc[index, 'level1_diag3'] = 8
    else:
        df.loc[index, 'level1_diag3'] = 0

# %%
for index, row in df.iterrows():
    if (row['level2_diag1'] >= 390 and row['level2_diag1'] < 399):
        df.loc[index, 'level2_diag1'] = 1
    elif (row['level2_diag1'] >= 401 and row['level2_diag1'] < 415):
        df.loc[index, 'level2_diag1'] = 2
    elif (row['level2_diag1'] >= 415 and row['level2_diag1'] < 460):
        df.loc[index, 'level2_diag1'] = 3
    elif (np.floor(row['level2_diag1']) == 785):
        df.loc[index, 'level2_diag1'] = 4
    elif (row['level2_diag1'] >= 460 and row['level2_diag1'] < 489):
        df.loc[index, 'level2_diag1'] = 5
    elif (row['level2_diag1'] >= 490 and row['level2_diag1'] < 497):
        df.loc[index, 'level2_diag1'] = 6
    elif (row['level2_diag1'] >= 500 and row['level2_diag1'] < 520):
        df.loc[index, 'level2_diag1'] = 7
    elif (np.floor(row['level2_diag1']) == 786):
        df.loc[index, 'level2_diag1'] = 8
    elif (row['level2_diag1'] >= 520 and row['level2_diag1'] < 530):
        df.loc[index, 'level2_diag1'] = 9
    elif (row['level2_diag1'] >= 530 and row['level2_diag1'] < 544):
        df.loc[index, 'level2_diag1'] = 10
    elif (row['level2_diag1'] >= 550 and row['level2_diag1'] < 554):
        df.loc[index, 'level2_diag1'] = 11
    elif (row['level2_diag1'] >= 555 and row['level2_diag1'] < 580):
        df.loc[index, 'level2_diag1'] = 12
    elif (np.floor(row['level2_diag1']) == 787):
        df.loc[index, 'level2_diag1'] = 13
    elif (np.floor(row['level2_diag1']) == 250):
        df.loc[index, 'level2_diag1'] = 14
    elif (row['level2_diag1'] >= 800 and row['level2_diag1'] < 1000):
        df.loc[index, 'level2_diag1'] = 15
    elif (row['level2_diag1'] >= 710 and row['level2_diag1'] < 740):
        df.loc[index, 'level2_diag1'] = 16
    elif (row['level2_diag1'] >= 580 and row['level2_diag1'] < 630):
        df.loc[index, 'level2_diag1'] = 17
    elif (np.floor(row['level2_diag1']) == 788):
        df.loc[index, 'level2_diag1'] = 18
    elif (row['level2_diag1'] >= 140 and row['level2_diag1'] < 240):
        df.loc[index, 'level2_diag1'] = 19
    elif row['level2_diag1'] >= 240 and row['level2_diag1'] < 280 and (np.floor(row['level2_diag1']) != 250):
        df.loc[index, 'level2_diag1'] = 20
    elif (row['level2_diag1'] >= 680 and row['level2_diag1'] < 710) or (np.floor(row['level2_diag1']) == 782):
        df.loc[index, 'level2_diag1'] = 21
    elif (row['level2_diag1'] >= 290 and row['level2_diag1'] < 320):
        df.loc[index, 'level2_diag1'] = 22
    else:
        df.loc[index, 'level2_diag1'] = 0
        
    if (row['level2_diag2'] >= 390 and row['level2_diag2'] < 399):
        df.loc[index, 'level2_diag2'] = 1
    elif (row['level2_diag2'] >= 401 and row['level2_diag2'] < 415):
        df.loc[index, 'level2_diag2'] = 2
    elif (row['level2_diag2'] >= 415 and row['level2_diag2'] < 460):
        df.loc[index, 'level2_diag2'] = 3
    elif (np.floor(row['level2_diag2']) == 785):
        df.loc[index, 'level2_diag2'] = 4
    elif (row['level2_diag2'] >= 460 and row['level2_diag2'] < 489):
        df.loc[index, 'level2_diag2'] = 5
    elif (row['level2_diag2'] >= 490 and row['level2_diag2'] < 497):
        df.loc[index, 'level2_diag2'] = 6
    elif (row['level2_diag2'] >= 500 and row['level2_diag2'] < 520):
        df.loc[index, 'level2_diag2'] = 7
    elif (np.floor(row['level2_diag2']) == 786):
        df.loc[index, 'level2_diag2'] = 8
    elif (row['level2_diag2'] >= 520 and row['level2_diag2'] < 530):
        df.loc[index, 'level2_diag2'] = 9
    elif (row['level2_diag2'] >= 530 and row['level2_diag2'] < 544):
        df.loc[index, 'level2_diag2'] = 10
    elif (row['level2_diag2'] >= 550 and row['level2_diag2'] < 554):
        df.loc[index, 'level2_diag2'] = 11
    elif (row['level2_diag2'] >= 555 and row['level2_diag2'] < 580):
        df.loc[index, 'level2_diag2'] = 12
    elif (np.floor(row['level2_diag2']) == 787):
        df.loc[index, 'level2_diag2'] = 13
    elif (np.floor(row['level2_diag2']) == 250):
        df.loc[index, 'level2_diag2'] = 14
    elif (row['level2_diag2'] >= 800 and row['level2_diag2'] < 1000):
        df.loc[index, 'level2_diag2'] = 15
    elif (row['level2_diag2'] >= 710 and row['level2_diag2'] < 740):
        df.loc[index, 'level2_diag2'] = 16
    elif (row['level2_diag2'] >= 580 and row['level2_diag2'] < 630):
        df.loc[index, 'level2_diag2'] = 17
    elif (np.floor(row['level2_diag2']) == 788):
        df.loc[index, 'level2_diag2'] = 18
    elif (row['level2_diag2'] >= 140 and row['level2_diag2'] < 240):
        df.loc[index, 'level2_diag2'] = 19
    elif row['level2_diag2'] >= 240 and row['level2_diag2'] < 280 and (np.floor(row['level2_diag2']) != 250):
        df.loc[index, 'level2_diag2'] = 20
    elif (row['level2_diag2'] >= 680 and row['level2_diag2'] < 710) or (np.floor(row['level2_diag2']) == 782):
        df.loc[index, 'level2_diag2'] = 21
    elif (row['level2_diag2'] >= 290 and row['level2_diag2'] < 320):
        df.loc[index, 'level2_diag2'] = 22
    else:
        df.loc[index, 'level2_diag2'] = 0
        
        
    if (row['level2_diag3'] >= 390 and row['level2_diag3'] < 399):
        df.loc[index, 'level2_diag3'] = 1
    elif (row['level2_diag3'] >= 401 and row['level2_diag3'] < 415):
        df.loc[index, 'level2_diag3'] = 2
    elif (row['level2_diag3'] >= 415 and row['level2_diag3'] < 460):
        df.loc[index, 'level2_diag3'] = 3
    elif (np.floor(row['level2_diag3']) == 785):
        df.loc[index, 'level2_diag3'] = 4
    elif (row['level2_diag3'] >= 460 and row['level2_diag3'] < 489):
        df.loc[index, 'level2_diag3'] = 5
    elif (row['level2_diag3'] >= 490 and row['level2_diag3'] < 497):
        df.loc[index, 'level2_diag3'] = 6
    elif (row['level2_diag3'] >= 500 and row['level2_diag3'] < 520):
        df.loc[index, 'level2_diag3'] = 7
    elif (np.floor(row['level2_diag3']) == 786):
        df.loc[index, 'level2_diag3'] = 8
    elif (row['level2_diag3'] >= 520 and row['level2_diag3'] < 530):
        df.loc[index, 'level2_diag3'] = 9
    elif (row['level2_diag3'] >= 530 and row['level2_diag3'] < 544):
        df.loc[index, 'level2_diag3'] = 10
    elif (row['level2_diag3'] >= 550 and row['level2_diag3'] < 554):
        df.loc[index, 'level2_diag3'] = 11
    elif (row['level2_diag3'] >= 555 and row['level2_diag3'] < 580):
        df.loc[index, 'level2_diag3'] = 12
    elif (np.floor(row['level2_diag3']) == 787):
        df.loc[index, 'level2_diag3'] = 13
    elif (np.floor(row['level2_diag3']) == 250):
        df.loc[index, 'level2_diag3'] = 14
    elif (row['level2_diag3'] >= 800 and row['level2_diag3'] < 1000):
        df.loc[index, 'level2_diag3'] = 15
    elif (row['level2_diag3'] >= 710 and row['level2_diag3'] < 740):
        df.loc[index, 'level2_diag3'] = 16
    elif (row['level2_diag3'] >= 580 and row['level2_diag3'] < 630):
        df.loc[index, 'level2_diag3'] = 17
    elif (np.floor(row['level2_diag3']) == 788):
        df.loc[index, 'level2_diag3'] = 18
    elif (row['level2_diag3'] >= 140 and row['level2_diag3'] < 240):
        df.loc[index, 'level2_diag3'] = 19
    elif row['level2_diag3'] >= 240 and row['level2_diag3'] < 280 and (np.floor(row['level2_diag3']) != 250):
        df.loc[index, 'level2_diag3'] = 20
    elif (row['level2_diag3'] >= 680 and row['level2_diag3'] < 710) or (np.floor(row['level2_diag3']) == 782):
        df.loc[index, 'level2_diag3'] = 21
    elif (row['level2_diag3'] >= 290 and row['level2_diag3'] < 320):
        df.loc[index, 'level2_diag3'] = 22
    else:
        df.loc[index, 'level2_diag3'] = 0

# %%
#Data Visualization
# Distribution of Readmission 
sns.countplot(df['readmitted']).set_title('Distribution of Readmission')
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribution of Readmission')

# %%
#Time in Hospital VS. Readmission
fig = plt.figure(figsize=(13,7),)
ax=sns.kdeplot(df.loc[(df['readmitted'] == 0),'time_in_hospital'] , color='b',shade=True,label='Not Readmitted')
ax=sns.kdeplot(df.loc[(df['readmitted'] == 1),'time_in_hospital'] , color='r',shade=True, label='Readmitted')
ax.set(xlabel='Time in Hospital', ylabel='Frequency')
plt.title('Time in Hospital VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Time in Hospital VS. Readmission')

# %%
#Age of Patient VS. Readmission
fig = plt.figure(figsize=(15,10))
sns.countplot(y= df['age'], hue = df['readmitted']).set_title('Age of Patient VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Age of Patient VS. Readmission')

# %%
#race VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(y = df['race'], hue = df['readmitted'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='race'>

# %%
#Number of medication used VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.barplot(x = df['readmitted'], y = df['num_medications']).set_title("Number of medication used VS. Readmission")
# Out:
# Text(0.5, 1.0, 'Number of medication used VS. Readmission')

# %%
#Gender of Patient VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(df['gender'], hue = df['readmitted']).set_title("Gender of Patient VS. Readmission")
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gender of Patient VS. Readmission')

# %%
#Change of Medication VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(df['change'], hue = df['readmitted']).set_title('Change of Medication VS. Readmission')
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Change of Medication VS. Readmission')

# %%
#Diabetes Medication prescribed VS Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(df['diabetesMed'], hue = df['readmitted']).set_title('Diabetes Medication prescribed VS Readmission')
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Diabetes Medication prescribed VS Readmission')

# %%
#Service Utilization VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.barplot( y = df['service_utilization'], x = df['readmitted']).set_title('Service Utilization VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Service Utilization VS. Readmission')

# %%
#Glucose test serum test result VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(y = df['max_glu_serum'], hue = df['readmitted']).set_title('Glucose test serum test result VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Glucose test serum test result VS. Readmission')

# %%
#A1C test result VS. Readmission
fig = plt.figure(figsize=(8,8))
sns.countplot(y= df['A1Cresult'], hue = df['readmitted']).set_title('A1C test result VS. Readmission')
# Out:
# Text(0.5, 1.0, 'A1C test result VS. Readmission')

# %%
#Number of lab procedure VS. Readmission
fig = plt.figure(figsize=(15,6),)
ax=sns.kdeplot(df.loc[(df['readmitted'] == 0),'num_lab_procedures'] , color='b',shade=True,label='Not readmitted')
ax=sns.kdeplot(df.loc[(df['readmitted'] == 1),'num_lab_procedures'] , color='r',shade=True, label='readmitted')
ax.set(xlabel='Number of lab procedure', ylabel='Frequency')
plt.title('Number of lab procedure VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Number of lab procedure VS. Readmission')

# %%
#Pre-Modeling Data Preprocessing
df['age'] = df['age'].astype('int64')
print(df.age.value_counts())
# convert age categories to mid-point values
age_dict = {1:5, 2:15, 3:25, 4:35, 5:45, 6:55, 7:65, 8:75, 9:85, 10:95}
df['age'] = df.age.map(age_dict)
print(df.age.value_counts())
# Out:
# 8     24784
# 7     21512
# 6     16530
# 9     16205
# 5      9199
# 4      3532
# 10     2591
# 3      1470
# 2       465
# 1        64
# Name: age, dtype: int64
# 75    24784
# 65    21512
# 55    16530
# 85    16205
# 45     9199
# 35     3532
# 95     2591
# 25     1470
# 15      465
# 5        64
# Name: age, dtype: int64

# %%
# convert data type of nominal features in dataframe to 'object' type
i = ['encounter_id', 'patient_nbr', 'gender', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id',\
          'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', \
          'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose','miglitol', \
          'troglitazone', 'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin', \
          'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed', \
          'age', 'A1Cresult', 'max_glu_serum', 'level1_diag1', 'level1_diag2', 'level1_diag3', 'level2_diag1', 'level2_diag2', 'level2_diag3']

df[i] = df[i].astype('object')

# %%
df.dtypes
# Out:
# encounter_id                object
# patient_nbr                 object
# race                        object
# gender                      object
# age                         object
# admission_type_id           object
# discharge_disposition_id    object
# admission_source_id         object
# time_in_hospital             int64
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                   int64
# service_utilization          int64
# numchange                    int64
# level1_diag1                object
# level2_diag1                object
# level1_diag2                object
# level2_diag2                object
# level1_diag3                object
# level2_diag3                object
# dtype: object

# %%
df['nummed'] = 0

for col in keys:
    df['nummed'] = df['nummed'] + df[col]
df['nummed'].value_counts()
# Out:
# 1    44539
# 0    22144
# 2    20878
# 3     7439
# 4     1290
# 5       57
# 6        5
# Name: nummed, dtype: int64

# %%
# get list of only numeric features
num_col = list(set(list(df._get_numeric_data().columns))- {'readmitted'})
num_col
# Out:
# ['number_inpatient',
#  'service_utilization',
#  'num_lab_procedures',
#  'number_emergency',
#  'time_in_hospital',
#  'number_diagnoses',
#  'numchange',
#  'num_procedures',
#  'number_outpatient',
#  'num_medications']

# %%
# Removing skewnewss and kurtosis using log transformation if it is above a threshold value -  2

statdataframe = pd.DataFrame()
statdataframe['numeric_column'] = num_col
skew_before = []
skew_after = []

kurt_before = []
kurt_after = []

standard_deviation_before = []
standard_deviation_after = []

log_transform_needed = []

log_type = []

for i in num_col:
    skewval = df[i].skew()
    skew_before.append(skewval)
    
    kurtval = df[i].kurtosis()
    kurt_before.append(kurtval)
    
    sdval = df[i].std()
    standard_deviation_before.append(sdval)
    
    if (abs(skewval) >2) & (abs(kurtval) >2):
        log_transform_needed.append('Yes')
        
        if len(df[df[i] == 0])/len(df) <=0.02:
            log_type.append('log')
            skewvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).skew()
            skew_after.append(skewvalnew)
            
            kurtvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).kurtosis()
            kurt_after.append(kurtvalnew)
            
            sdvalnew = np.log(pd.DataFrame(df[train_data[i] > 0])[i]).std()
            standard_deviation_after.append(sdvalnew)
            
        else:
            log_type.append('log1p')
            skewvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).skew()
            skew_after.append(skewvalnew)
        
            kurtvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).kurtosis()
            kurt_after.append(kurtvalnew)
            
            sdvalnew = np.log1p(pd.DataFrame(df[df[i] >= 0])[i]).std()
            standard_deviation_after.append(sdvalnew)
            
    else:
        log_type.append('NA')
        log_transform_needed.append('No')
        
        skew_after.append(skewval)
        kurt_after.append(kurtval)
        standard_deviation_after.append(sdval)

statdataframe['skew_before'] = skew_before
statdataframe['kurtosis_before'] = kurt_before
statdataframe['standard_deviation_before'] = standard_deviation_before
statdataframe['log_transform_needed'] = log_transform_needed
statdataframe['log_type'] = log_type
statdataframe['skew_after'] = skew_after
statdataframe['kurtosis_after'] = kurt_after
statdataframe['standard_deviation_after'] = standard_deviation_after

# %%
statdataframe
# Out:
#         numeric_column  skew_before  kurtosis_before  \
# 0     number_inpatient     3.566745        20.046816
# 1  service_utilization     5.312668        67.186861
# 2   num_lab_procedures    -0.240602        -0.253321
# 3     number_emergency    22.690853      1164.432578
# 4     time_in_hospital     1.127237         0.837861
# 5     number_diagnoses    -0.809105        -0.380149
# 6            numchange     1.427227         1.454673
# 7       num_procedures     1.313315         0.856937
# 8    number_outpatient     8.770568       146.332546
# 9      num_medications     1.338507         3.542840
#
#    standard_deviation_before log_transform_needed log_type  skew_after  \
# 0                   1.270213                  Yes    log1p    1.425332
# 1                   2.316389                  Yes    log1p    1.097495
# 2                  19.655471                   No       NA   -0.240602
# 3                   0.948463                  Yes    log1p    3.614896
# 4                   2.982393                   No       NA    1.127237
# 5                   1.836415                   No       NA   -0.809105
# 6                   0.488526                   No       NA    1.427227
# 7                   1.702837                   No       NA    1.313315
# 8                   1.280134                  Yes    log1p    2.708537
# 9                   8.071928                   No       NA    1.338507
#
#    kurtosis_after  standard_deviation_after
# 0        1.320066                  0.513417
# 1        0.497783                  0.665716
# 2       -0.253321                 19.655471
# 3       15.856617                  0.318794
# 4        0.837861                  2.982393
# 5       -0.380149                  1.836415
# 6        1.454673                  0.488526
# 7        0.856937                  1.702837
# 8        7.648436                  0.432947
# 9        3.542840                  8.071928

# %%
# performing the log transformation for the columns determined to be needing it above.

for i in range(len(statdataframe)):
    if statdataframe['log_transform_needed'][i] == 'Yes':
        colname = str(statdataframe['numeric_column'][i])
        
        if statdataframe['log_type'][i] == 'log':
            df = df[df[colname] > 0]
            df[colname + "_log"] = np.log(df[colname])
            
        elif statdataframe['log_type'][i] == 'log1p':
            df = df[df[colname] >= 0]
            df[colname + "_log1p"] = np.log1p(df[colname])

# %%
df = df.drop(['number_outpatient', 'number_inpatient', 'number_emergency','service_utilization'], axis = 1)

# %%
df.shape
# Out:
# (96352, 54)

# %%
# get list of only numeric features
numerics = list(set(list(df._get_numeric_data().columns))- {'readmitted'})
numerics
# Out:
# ['service_utilization_log1p',
#  'num_lab_procedures',
#  'number_inpatient_log1p',
#  'time_in_hospital',
#  'number_diagnoses',
#  'numchange',
#  'num_procedures',
#  'number_outpatient_log1p',
#  'number_emergency_log1p',
#  'num_medications']

# %%
# show list of features that are categorical
df.encounter_id = df.encounter_id.astype('int64')
df.patient_nbr = df.patient_nbr.astype('int64')
df.diabetesMed = df.diabetesMed.astype('int64')
df.change = df.change.astype('int64')

# convert data type of nominal features in dataframe to 'object' type for aggregating
i = ['metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', \
          'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose','miglitol', \
          'troglitazone', 'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin', \
          'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone','A1Cresult']
df[i] = df[i].astype('int64')

df.dtypes
# Out:
# encounter_id                   int64
# patient_nbr                    int64
# race                          object
# gender                        object
# age                           object
# admission_type_id             object
# discharge_disposition_id      object
# admission_source_id           object
# time_in_hospital               int64
# num_lab_procedures             int64
# num_procedures                 int64
# num_medications                int64
# diag_1                        object
# diag_2                        object
# diag_3                        object
# number_diagnoses               int64
# max_glu_serum                 object
# A1Cresult                      int64
# metformin                      int64
# repaglinide                    int64
# nateglinide                    int64
# chlorpropamide                 int64
# glimepiride                    int64
# acetohexamide                  int64
# glipizide                      int64
# glyburide                      int64
# tolbutamide                    int64
# pioglitazone                   int64
# rosiglitazone                  int64
# acarbose                       int64
# miglitol                       int64
# troglitazone                   int64
# tolazamide                     int64
# insulin                        int64
# glyburide-metformin            int64
# glipizide-metformin            int64
# glimepiride-pioglitazone       int64
# metformin-rosiglitazone        int64
# metformin-pioglitazone         int64
# change                         int64
# diabetesMed                    int64
# readmitted                     int64
# numchange                      int64
# level1_diag1                  object
# level2_diag1                  object
# level1_diag2                  object
# level2_diag2                  object
# level1_diag3                  object
# level2_diag3                  object
# nummed                        object
# number_inpatient_log1p       float64
# service_utilization_log1p    float64
# number_emergency_log1p       float64
# number_outpatient_log1p      float64
# dtype: object

# %%
dfcopy = df.copy(deep = True)

# %%
df['readmitted'] = df['readmitted'].apply(lambda x: 0 if x == 2 else x)

# %%
# drop individual diagnosis columns that have too granular disease information
# also drop level 2 categorization (which was not comparable with any reference)
# also drop level 1 secondary and tertiary diagnoses
df.drop(['diag_1', 'diag_2', 'diag_3', 'level2_diag1', 'level1_diag2', 'level2_diag2', 'level1_diag3', 'level2_diag3'], axis=1, inplace=True)

# %%
interactionterms = [('num_medications','time_in_hospital'),
('num_medications','num_procedures'),
('time_in_hospital','num_lab_procedures'),
('num_medications','num_lab_procedures'),
('num_medications','number_diagnoses'),
('age','number_diagnoses'),
('change','num_medications'),
('number_diagnoses','time_in_hospital'),
('num_medications','numchange')]

# %%
for inter in interactionterms:
    name = inter[0] + '|' + inter[1]
    df[name] = df[inter[0]] * df[inter[1]]

# %%
df[['num_medications','time_in_hospital', 'num_medications|time_in_hospital']].head()
# Out:
#    num_medications  time_in_hospital  num_medications|time_in_hospital
# 1               18                 3                                54
# 2               13                 2                                26
# 3               16                 2                                32
# 4                8                 1                                 8
# 5               16                 3                                48

# %%
# Feature Scaling
datf = pd.DataFrame()
datf['features'] = numerics
datf['std_dev'] = datf['features'].apply(lambda x: df[x].std())
datf['mean'] = datf['features'].apply(lambda x: df[x].mean())

# %%
# dropping multiple encounters while keeping either first or last encounter of these patients
df2 = df.drop_duplicates(subset= ['patient_nbr'], keep = 'first')
df2.shape
# Out:
# (67528, 55)

# %%
# standardize function
def standardize(raw_data):
    return ((raw_data - np.mean(raw_data, axis = 0)) / np.std(raw_data, axis = 0))

# %%
df2[numerics] = standardize(df2[numerics])
import scipy as sp
df2 = df2[(np.abs(sp.stats.zscore(df2[numerics])) < 3).all(axis=1)]
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
from matplotlib.colors import ListedColormap
my_cmap = ListedColormap(sns.light_palette((250, 100, 50), input="husl", n_colors=50).as_hex())
table = df2.drop(['patient_nbr', 'encounter_id'], axis=1).corr(method='pearson')
table.style.background_gradient(cmap=my_cmap, axis = 0)
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\pandas\io\formats\style.py:1264: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\91944\anaconda3\lib\site-packages\pandas\io\formats\style.py:1265: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# #T_6398d_row0_col0,#T_6398d_row1_col1,#T_6398d_row2_col2,#T_6398d_row3_col3,#T_6398d_row4_col4,#T_6398d_row5_col5,#T_6398d_row6_col6,#T_6398d_row7_col7,#T_6398d_row8_col8,#T_6398d_row9_col9,#T_6398d_row10_col10,#T_6398d_row12_col12,#T_6398d_row13_col13,#T_6398d_row14_col14,#T_6398d_row15_col15,#T_6398d_row16_col16,#T_6398d_row17_col17,#T_6398d_row18_col18,#T_6398d_row19_col19,#T_6398d_row20_col20,#T_6398d_row21_col21,#T_6398d_row22_col22,#T_6398d_row23_col23,#T_6398d_row26_col26,#T_6398d_row27_col27,#T_6398d_row28_col28,#T_6398d_row29_col29,#T_6398d_row30_col30,#T_6398d_row31_col31,#T_6398d_row32_col32,#T_6398d_row33_col33,#T_6398d_row34_col34,#T_6398d_row35_col35,#T_6398d_row36_col36,#T_6398d_row37_col37,#T_6398d_row38_col38,#T_6398d_row39_col39,#T_6398d_row40_col40,#T_6398d_row41_col41,#T_6398d_row42_col42{
#             background-color:  #007ad1;
#             color:  #f1f1f1;
#         }#T_6398d_row0_col1,#T_6398d_row1_col41,#T_6398d_row28_col6,#T_6398d_row40_col6,#T_6398d_row41_col1{
#             background-color:  #9dc8e7;
#             color:  #000000;
#         }#T_6398d_row0_col2,#T_6398d_row1_col4,#T_6398d_row2_col41,#T_6398d_row4_col1,#T_6398d_row5_col38,#T_6398d_row12_col40,#T_6398d_row13_col6,#T_6398d_row16_col40,#T_6398d_row21_col3,#T_6398d_row21_col38,#T_6398d_row27_col38,#T_6398d_row28_col3,#T_6398d_row28_col10,#T_6398d_row30_col3,#T_6398d_row30_col35,#T_6398d_row30_col37,#T_6398d_row30_col39,#T_6398d_row35_col30,#T_6398d_row37_col2,#T_6398d_row38_col27,#T_6398d_row40_col4,#T_6398d_row40_col10,#T_6398d_row41_col2,#T_6398d_row42_col1{
#             background-color:  #c4dbec;
#             color:  #000000;
#         }#T_6398d_row0_col3,#T_6398d_row3_col0,#T_6398d_row3_col37,#T_6398d_row21_col30,#T_6398d_row28_col40,#T_6398d_row37_col3,#T_6398d_row40_col28,#T_6398d_row42_col21{
#             background-color:  #85bbe4;
#             color:  #000000;
#         }#T_6398d_row0_col4,#T_6398d_row1_col39,#T_6398d_row2_col35,#T_6398d_row3_col1,#T_6398d_row27_col15,#T_6398d_row27_col16,#T_6398d_row36_col40,#T_6398d_row37_col4,#T_6398d_row40_col12,#T_6398d_row40_col37,#T_6398d_row40_col41,#T_6398d_row42_col37,#T_6398d_row42_col41{
#             background-color:  #b1d1ea;
#             color:  #000000;
#         }#T_6398d_row0_col5,#T_6398d_row0_col12,#T_6398d_row0_col27,#T_6398d_row1_col12,#T_6398d_row1_col13,#T_6398d_row2_col12,#T_6398d_row2_col13,#T_6398d_row2_col40,#T_6398d_row3_col10,#T_6398d_row3_col16,#T_6398d_row4_col2,#T_6398d_row5_col6,#T_6398d_row5_col12,#T_6398d_row5_col13,#T_6398d_row5_col27,#T_6398d_row5_col42,#T_6398d_row6_col10,#T_6398d_row6_col15,#T_6398d_row10_col6,#T_6398d_row10_col15,#T_6398d_row12_col15,#T_6398d_row15_col6,#T_6398d_row15_col10,#T_6398d_row15_col13,#T_6398d_row16_col10,#T_6398d_row17_col13,#T_6398d_row18_col12,#T_6398d_row23_col13,#T_6398d_row27_col0,#T_6398d_row27_col1,#T_6398d_row27_col4,#T_6398d_row28_col5,#T_6398d_row29_col4,#T_6398d_row29_col12,#T_6398d_row29_col13,#T_6398d_row30_col12,#T_6398d_row30_col13,#T_6398d_row31_col4,#T_6398d_row31_col12,#T_6398d_row31_col33,#T_6398d_row32_col12,#T_6398d_row32_col13,#T_6398d_row33_col4,#T_6398d_row33_col12,#T_6398d_row33_col21,#T_6398d_row33_col31,#T_6398d_row34_col12,#T_6398d_row34_col13,#T_6398d_row35_col5,#T_6398d_row36_col12,#T_6398d_row36_col13,#T_6398d_row37_col12,#T_6398d_row37_col13,#T_6398d_row37_col27,#T_6398d_row39_col10,#T_6398d_row39_col15,#T_6398d_row39_col16,#T_6398d_row39_col32,#T_6398d_row41_col5,#T_6398d_row41_col12,#T_6398d_row41_col13,#T_6398d_row41_col27,#T_6398d_row42_col12,#T_6398d_row42_col13{
#             background-color:  #d7e5ef;
#             color:  #000000;
#         }#T_6398d_row0_col6,#T_6398d_row0_col7,#T_6398d_row0_col15,#T_6398d_row0_col32,#T_6398d_row1_col15,#T_6398d_row1_col16,#T_6398d_row1_col28,#T_6398d_row1_col32,#T_6398d_row3_col7,#T_6398d_row3_col8,#T_6398d_row3_col29,#T_6398d_row4_col5,#T_6398d_row4_col7,#T_6398d_row4_col16,#T_6398d_row4_col27,#T_6398d_row4_col29,#T_6398d_row6_col21,#T_6398d_row6_col32,#T_6398d_row7_col0,#T_6398d_row7_col1,#T_6398d_row7_col2,#T_6398d_row7_col30,#T_6398d_row7_col31,#T_6398d_row7_col32,#T_6398d_row7_col37,#T_6398d_row7_col39,#T_6398d_row7_col42,#T_6398d_row8_col1,#T_6398d_row8_col2,#T_6398d_row8_col5,#T_6398d_row8_col31,#T_6398d_row8_col32,#T_6398d_row8_col34,#T_6398d_row8_col41,#T_6398d_row9_col1,#T_6398d_row9_col2,#T_6398d_row9_col4,#T_6398d_row9_col5,#T_6398d_row9_col6,#T_6398d_row9_col15,#T_6398d_row9_col21,#T_6398d_row9_col31,#T_6398d_row9_col32,#T_6398d_row10_col2,#T_6398d_row10_col3,#T_6398d_row10_col31,#T_6398d_row10_col32,#T_6398d_row10_col39,#T_6398d_row10_col41,#T_6398d_row12_col0,#T_6398d_row12_col2,#T_6398d_row12_col3,#T_6398d_row12_col4,#T_6398d_row12_col5,#T_6398d_row12_col21,#T_6398d_row12_col31,#T_6398d_row12_col32,#T_6398d_row12_col34,#T_6398d_row12_col37,#T_6398d_row12_col38,#T_6398d_row12_col39,#T_6398d_row13_col0,#T_6398d_row13_col1,#T_6398d_row13_col2,#T_6398d_row13_col3,#T_6398d_row13_col4,#T_6398d_row13_col5,#T_6398d_row13_col31,#T_6398d_row13_col32,#T_6398d_row13_col34,#T_6398d_row13_col37,#T_6398d_row13_col41,#T_6398d_row14_col1,#T_6398d_row14_col2,#T_6398d_row14_col5,#T_6398d_row14_col6,#T_6398d_row14_col15,#T_6398d_row14_col16,#T_6398d_row14_col21,#T_6398d_row14_col31,#T_6398d_row14_col32,#T_6398d_row15_col5,#T_6398d_row15_col8,#T_6398d_row15_col22,#T_6398d_row15_col33,#T_6398d_row15_col34,#T_6398d_row15_col36,#T_6398d_row15_col42,#T_6398d_row16_col3,#T_6398d_row16_col5,#T_6398d_row16_col7,#T_6398d_row16_col8,#T_6398d_row16_col31,#T_6398d_row16_col32,#T_6398d_row16_col34,#T_6398d_row16_col39,#T_6398d_row17_col1,#T_6398d_row17_col2,#T_6398d_row17_col5,#T_6398d_row17_col7,#T_6398d_row17_col21,#T_6398d_row17_col28,#T_6398d_row17_col32,#T_6398d_row17_col34,#T_6398d_row17_col40,#T_6398d_row18_col1,#T_6398d_row18_col2,#T_6398d_row18_col5,#T_6398d_row18_col7,#T_6398d_row18_col31,#T_6398d_row18_col32,#T_6398d_row18_col33,#T_6398d_row18_col34,#T_6398d_row19_col1,#T_6398d_row19_col2,#T_6398d_row19_col5,#T_6398d_row19_col31,#T_6398d_row19_col32,#T_6398d_row19_col37,#T_6398d_row19_col41,#T_6398d_row20_col1,#T_6398d_row20_col2,#T_6398d_row20_col4,#T_6398d_row20_col5,#T_6398d_row20_col21,#T_6398d_row20_col32,#T_6398d_row21_col2,#T_6398d_row21_col6,#T_6398d_row22_col2,#T_6398d_row22_col5,#T_6398d_row22_col6,#T_6398d_row22_col32,#T_6398d_row22_col40,#T_6398d_row23_col1,#T_6398d_row23_col2,#T_6398d_row23_col5,#T_6398d_row23_col32,#T_6398d_row23_col34,#T_6398d_row26_col1,#T_6398d_row26_col2,#T_6398d_row26_col5,#T_6398d_row26_col31,#T_6398d_row26_col32,#T_6398d_row27_col17,#T_6398d_row27_col31,#T_6398d_row29_col2,#T_6398d_row29_col3,#T_6398d_row29_col5,#T_6398d_row29_col6,#T_6398d_row29_col15,#T_6398d_row29_col28,#T_6398d_row29_col34,#T_6398d_row29_col35,#T_6398d_row29_col38,#T_6398d_row29_col39,#T_6398d_row30_col2,#T_6398d_row30_col7,#T_6398d_row30_col31,#T_6398d_row30_col34,#T_6398d_row31_col2,#T_6398d_row31_col6,#T_6398d_row31_col29,#T_6398d_row31_col35,#T_6398d_row31_col38,#T_6398d_row31_col39,#T_6398d_row32_col1,#T_6398d_row32_col3,#T_6398d_row32_col27,#T_6398d_row32_col28,#T_6398d_row32_col29,#T_6398d_row32_col30,#T_6398d_row32_col40,#T_6398d_row32_col42,#T_6398d_row33_col1,#T_6398d_row33_col27,#T_6398d_row33_col28,#T_6398d_row33_col30,#T_6398d_row33_col41,#T_6398d_row33_col42,#T_6398d_row34_col27,#T_6398d_row34_col28,#T_6398d_row34_col39,#T_6398d_row35_col7,#T_6398d_row36_col5,#T_6398d_row36_col6,#T_6398d_row36_col31,#T_6398d_row37_col7,#T_6398d_row37_col15,#T_6398d_row37_col16,#T_6398d_row37_col29,#T_6398d_row37_col32,#T_6398d_row38_col7,#T_6398d_row38_col29,#T_6398d_row38_col33,#T_6398d_row39_col7,#T_6398d_row39_col8,#T ...
#             background-color:  #e6ecf1;
#             color:  #000000;
#         }#T_6398d_row0_col8,#T_6398d_row0_col22,#T_6398d_row0_col33,#T_6398d_row1_col6,#T_6398d_row1_col7,

# %%
df2['level1_diag1'] = df2['level1_diag1'].astype('object')
df_pd = pd.get_dummies(df2, columns=['gender', 'admission_type_id', 'discharge_disposition_id',
                                      'admission_source_id', 'max_glu_serum', 'A1Cresult', 'level1_diag1'], drop_first = True)
just_dummies = pd.get_dummies(df_pd['race'])
df_pd = pd.concat([df_pd, just_dummies], axis=1)      
df_pd.drop(['race'], inplace=True, axis=1)
df
# Out:
#         encounter_id  patient_nbr             race gender age  \
# 1             149190     55629189        Caucasian      0  15
# 2              64410     86047875  AfricanAmerican      0  25
# 3             500364     82442376        Caucasian      1  35
# 4              16680     42519267        Caucasian      1  45
# 5              35754     82637451        Caucasian      1  55
# ...              ...          ...              ...    ...  ..
# 101661     442558928     87326991        Caucasian      0  85
# 101662     442561946     97892019  AfricanAmerican      1  55
# 101663     442569986    146138783         Hispanic      0  55
# 101664     442573442     41262156        Caucasian      1  55
# 101665     442573472    132950534        Caucasian      0  55
#
#        admission_type_id discharge_disposition_id admission_source_id  \
# 1                      1                        1                   7
# 2                      1                        1                   7
# 3                      1                        1                   7
# 4                      1                        1                   7
# 5                      1                        1                   1
# ...                  ...                      ...                 ...
# 101661                 1                        1                   7
# 101662                 1                        1                   7
# 101663                 1                        1                   7
# 101664                 1                        1                   7
# 101665                 3                        1                   1
#
#         time_in_hospital  num_lab_procedures  ...  number_outpatient_log1p  \
# 1                      3                  59  ...                 0.000000
# 2                      2                  11  ...                 1.098612
# 3                      2                  44  ...                 0.000000
# 4                      1                  51  ...                 0.000000
# 5                      3                  31  ...                 0.000000
# ...                  ...                 ...  ...                      ...
# 101661                 4                  66  ...                 0.000000
# 101662                 6                  49  ...                 0.000000
# 101663                 3                  11  ...                 0.000000
# 101664                 4                  51  ...                 0.000000
# 101665                 3                  25  ...                 0.000000
#
#         num_medications|time_in_hospital  num_medications|num_procedures  \
# 1                                     54                               0
# 2                                     26                              65
# 3                                     32                              16
# 4                                      8                               0
# 5                                     48                              96
# ...                                  ...                             ...
# 101661                                56                               0
# 101662                                54                               9
# 101663                                24                               8
# 101664                                36                               0
# 101665                                42                              14
#
#        time_in_hospital|num_lab_procedures  \
# 1                                      177
# 2                                       22
# 3                                       88
# 4                                       51
# 5                                       93
# ...                                    ...
# 101661                                 264
# 101662                                 294
# 101663                                  33
# 101664                                 204
# 101665                                  75
#
#         num_medications|num_lab_procedures  num_medications|number_diagnoses  \
# 1                                     1062                               162
# 2                                      143                                78
# 3                                      704                               112
# 4                                      408                                40
# 5                                      496                               144
# ...                                    ...                               ...
# 101661                                 924                               112
# 101662                                 441                                54
# 101663                                  88                                40
# 101664                                 459                                63
# 101665                                 350                               126
#
#         age|number_diagnoses  change|num_medications  \
# 1                        135                      18
# 2                        150                       0
# 3                        245                      16
# 4                        225                       8
# 5                        495                       0
# ...                      ...                     ...
# 101661                   680                       0
# 101662                   330                       0
# 101663                   275                       8
# 101664                   385                       0
# 101665                   495                       0
#
#         number_diagnoses|time_in_hospital  num_medications|numchange
# 1                                      27                         18
# 2                                      12                          0
# 3                                      14                         16
# 4                                       5                          0
# 5                                      27                          0
# ...                                   ...                        ...
# 101661                                 32                          0
# 101662                                 36                          0
# 101663                                 15                          0
# 101664                                 28                          0
# 101665                                 27                          0
#
# [96352 rows x 55 columns]

# %%
non_num_cols = ['race', 'gender', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'max_glu_serum', 'A1Cresult', 'level1_diag1' ]

# %%
num_cols = list(set(list(df._get_numeric_data().columns))- {'readmitted', 'change'})
num_cols
# Out:
# ['num_medications|numchange',
#  'insulin',
#  'metformin-rosiglitazone',
#  'num_medications|num_procedures',
#  'tolazamide',
#  'number_diagnoses',
#  'num_medications|time_in_hospital',
#  'num_procedures',
#  'repaglinide',
#  'num_medications',
#  'service_utilization_log1p',
#  'metformin-pioglitazone',
#  'num_medications|number_diagnoses',
#  'glimepiride',
#  'encounter_id',
#  'num_lab_procedures',
#  'number_inpatient_log1p',
#  'time_in_hospital',
#  'number_diagnoses|time_in_hospital',
#  'acetohexamide',
#  'rosiglitazone',
#  'numchange',
#  'number_emergency_log1p',
#  'diabetesMed',
#  'glipizide-metformin',
#  'patient_nbr',
#  'chlorpropamide',
#  'glyburide',
#  'time_in_hospital|num_lab_procedures',
#  'glipizide',
#  'miglitol',
#  'acarbose',
#  'glyburide-metformin',
#  'change|num_medications',
#  'troglitazone',
#  'pioglitazone',
#  'nateglinide',
#  'metformin',
#  'num_medications|num_lab_procedures',
#  'A1Cresult',
#  'tolbutamide',
#  'glimepiride-pioglitazone',
#  'number_outpatient_log1p']

# %%
new_non_num_cols = []
for i in non_num_cols:
    for j in df_pd.columns:
        if i in j:
            new_non_num_cols.append(j)

# %%
new_non_num_cols
# Out:
# ['gender_1',
#  'admission_type_id_3',
#  'admission_type_id_4',
#  'admission_type_id_5',
#  'discharge_disposition_id_2',
#  'discharge_disposition_id_7',
#  'discharge_disposition_id_10',
#  'discharge_disposition_id_18',
#  'discharge_disposition_id_19',
#  'discharge_disposition_id_20',
#  'discharge_disposition_id_27',
#  'discharge_disposition_id_28',
#  'admission_source_id_4',
#  'admission_source_id_7',
#  'admission_source_id_8',
#  'admission_source_id_9',
#  'admission_source_id_11',
#  'max_glu_serum_0',
#  'max_glu_serum_1',
#  'A1Cresult_0',
#  'A1Cresult_1',
#  'level1_diag1_1.0',
#  'level1_diag1_2.0',
#  'level1_diag1_3.0',
#  'level1_diag1_4.0',
#  'level1_diag1_5.0',
#  'level1_diag1_6.0',
#  'level1_diag1_7.0',
#  'level1_diag1_8.0']

# %%
l = []
for feature in list(df_pd.columns):
    if '|' in feature:
        l.append(feature)
l
# Out:
# ['num_medications|time_in_hospital',
#  'num_medications|num_procedures',
#  'time_in_hospital|num_lab_procedures',
#  'num_medications|num_lab_procedures',
#  'num_medications|number_diagnoses',
#  'age|number_diagnoses',
#  'change|num_medications',
#  'number_diagnoses|time_in_hospital',
#  'num_medications|numchange']

# %%
df_pd.head().T
# Out:
#                            1         2         3         4         5
# encounter_id          149190     64410    500364     16680     35754
# patient_nbr         55629189  86047875  82442376  42519267  82637451
# age                       15        25        35        45        55
# time_in_hospital   -0.444771 -0.784051 -0.784051 -1.123332 -0.444771
# num_lab_procedures  0.803836 -1.602187  0.051954  0.402832 -0.599677
# ...                      ...       ...       ...       ...       ...
# AfricanAmerican            0         1         0         0         0
# Asian                      0         0         0         0         0
# Caucasian                  1         0         1         1         1
# Hispanic                   0         0         0         0         0
# Other                      0         0         0         0         0
#
# [81 rows x 5 columns]

# %%
feature_set = ['age', 'time_in_hospital', 'num_procedures', 'num_medications', 'number_outpatient_log1p', 
                 'number_emergency_log1p', 'number_inpatient_log1p', 'number_diagnoses', 'metformin', 
                 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 'glyburide',
                 'pioglitazone', 'rosiglitazone', 'acarbose', 'tolazamide', 'insulin', 'glyburide-metformin',
                 'AfricanAmerican', 'Asian', 'Caucasian', 'Hispanic', 'Other', 'gender_1', 
                 'admission_type_id_3', 'admission_type_id_5', 'discharge_disposition_id_2', 'discharge_disposition_id_7', 
                 'discharge_disposition_id_10', 'discharge_disposition_id_18', 'admission_source_id_4',
                 'admission_source_id_7', 'admission_source_id_9', 'max_glu_serum_0', 'max_glu_serum_1', 'A1Cresult_0',
                 'A1Cresult_1', 'num_medications|time_in_hospital', 'num_medications|num_procedures',
                 'time_in_hospital|num_lab_procedures', 'num_medications|num_lab_procedures', 'num_medications|number_diagnoses',
                 'age|number_diagnoses', 'change|num_medications', 'number_diagnoses|time_in_hospital',
                 'num_medications|numchange', 'level1_diag1_1.0', 'level1_diag1_2.0', 'level1_diag1_3.0', 'level1_diag1_4.0',
                 'level1_diag1_5.0','level1_diag1_6.0', 'level1_diag1_7.0', 'level1_diag1_8.0']

# %%
X = df_pd[feature_set]
y = df_pd['readmitted']

# %%
df_pd['readmitted'].value_counts()
# Out:
# 0    54593
# 1     5070
# Name: readmitted, dtype: int64

# %%
#TRAINING - LOGIT
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
logit = LogisticRegression(fit_intercept=True)
logit.fit(X_train, y_train)
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#VALIDATION
#cross validation
from sklearn.model_selection import cross_val_score,KFold
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
kf=KFold(n_splits=5)
score=cross_val_score(logreg,X_train,y_train,cv=kf)
print("Cross Validation Scores are {}".format(score))
print("Average Cross Validation score :{}".format(score.mean()))
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Cross Validation Scores are [0.91514771 0.91535722 0.91399539 0.9168238  0.91430966]
# Average Cross Validation score :0.9151267546616385
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#TESTING
logit_pred = logit.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
# Out:
# Predict     0   All
# Actual
# 0        1466  1466
# 1         166   166
# All      1632  1632

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))
# Out:
# Accuracy is 0.91
# Precision is 0.00
# Recall is 0.00

# %%
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE
from collections import Counter
print('Original dataset shape {}'.format(Counter(y_train)))
sm = SMOTE(random_state=20)
train_input_new, train_output_new = sm.fit_resample(X_train, y_train)
print('New dataset shape {}'.format(Counter(train_output_new)))
# Out:
# Original dataset shape Counter({0: 43685, 1: 4045})
# New dataset shape Counter({1: 43685, 0: 43685})

# %%
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
logit = LogisticRegression(fit_intercept=True)
logit.fit(X_train, y_train)
# Out:
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='warn',
          n_jobs=None, penalty='l1', random_state=None, solver='warn',
          tol=0.0001, verbose=0, warm_start=False)
# Out:
# LogisticRegression(multi_class='warn', penalty='l1', solver='warn')

# %%
logit_pred = logit.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
# Out:
# Predict     0     1   All
# Actual
# 0        1690  1469  3159
# 1         161   130   291
# All      1851  1599  3450

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))

accuracy_logit = accuracy_score(y_test, logit_pred)
precision_logit = precision_score(y_test, logit_pred)
recall_logit = recall_score(y_test, logit_pred)
# Out:
# Accuracy is 0.75
# Precision is 0.77
# Recall is 0.73

# %%
feature_set_no_int = ['age', 'time_in_hospital', 'num_procedures', 'num_medications', 'number_outpatient_log1p', 
                 'number_emergency_log1p', 'number_inpatient_log1p', 'number_diagnoses', 'metformin', 
                 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 
                 'glyburide', 'pioglitazone', 'rosiglitazone', 'acarbose', 
                 'tolazamide', 'insulin', 'glyburide-metformin',
                 'AfricanAmerican', 'Asian', 'Caucasian', 
                 'Hispanic', 'Other', 'gender_1', 
                 'admission_type_id_3', 'admission_type_id_5', 
                 'discharge_disposition_id_2', 'discharge_disposition_id_7', 
                 'discharge_disposition_id_10', 'discharge_disposition_id_18', 
                 'admission_source_id_4', 'admission_source_id_7', 
                 'admission_source_id_9', 'max_glu_serum_0', 
                 'max_glu_serum_1', 'A1Cresult_0', 'A1Cresult_1', 
                 'level1_diag1_1.0',
                 'level1_diag1_2.0',
                 'level1_diag1_3.0',
                 'level1_diag1_4.0',
                 'level1_diag1_5.0',
                 'level1_diag1_6.0',
                 'level1_diag1_7.0',
                 'level1_diag1_8.0']

# %%
X = df_pd[feature_set_no_int]
y = df_pd['readmitted']
df_pd['readmitted'].value_counts()
# Out:
# 0    54593
# 1     5070
# Name: readmitted, dtype: int64

# %%
print('Original dataset shape {}'.format(Counter(y)))
smt = SMOTE(random_state=20)
train_input_new, train_output_new = smt.fit_resample(X, y)
print('New dataset shape {}'.format(Counter(train_output_new)))
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
# Out:
# Original dataset shape Counter({0: 54593, 1: 5070})
# New dataset shape Counter({0: 54593, 1: 54593})

# %%
#TRAINING - DECISION TREE
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=28, criterion = "entropy", min_samples_split=10)
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=28, min_samples_split=10)

# %%
#VALIDATION
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold, cross_val_score
clf = DecisionTreeClassifier(random_state=42)
k_folds = KFold(n_splits = 5)
scores = cross_val_score(clf, X_train, y_train, cv = k_folds)
print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.88986835 0.89009731 0.88780767 0.89426985 0.89266701]
# Average CV Score:  0.8909420370562058
# Number of CV Scores used in Average:  5

# %%
#TESTING
dtree_pred = dtree.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(dtree_pred, name = 'Predict'), margins = True)
# Out:
# Predict     0     1   All
# Actual
# 0        2066  1907  3973
# 1         218   202   420
# All      2284  2109  4393

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, dtree_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, dtree_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, dtree_pred)))

accuracy_dtree = accuracy_score(y_test, dtree_pred)
precision_dtree = precision_score(y_test, dtree_pred)
recall_dtree = recall_score(y_test, dtree_pred)
# Out:
# Accuracy is 0.90
# Precision is 0.92
# Recall is 0.87

# %%
feature_set_no_int = ['age', 'time_in_hospital', 'num_procedures', 'num_medications', 'number_outpatient_log1p', 
                 'number_emergency_log1p', 'number_inpatient_log1p', 'number_diagnoses', 'metformin', 
                 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 
                 'glyburide', 'pioglitazone', 'rosiglitazone', 'acarbose', 
                 'tolazamide', 'insulin', 'glyburide-metformin',
                 'AfricanAmerican', 'Asian', 'Caucasian', 
                 'Hispanic', 'Other', 'gender_1', 
                 'admission_type_id_3', 'admission_type_id_5', 
                 'discharge_disposition_id_2', 'discharge_disposition_id_7', 
                 'discharge_disposition_id_10', 'discharge_disposition_id_18', 
                 'admission_source_id_4', 'admission_source_id_7', 
                 'admission_source_id_9', 'max_glu_serum_0', 
                 'max_glu_serum_1', 'A1Cresult_0', 'A1Cresult_1', 
                 'level1_diag1_1.0',
                 'level1_diag1_2.0',
                 'level1_diag1_3.0',
                 'level1_diag1_4.0',
                 'level1_diag1_5.0',
                 'level1_diag1_6.0',
                 'level1_diag1_7.0',
                 'level1_diag1_8.0']

# %%
X = df_pd[feature_set_no_int]
y = df_pd['readmitted']
df_pd['readmitted'].value_counts()
# Out:
# 0    54593
# 1     5070
# Name: readmitted, dtype: int64

# %%
print('Original dataset shape {}'.format(Counter(y)))
smt = SMOTE(random_state=20)
train_input_new, train_output_new = smt.fit_resample(X, y)
print('New dataset shape {}'.format(Counter(train_output_new)))
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
# Out:
# Original dataset shape Counter({0: 54593, 1: 5070})
# New dataset shape Counter({0: 54593, 1: 54593})

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=28, criterion = "entropy", min_samples_split=10)
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=28, min_samples_split=10)

# %%
dtree_pred = dtree.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(dtree_pred, name = 'Predict'), margins = True)
# Out:
# Predict     0     1   All
# Actual
# 0        2063  1910  3973
# 1         217   203   420
# All      2280  2113  4393

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, dtree_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, dtree_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, dtree_pred)))

accuracy_dtree = accuracy_score(y_test, dtree_pred)
precision_dtree = precision_score(y_test, dtree_pred)
recall_dtree = recall_score(y_test, dtree_pred)
# Out:
# Accuracy is 0.89
# Precision is 0.91
# Recall is 0.87

# %%
# Create list of top most features based on importance
feature_names = X_train.columns
feature_imports = dtree.feature_importances_
most_imp_features = pd.DataFrame([f for f in zip(feature_names,feature_imports)], columns=["Feature", "Importance"]).nlargest(10, "Importance")
most_imp_features.sort_values(by="Importance", inplace=True)
print(most_imp_features)
plt.figure(figsize=(10,6))
plt.barh(range(len(most_imp_features)), most_imp_features.Importance, align='center', alpha=0.8)
plt.yticks(range(len(most_imp_features)), most_imp_features.Feature, fontsize=14)
plt.xlabel('Importance')
plt.title('Most important features - Decision Tree')
plt.show()
# Out:
#                        Feature  Importance
# 4      number_outpatient_log1p    0.008662
# 19                     insulin    0.008723
# 34       admission_source_id_7    0.009061
# 29  discharge_disposition_id_2    0.009137
# 26                    gender_1    0.009928
# 0                          age    0.031645
# 7             number_diagnoses    0.067838
# 2               num_procedures    0.073459
# 3              num_medications    0.091875
# 1             time_in_hospital    0.560899

# %%
X = df_pd[feature_set_no_int]
y = df_pd['readmitted']

print('Original dataset shape {}'.format(Counter(y)))
smt = SMOTE(random_state=20)
train_input_new, train_output_new = smt.fit_resample(X, y)
print('New dataset shape {}'.format(Counter(train_output_new)))
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
# Out:
# Original dataset shape Counter({0: 54593, 1: 5070})
# New dataset shape Counter({0: 54593, 1: 54593})

# %%
#TRAINING - RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
rm = RandomForestClassifier(n_estimators = 10, max_depth=25, criterion = "gini", min_samples_split=10)
rm.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=25, min_samples_split=10, n_estimators=10)

# %%
#VALIDATION - RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, cross_val_score
clf = RandomForestClassifier()
k_folds = KFold(n_splits = 5)
scores = cross_val_score(clf, X_train, y_train, cv = k_folds)
print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.93686319 0.93279908 0.93755009 0.93399737 0.93617265]
# Average CV Score:  0.9354764759017226
# Number of CV Scores used in Average:  5

# %%
#TESTING - RANDOM FOREST
rm_prd = rm.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(rm_prd, name = 'Predict'), margins = True)
# Out:
# Predict     0     1   All
# Actual
# 0        1944  2029  3973
# 1         203   217   420
# All      2147  2246  4393

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, rm_prd)))
print("Precision is {0:.2f}".format(precision_score(y_test, rm_prd)))
print("Recall is {0:.2f}".format(recall_score(y_test, rm_prd)))

accuracy_rm = accuracy_score(y_test, rm_prd)
precision_rm = precision_score(y_test, rm_prd)
recall_rm = recall_score(y_test, rm_prd)
# Out:
# Accuracy is 0.89
# Precision is 0.88
# Recall is 0.90

# %%
# Create list of top most features based on importance
feature_names = X_train.columns
feature_imports = rm.feature_importances_
most_imp_features = pd.DataFrame([f for f in zip(feature_names,feature_imports)], columns=["Feature", "Importance"]).nlargest(10, "Importance")
most_imp_features.sort_values(by="Importance", inplace=True)
plt.figure(figsize=(10,6))
plt.barh(range(len(most_imp_features)), most_imp_features.Importance, align='center', alpha=0.8)
plt.yticks(range(len(most_imp_features)), most_imp_features.Feature, fontsize=14)
plt.xlabel('Importance')
plt.title('Most important features - Random Forest ')
plt.show()

# %%
plt.figure(figsize=(14, 7))
ax = plt.subplot(111)

models = ['Logistic Regression', 'Decision Tree', 'Random Forests']
values = [accuracy_logit, accuracy_dtree, accuracy_rm]
model = np.arange(len(models))

plt.bar(model, values, align='center', width = 0.15, alpha=0.7, color = 'red', label= 'accuracy')
plt.xticks(model, models)
           

           
ax = plt.subplot(111)

models = ['Logistic Regression', 'Decision Tree', 'Random Forests']
values = [precision_logit, precision_dtree, precision_rm]
model = np.arange(len(models))

plt.bar(model+0.15, values, align='center', width = 0.15, alpha=0.7, color = 'blue', label = 'precision')
plt.xticks(model, models)



ax = plt.subplot(111)

models = ['Logistic Regression', 'Decision Tree', 'Random Forests' ]
values = [recall_logit, recall_dtree, recall_rm, ]
model = np.arange(len(models))

plt.bar(model+0.3, values, align='center', width = 0.15, alpha=0.7, color = 'green', label = 'recall')
plt.xticks(model, models)



plt.ylabel('Performance Metrics for Different models')
plt.title('Model')
    
# removing the axis on the top and right of the plot window
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.legend()

plt.show()
# Out:
# <ipython-input-370-a1f6da031ada>:13: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(111)
# <ipython-input-370-a1f6da031ada>:24: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(111)

# %%
# Linear Classifier
from sklearn.metrics import accuracy_score,classification_report
from sklearn.svm import SVC

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
model_svm = SVC(kernel='rbf')

# %%
model_svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
#TRAINING - SVM
print ("\nSVM Linear Classifier - Train Confusion Matrix\n\n",pd.crosstab(y_train, model_svm.predict(X_train),rownames =["Actuall"],colnames = ["Predicted"]) )
print ("\nSVM Linear Classifier - Train accuracy:",round(accuracy_score(y_train, model_svm.predict(X_train)),3))
print ("\nSVM Linear Classifier - Train Classification Report\n", classification_report(y_train,model_svm.predict(X_train)))
# Out:
# SVM Linear Classifier - Train Confusion Matrix
#
#  Predicted      0
# Actuall
# 0          43685
# 1           4045
#
# SVM Linear Classifier - Train accuracy: 0.915
#
# SVM Linear Classifier - Train Classification Report
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     43685
#            1       0.00      0.00      0.00      4045
#
#     accuracy                           0.92     47730
#    macro avg       0.46      0.50      0.48     47730
# weighted avg       0.84      0.92      0.87     47730
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#VALIDATION - SVM
from sklearn.metrics import accuracy_score,classification_report
from sklearn.svm import SVC
from sklearn.model_selection import KFold, cross_val_score
clf = SVC(kernel='rbf')
k_folds = KFold(n_splits = 5)
scores = cross_val_score(clf, X_train, y_train, cv = k_folds)
print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))
# Out:
# Cross Validation Scores:  [0.91514771 0.91535722 0.91399539 0.91703331 0.91472868]
# Average CV Score:  0.9152524617640896
# Number of CV Scores used in Average:  5

# %%
#TESTING - SVM
print ("\n\nSVM Linear Classifier - Test Confusion Matrix\n\n",pd.crosstab(y_test, model_svm.predict(X_test),rownames = ["Actuall"],colnames = ["Predicted"]))
print ("\nSVM Linear Classifier - Test accuracy:",round(accuracy_score(y_test,model_svm.predict(X_test)),3))
print ("\nSVM Linear Classifier - Test Classification Report\n",classification_report(y_test,model_svm.predict(X_test)))
# Out:
# SVM Linear Classifier - Test Confusion Matrix
#
#  Predicted      0
# Actuall
# 0          10908
# 1           1025
#
# SVM Linear Classifier - Test accuracy: 0.914
#
# SVM Linear Classifier - Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.96     10908
#            1       0.00      0.00      0.00      1025
#
#     accuracy                           0.91     11933
#    macro avg       0.46      0.50      0.48     11933
# weighted avg       0.84      0.91      0.87     11933
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\91944\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE
from collections import Counter
print('Original dataset shape {}'.format(Counter(y_train)))
sm = SMOTE(random_state=20)
train_input_new, train_output_new = sm.fit_resample(X_train, y_train)
print('New dataset shape {}'.format(Counter(train_output_new)))
# Out:
# Original dataset shape Counter({0: 43685, 1: 4045})
# New dataset shape Counter({1: 43685, 0: 43685})

# %%
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)

# %%
model_svm1 = SVC(kernel='rbf')

# %%
model_svm1.fit(X_train, y_train)
# Out:
# SVC()

# %%
print ("\nSVM Linear Classifier - Train Confusion Matrix\n\n",pd.crosstab(y_train, model_svm1.predict(X_train),rownames =["Actuall"],colnames = ["Predicted"]) )
print ("\nSVM Linear Classifier - Train accuracy:",round(accuracy_score(y_train, model_svm1.predict(X_train)),3))
print ("\nSVM Linear Classifier - Train Classification Report\n", classification_report(y_train,model_svm1.predict(X_train)))
# Out:
# SVM Linear Classifier - Train Confusion Matrix
#
#  Predicted      0      1
# Actuall
# 0          23391  11676
# 1           7908  26921
#
# SVM Linear Classifier - Train accuracy: 0.72
#
# SVM Linear Classifier - Train Classification Report
#                precision    recall  f1-score   support
#
#            0       0.75      0.67      0.70     35067
#            1       0.70      0.77      0.73     34829
#
#     accuracy                           0.72     69896
#    macro avg       0.72      0.72      0.72     69896
# weighted avg       0.72      0.72      0.72     69896

# %%
#print ("\n\nSVM Linear Classifier - Test Confusion Matrix\n\n",pd.crosstab(y_test, model_svm1.predict(X_test),rownames = ["Actuall"],colnames = ["Predicted"]))
print ("\nSVM Linear Classifier - Test accuracy:",round(accuracy_score(y_test,model_svm1.predict(X_test)),3))
#print ("\nSVM Linear Classifier - Test Classification Report\n",classification_report(y_test,model_svm1.predict(X_test)))
# Out:
# SVM Linear Classifier - Test accuracy: 0.72

# %%
#Deep neural network classifier applied on handwritten digits using Keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,classification_report

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import Adadelta,Adam,RMSprop
from keras.utils import np_utils

# %%
# Defining hyper parameters
np.random.seed(1337)
nb_classes = 2
batch_size = 128
nb_epochs = 100

# %%
#Deep Layer Model building in Keras
model = Sequential()

# %%
model.add(Dense(50, input_shape=(48,), activation='relu'))

# %%
model.add(Dense(100))
model.add(Activation('softmax'))
model.add(Dropout(0.5))

# %%
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
#Model training
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
#Y_train = np_utils.to_categorical(y_train, nb_classes)

# %%
x_vars_stdscle = StandardScaler().fit_transform(X)
#The following section of the code splits the data into train and test based on a 70-30 split:
X_train,X_test,y_train,y_test = train_test_split(x_vars_stdscle,y,train_size = 0.7,random_state=42)

# %%
X_train = np.asarray(X_train).astype(np.int64)
y_train = np.array(y_train).astype(np.int64)
X_train.size
# Out:
# 2004672

# %%
model.fit(X_train, y_train, batch_size=batch_size,epochs=nb_epochs,verbose=1)
# Out:
# Epoch 1/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.5164 - accuracy: 0.9130
# Epoch 2/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3855 - accuracy: 0.9147: 0s - loss: 0.422
# Epoch 3/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3421 - accuracy: 0.9147
# Epoch 4/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3249 - accuracy: 0.9147
# Epoch 5/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3161 - accuracy: 0.9147: 0s - loss: 0.3191 - accuracy:  - ETA: 0s - loss: 0.3180 - accu
# Epoch 6/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3104 - accuracy: 0.9147
# Epoch 7/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3037 - accuracy: 0.9147
# Epoch 8/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.3000 - accuracy: 0.9147
# Epoch 9/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2971 - accuracy: 0.9147
# Epoch 10/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2942 - accuracy: 0.9147
# Epoch 11/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2930 - accuracy: 0.9147
# Epoch 12/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2909 - accuracy: 0.9147
# Epoch 13/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2895 - accuracy: 0.9147
# Epoch 14/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2890 - accuracy: 0.9147
# Epoch 15/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2875 - accuracy: 0.9147
# Epoch 16/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2868 - accuracy: 0.9147
# Epoch 17/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2868 - accuracy: 0.9147
# Epoch 18/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2859 - accuracy: 0.9147
# Epoch 19/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2860 - accuracy: 0.9147
# Epoch 20/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2857 - accuracy: 0.9147
# Epoch 21/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2851 - accuracy: 0.9147
# Epoch 22/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2852 - accuracy: 0.9147
# Epoch 23/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2851 - accuracy: 0.9147
# Epoch 24/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2848 - accuracy: 0.9147
# Epoch 25/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2847 - accuracy: 0.9147: 0s - loss: 0.2864 - accuracy: 0.
# Epoch 26/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2848 - accuracy: 0.9147
# Epoch 27/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2844 - accuracy: 0.9147
# Epoch 28/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2848 - accuracy: 0.9147
# Epoch 29/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2842 - accuracy: 0.9147
# Epoch 30/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2837 - accuracy: 0.9147
# Epoch 31/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2835 - accuracy: 0.9147
# Epoch 32/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2837 - accuracy: 0.9147: 0s - loss: 0.2849 - accuracy: 0.
# Epoch 33/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2833 - accuracy: 0.9147: 0s - loss: 0.283
# Epoch 34/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2832 - accuracy: 0.9147
# Epoch 35/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2827 - accuracy: 0.9147
# Epoch 36/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2829 - accuracy: 0.9147
# Epoch 37/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2829 - accuracy: 0.9147
# Epoch 38/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2825 - accuracy: 0.9147
# Epoch 39/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2830 - accuracy: 0.9147
# Epoch 40/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2823 - accuracy: 0.9147
# Epoch 41/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2815 - accuracy: 0.9147
# Epoch 42/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2818 - accuracy: 0.9147: 0s - loss: 0.2819
# Epoch 43/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2817 - accuracy: 0.9147
# Epoch 44/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2812 - accuracy: 0.9147
# Epoch 45/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2809 - accuracy: 0.9147
# Epoch 46/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2805 - accuracy: 0.9147
# Epoch 47/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2804 - accuracy: 0.9147
# Epoch 48/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2801 - accuracy: 0.9147
# Epoch 49/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2799 - accuracy: 0.9147
# Epoch 50/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2798 - accuracy: 0.9147
# Epoch 51/100
# 327/327 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.91 - 1s 2ms/step - loss: 0.2789 - accuracy: 0.9147
# Epoch 52/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2794 - accuracy: 0.9147
# Epoch 53/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2787 - accuracy: 0.9147
# Epoch 54/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2785 - accuracy: 0.9147
# Epoch 55/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2779 - accuracy: 0.9147
# Epoch 56/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2775 - accuracy: 0.9147
# Epoch 57/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2766 - accuracy: 0.9147
# Epoch 58/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2776 - accuracy: 0.9147
# Epoch 59/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2770 - accuracy: 0.9147
# Epoch 60/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2761 - accuracy: 0.9147
# Epoch 61/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2758 - accuracy: 0.9147: 0s - loss: 0.2759 - accuracy: 0.
# Epoch 62/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2761 - accuracy: 0.9147
# Epoch 63/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2757 - accuracy: 0.9147
# Epoch 64/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2755 - accuracy: 0.9147
# Epoch 65/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2751 - accuracy: 0.9147
# Epoch 66/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2748 - accuracy: 0.9147: 0s - loss: 0.2735 - accuracy: 0.
# Epoch 67/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2745 - accuracy: 0.9147
# Epoch 68/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2734 - accuracy: 0.9147
# Epoch 69/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2738 - accuracy: 0.9147
# Epoch 70/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2736 - accuracy: 0.9147: 0s - loss: 0.2734 - accuracy: 0.
# Epoch 71/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2729 - accuracy: 0.9147
# Epoch 72/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2726 - accuracy: 0.9147
# Epoch 73/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2720 - accuracy: 0.9147
# Epoch 74/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2720 - accuracy: 0.9147
# Epoch 75/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2713 - accuracy: 0.9147
# Epoch 76/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2709 - accuracy: 0.9147
# Epoch 77/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2712 - accuracy: 0.9147
# Epoch 78/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2711 - accuracy: 0.9147
# Epoch 79/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2708 - accuracy: 0.9146
# Epoch 80/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2696 - accuracy: 0.9146
# Epoch 81/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2689 - accuracy: 0.9147
# Epoch 82/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2696 - accuracy: 0.9147: 0s - loss: 0.2672 - accura
# Epoch 83/100
# 327/327 [==============================] - 0s 1ms/step - loss: 0.2691 - accuracy: 0.9147
# Epoch 84/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2686 - accuracy: 0.9147
# Epoch 85/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2680 - accuracy: 0.9147
# Epoch 86/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2691 - accuracy: 0.9147
# Epoch 87/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2689 - accuracy: 0.9146
# Epoch 88/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2678 - accuracy: 0.9147
# Epoch 89/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2672 - accuracy: 0.9147
# Epoch 90/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2674 - accuracy: 0.9146
# Epoch 91/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2668 - accuracy: 0.9146
# Epoch 92/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2666 - accuracy: 0.9148
# Epoch 93/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2656 - accuracy: 0.9147
# Epoch 94/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2657 - accuracy: 0.9148
# Epoch 95/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2650 - accuracy: 0.9145
# Epoch 96/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2650 - accuracy: 0.9149
# Epoch 97/100
# 327/327 [==============================] - 0s 2ms/step - loss: 0.2647 - accuracy: 0.9147: 0s - loss: 0.2680 - accuracy:
# Epoch 98/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2646 - accuracy: 0.9147
# Epoch 99/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2648 - accuracy: 0.9147
# Epoch 100/100
# 327/327 [==============================] - 1s 2ms/step - loss: 0.2644 - accuracy: 0.9149

# %%
#Returns the loss value & metrics values for the model in test mode.
score = model.evaluate(X_test, y_test,
                       batch_size=batch_size, verbose=1)
 
print('Test accuracy:', score[0], score[1])
# Out:
# 140/140 [==============================] - 0s 670us/step - loss: 0.3049 - accuracy: 0.9158
# Test accuracy: 0.30488213896751404 0.9158053398132324

# %%
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
#Model Prediction
y_train_predclass = model.predict_classes(X_train,batch_size=batch_size)
y_test_predclass = model.predict_classes(X_test,batch_size=batch_size)
y_train_predclass = np.array(y_train).astype(np.int64)
y_test_predclass = np.array(y_test).astype(np.int64)

# %%
print ("\n\nDeep Neural Network - Train accuracy:", round(accuracy_score(y_train,y_train_predclass),3))
print ("\nDeep Neural Network - Train Classification Report", print (classification_report(y_train,y_train_predclass)))
print ('\n Deep Neural Network - Train Confusion Matrix')
print (pd.crosstab(y_train,y_train_predclass[1],rownames = ["Actual"],colnames = ["Predicted"]) )
# Out:
# Deep Neural Network - Train accuracy: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     38201
#            1       1.00      1.00      1.00      3563
#
#     accuracy                           1.00     41764
#    macro avg       1.00      1.00      1.00     41764
# weighted avg       1.00      1.00      1.00     41764
#
#
# Deep Neural Network - Train Classification Report None
#
#  Deep Neural Network - Train Confusion Matrix
# Predicted      0
# Actual
# 0          38201
# 1           3563

# %%
print ("\nDeep Neural Network - Test accuracy:",round(accuracy_score(y_test, y_test_predclass),3))
print ("\nDeep Neural Network - Test Classification Report")
print (classification_report(y_test,y_test_predclass))
print ("\nDeep Neural Network - Test Confusion Matrix\n")
print (pd.crosstab(y_test,y_test_predclass,rownames = ["Actuall"],colnames = ["Predicted"]) )
# Out:
# Deep Neural Network - Test accuracy: 1.0
#
# Deep Neural Network - Test Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     16392
#            1       1.00      1.00      1.00      1507
#
#     accuracy                           1.00     17899
#    macro avg       1.00      1.00      1.00     17899
# weighted avg       1.00      1.00      1.00     17899
#
#
# Deep Neural Network - Test Confusion Matrix
#
# Predicted      0     1
# Actuall
# 0          16392     0
# 1              0  1507
